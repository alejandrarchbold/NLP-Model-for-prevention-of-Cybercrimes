# %% [markdown]
# # Detecting cybercrimes using similarity models

# %% [markdown]
# ## OS

# %%
import os # The OS module in Python provides a way of using operating system dependent functionality
import pandas as pd # Read data from file

# %%
os.listdir("C:/Users/Alejandra/Desktop/Proyecto") # Reads and shows files in entered location
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'datos prueba',
#  'download_utils.py',
#  'GoogleNews-vectors-negative300.bin',
#  'grader.py',
#  'My First Project-689f409050bd.json',
#  'NLP.ipynb',
#  'prueba1.xlsx',
#  'prueba2.xlsx',
#  'setup.py',
#  'solution.py',
#  'test_embedding.tsv',
#  'tweets',
#  'util.py',
#  'validation.tsv',
#  '__pycache__']

# %% [markdown]
# ## Data

# %%
data = pd.read_excel("prueba1.xlsx",sheet_name="Archive") # Importing the database (tweets)

# %%
data.head() # Returns the first rows of the database
# Out:
#                 id_str        from_user  \
# 0  1254475950059896832          elk2812
# 1  1254469890683084800    JhojanObregon
# 2  1254419035208462336        farcila20
# 3  1254261736812810241         Tapas667
# 4  1254132061771882498  FlorMariaSerna5
#
#                                                 text  \
# 0  @Fernand60915270 @farmerguanabana @jflafaurie ...
# 1  Este señor parece que solo lee el título de no...
# 2  El cómplice de Santrich en Colombia goza de to...
# 3  @Lucho_Pipe10 @Elbatobatillo Pues colombia apo...
# 4  @DELAESPRIELLAE @AlexLopezMaya Honorable Dr AB...
#
#                        created_at                time  geo_coordinates  \
# 0  Sun Apr 26 18:22:28 +0000 2020 2020-04-26 19:22:28              NaN
# 1  Sun Apr 26 17:58:23 +0000 2020 2020-04-26 18:58:23              NaN
# 2  Sun Apr 26 14:36:18 +0000 2020 2020-04-26 15:36:18              NaN
# 3  Sun Apr 26 04:11:15 +0000 2020 2020-04-26 05:11:15              NaN
# 4  Sat Apr 25 19:35:58 +0000 2020 2020-04-25 20:35:58              NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN             1.189782e+18         Fernand60915270
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN             8.199648e+17            Lucho_Pipe10
# 4        NaN             5.489067e+08          DELAESPRIELLAE
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0  1160001175380484097               1.254359e+18
# 1            201605528                        NaN
# 2  1210573841153581057                        NaN
# 3  1062105377637052419               1.254250e+18
# 4  1224110745970991109               1.253837e+18
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1160001592...                  1708
# 1  http://pbs.twimg.com/profile_images/1246568582...                   165
# 2  http://pbs.twimg.com/profile_images/1210574132...                   532
# 3  http://pbs.twimg.com/profile_images/1241786730...                    24
# 4  http://pbs.twimg.com/profile_images/1251262160...                    57
#
#    user_friends_count                 user_location  \
# 0                3296                           NaN
# 1                 634  Lima: -12.062106, -77.036526
# 2                 963                           NaN
# 3                  52        Bogotá, D.C., Colombia
# 4                  64                           NaN
#
#                                           status_url  \
# 0  http://twitter.com/elk2812/statuses/1254475950...
# 1  http://twitter.com/JhojanObregon/statuses/1254...
# 2  http://twitter.com/farcila20/statuses/12544190...
# 3  http://twitter.com/Tapas667/statuses/125426173...
# 4  http://twitter.com/FlorMariaSerna5/statuses/12...
#
#                                         entities_str
# 0  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 1  {"hashtags":[],"symbols":[],"user_mentions":[]...
# 2  {"hashtags":[],"symbols":[],"user_mentions":[]...
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 4  {"hashtags":[],"symbols":[],"user_mentions":[{...

# %%
text=data['text'].tolist() # converting to list the column "text" where it contains the tweets

# %%
#print(text) # printing the tweets

# %%
len(text) # number of tweets
# Out:
# 44

# %%
tweet_1 =[text[0]] # accessing to the first tweet from the list 'text'
tweet_1
# Out:
# ['@Fernand60915270 @farmerguanabana @jflafaurie @HenaoBernardo @Fedegan @GaulaMilitares @GaulaPolicia @NobelPrize @JuanManSantos @JEP_Colombia @PartidoFARC @IvanDuque @CongresoCol Por La Empresa e Inversión es que Ud y Su Flia Pueden Comer y Disfrutar  de Medios para que uds PARASITOS VIVAN porque Trabaja Mas facil una Pala Empeñada que un Solo MAMERTOS de Uds Se Mueva y Algo por este País Viven de Gorra del Secuestro la Extorsión y Se Camuflan de Lideres']

# %% [markdown]
# ## Data Preparation
#
# - ## Functions to remove URL links, @mention, #hashtags

# %%
import string # String contains methods that allow the use of characters which are considered punctuation characters, 
                # digits, uppercase, lowercase, etc.
import re # Regular expression operations

# %%
def strip_links(text): # function to remove/strip URL links
    link_regular_expression = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links = re.findall(link_regular_expression, text)
    for link in links:
        text = text.replace(link[0], ', ')   
    return text

# %%
def strip_all_entities(text): # function to remove/strip mentions, hashtags, characters from some users
    entity_prefixes = ['@','#','\\','_']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

# %% [markdown]
# source: https://stackoverflow.com/questions/8376691/how-to-remove-hashtag-user-link-of-a-tweet-using-regular-expression

# %%
def strip_all(list_text): # function that removes all URL links, @mention, #hashtags
    list_stripped = []
    for t in list_text:
        word = strip_all_entities(strip_links(t))
        list_stripped.append(word)
    return(list_stripped)

# %%
tweets = strip_all(text)
#tweets  # printing the tweets

# %% [markdown]
# - ## Function to convert tweets in lowercase

# %%
def lower_case(list_text): # Convert lowercase tweets for language processing
    list_lower_case = []
    for i in list_text:
        word = i.strip()
        new_word = word.lower()
        list_lower_case.append(new_word)
    return(list_lower_case)

# %%
tweets = lower_case(tweets)

#tweets  # printing the tweets

# %% [markdown]
# - ## Replace the emojis for their names

# %%
import emoji # Emoji codes

# %%
def replace_name_emoji(list_text): # function that replaces emoticons by their names
    list_name_emoji = []
    for l in list_text:
        list_name_emoji.append(emoji.demojize(l, delimiters=("", "")))
    return(list_name_emoji)

# %%
tweets = replace_name_emoji(tweets)

tweets  # printing the tweets
# Out:
# ['por la empresa e inversión es que ud y su flia pueden comer y disfrutar de medios para que uds parasitos vivan porque trabaja mas facil una pala empeñada que un solo mamertos de uds se mueva y algo por este país viven de gorra del secuestro la extorsión y se camuflan de lideres   ',
#  'este señor parece que solo lee el título de noticia tanto uruguay méxico colombia y chile viene aplicando educación a distancia muchos años atrás aquí un genocida apoyó prensa chicha y mató estudiantes universitarios un suicida secuestró docentes y así hipócrita   ',
#  'el cómplice de santrich en colombia goza de total apoyo de los magistrados jurídicamente podría decirse qué hay complicidad con el terrorismo   ',
#  'pues colombia apoyó en la guerra de corea tal vez se acuerdan y nos mandan un bombazo   ',
#  'por lo visto en hoy en twitter y el apoyo al m 19 en unos años timochenko será en realidad un líder defensor y salvador del pueblo colombiano y las farc pasaran a ser en realidad un ejemplo de lucha social con armas y paz lo que hay que leer en estos dias   ',
#  'exacto y ya hubo algo para los campesinos de la guerra de los grupos paramilitares que el mismo ejercito desactivó y se llama como me puede decir o me toca contestarle la pregunta si está preparado para debatir conflicto armado si puede contestar o le ayudo thumbs_upColombia   ',
#  'desafortunado twitt la guerra sólo ha dejado madres humildes llorando sus hijos voy hacer de cuenta que no lo he leído porque le tengo respeto apoyo la colombia justa la de oportunidades más no la confrontación y la polarización en la que nos han sometido   ',
#  'con el nombramiento de la fecal general para acabar con el poder judicial y ahora con el apoyo armado militar y policial ya españa tiene dictadura tipo chavista solo les falta darle armas a los colectivos paramilitares podemitas y psoevitas para ser la tiranía perfecta   ',
#  'claaaaro estas feliz con la invasiòn de cuba rusia china iran eln farc terrorismo plastas de mierda como tù etc etc   ',
#  'feliz cumpleaños gustavo lo mejor fue que dejarás el camino de las armas colombia siempre ha necesitado una reforma integral agraria y ésta al igual que la paz nunca se logrará por el camino de las armas te deseo lo mejor y que continúes con tus acertados argumentos   ',
#  'feliz cumpleaños gustavo lo mejor fue que dejarás el camino de las armas colombia siempre ha necesitado una reforma integral agraria y ésta al igual que la paz nunca se logrará por el camino de las armas te deseo lo mejor y que continúes con tus acertados argumentos   ']

# %% [markdown]
# ## Translation

# %%
# provides authentication credentials to application code:

os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="C:/Users/Alejandra/Desktop/Proyecto/My First Project-689f409050bd.json"

# %%
from google.cloud import translate_v2 as translate

def translate_text(text,target='en'):
    translate_client = translate.Client()
    result = translate_client.translate(text, target_language=target, format_= "text")
    
    return(result['translatedText'])

# %%
test_tweets = []

character_count = 0
translated_tweets = 0

for f in tweets:
    tweets_translated = translate_text(f, target = "en")
    test_tweets.append(tweets_translated)
    
    translated_tweets += 1
    character_count += len(f)

# %%
# test_tweets

# %%
print("Total characters translated: {0}".format(character_count))
print("Translated Tweets: {0}".format(translated_tweets))
# Out:
# Total characters translated: 10295
# Translated Tweets: 44

# %%
test_tweets[0] # first translated tweet
# Out:
# 'for the company and investment is that you and your family can eat and enjoy the means for you parasites to live because a pawned shovel works easier than a single mamertos of you to move and something for this country lives from kidnapping cap extortion and they camouflage themselves as leaders'

# %%
# exporting translated tweets

# %%
base = pd.DataFrame(test_tweets, columns=["tweets"])

# %%
base.to_csv('test.csv', sep = ',')

# %% [markdown]
# ### Grading

# %%
from grader import Grader

# %%
grader = Grader()

# %% [markdown]
# ## Word Embedding

# %%
import gensim

#wv_embedding is the embedding loaded
wv_embeddings = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True, limit=500000) ######### YOUR CODE HERE #############
type(wv_embeddings )
# Out:
# gensim.models.keyedvectors.Word2VecKeyedVectors

# %% [markdown]
# ## From word to text embedding

# %%
#This function converts a question in a vector
import numpy as np
def tweets_to_vec(tweet, embeddings, dim=300):

    result = np.zeros(dim) #300 dimensional vector for phrase vector
    cnt = 0
    words = tweet.split()
    for word in words: #All word vectors composing the phrase are summed
        if word in embeddings:
            result += np.array(embeddings[word])
            cnt += 1
    if cnt != 0: #This would happen if no word was found in the embedding
        result /= cnt
    return result

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\

# hola [ 0.04995858  0.02655646 -0.00574289 ... -0.09630229  0.09677327
#   0.0209259 ]
# [ 0.04995858  0.02655646 -0.00574289 ... -0.09630229  0.09677327
#   0.0209259 ]
# hola [ 0.04995858  0.02655646 -0.00574289 ... -0.03153274  0.04445514
#  -0.05274156]
# [ 0.04995858  0.02655646 -0.00574289 ... -0.03153274  0.04445514
#  -0.05274156]
# hola [ 0.04995858  0.02655646 -0.00574289 ... -0.08131181  0.02561529
#  -0.00383548]
# [ 0.04995858  0.02655646 -0.00574289 ... -0.08131181  0.02561529
#  -0.00383548]
# hola [ 0.04995858  0.02655646 -0.00574289 ... -0.02748549  0.0250651
#  -0.05288493]
# [ 0.04995858  0.02655646 -0.00574289 ... -0.02748549  0.0250651
#  -0.05288493]
# hola [ 0.04995858  0.02655646 -0.00574289 ... -0.02973298  0.0547697
#  -0.01229957]
# [ 0.04995858  0.02655646 -0.00574289 ... -0.02973298  0.0547697
#  -0.01229957]
# hola [ 0.04995858  0.02655646 -0.00574289 ... -0.10629582  0.00564575
#   0.05291748]
# [ 0.04995858  0.02655646 -0.00574289 ... -0.10629582  0.00564575
#   0.05291748]
# hola [ 0.04995858  0.02655646 -0.00574289 ... -0.06384888  0.01786127
#  -0.01817504]
# [ 0.04995858  0.02655646 -0.00574289 ... -0.06384888  0.01786127
#  -0.01817504]
# hola [ 0.04995858  0.02655646 -0.00574289 ... -0.06384888  0.01786127
#  -0.01817504]
# [ 0.04995858  0.02655646 -0.00574289 ... -0.06384888  0.01786127
#  -0.01817504]

# %% [markdown]
# ## Evaluation of text similarity

# %% [markdown]
# ### HitsCount and DCGScore

# %%
'''
Metric 1 to validate the precision of a model
'''
def hits_count(dup_ranks, k):
    
    return np.average(np.array(dup_ranks) <= np.array([k]))

# %%
'''
Metric 2 to validate the precision of a model
'''

def dcg_score(dup_ranks, k):

    return np.average((np.array(dup_ranks) <= np.array([k]))*1./(np.log2(1. + np.array(dup_ranks))))

# %% [markdown]
# ## Cosine similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
tweet_vec= []
for tweet in test_tweets:
    # Strip removes the first space in the string
    tweet = tweet.strip()
    
    answer = tweets_to_vec(tweet, wv_embeddings)
    # Print each question with its vectorization
    tweet_vec.append(answer)

# %%
len(tweet_vec)
# Out:
# 44

# %%
a=cosine_similarity([tweet_vec[0]],[tweet_vec[1]])

# %%
def cosine_measure(list_text):
    list_total =[]
    for i in list_text:
        list_cosine =[]
        for j in list_text:
            if (i-j).all():
                a=cosine_similarity([i],[j])
                list_cosine.append(a)
        list_total.append(list_cosine)
    return(list_total)

# %%
cosines = cosine_measure(tweet_vec)

# %%
cosines
# Out:
# [[array([[0.70207276]]),
#   array([[0.72803324]]),
#   array([[0.69135575]]),
#   array([[0.76820153]]),
#   array([[0.75138278]]),
#   array([[0.82597124]]),
#   array([[0.75621477]]),
#   array([[0.75988078]]),
#   array([[0.81055416]]),
#   array([[0.76671452]]),
#   array([[0.72988869]]),
#   array([[0.74240722]]),
#   array([[0.8504179]]),
#   array([[0.87075671]]),
#   array([[0.73541807]]),
#   array([[0.71118979]]),
#   array([[0.81135899]]),
#   array([[0.64664508]]),
#   array([[0.70092177]]),
#   array([[0.84696347]]),
#   array([[0.65197291]]),
#   array([[0.81843312]]),
#   array([[0.7779822]]),
#   array([[0.73049599]]),
#   array([[0.78577445]]),
#   array([[0.74854324]]),
#   array([[0.81482561]]),
#   array([[0.60668862]]),
#   array([[0.7508488]]),
#   array([[0.84334356]]),
#   array([[0.60442462]]),
#   array([[0.70436354]]),
#   array([[0.73789919]]),
#   array([[0.84620825]]),
#   array([[0.74976576]]),
#   array([[0.64572982]]),
#   array([[0.78208251]]),
#   array([[0.83940032]]),
#   array([[0.80672969]]),
#   array([[0.68024306]]),
#   array([[0.57901189]]),
#   array([[0.81875488]]),
#   array([[0.81875488]])],
#  [array([[0.70207276]]),
#   array([[0.67576904]]),
#   array([[0.62723042]]),
#   array([[0.61211732]]),
#   array([[0.75506598]]),
#   array([[0.65609172]]),
#   array([[0.68018978]]),
#   array([[0.73786959]]),
#   array([[0.6852927]]),
#   array([[0.69928739]]),
#   array([[0.65591677]]),
#   array([[0.69077009]]),
#   array([[0.68653416]]),
#   array([[0.67933699]]),
#   array([[0.65017945]]),
#   array([[0.65061942]]),
#   array([[0.67387691]]),
#   array([[0.70205525]]),
#   array([[0.70985495]]),
#   array([[0.71796925]]),
#   array([[0.65804938]]),
#   array([[0.65363119]]),
#   array([[0.71704651]]),
#   array([[0.72987158]]),
#   array([[0.71236097]]),
#   array([[0.66988137]]),
#   array([[0.7088409]]),
#   array([[0.6176531]]),
#   array([[0.65305782]]),
#   array([[0.71737129]]),
#   array([[0.64205702]]),
#   array([[0.62566022]]),
#   array([[0.65904407]]),
#   array([[0.68964363]]),
#   array([[0.70538805]]),
#   array([[0.69729917]]),
#   array([[0.7096145]]),
#   array([[0.68708975]]),
#   array([[0.74118572]]),
#   array([[0.67264167]]),
#   array([[0.50987721]]),
#   array([[0.6442771]]),
#   array([[0.6442771]])],
#  [array([[0.72803324]]),
#   array([[0.67576904]]),
#   array([[0.58025386]]),
#   array([[0.63719961]]),
#   array([[0.78838064]]),
#   array([[0.76268137]]),
#   array([[0.77835482]]),
#   array([[0.70815986]]),
#   array([[0.75630101]]),
#   array([[0.7108402]]),
#   array([[0.77507202]]),
#   array([[0.8322362]]),
#   array([[0.71421548]]),
#   array([[0.71241466]]),
#   array([[0.8034484]]),
#   array([[0.7268007]]),
#   array([[0.80764815]]),
#   array([[0.68050194]]),
#   array([[0.76114324]]),
#   array([[0.81990727]]),
#   array([[0.71909187]]),
#   array([[0.69358081]]),
#   array([[0.77566751]]),
#   array([[0.75648859]]),
#   array([[0.78955813]]),
#   array([[0.70005545]]),
#   array([[0.79769605]]),
#   array([[0.69399584]]),
#   array([[0.76322999]]),
#   array([[0.7090969]]),
#   array([[0.73562325]]),
#   array([[0.66247771]]),
#   array([[0.70647421]]),
#   array([[0.73975667]]),
#   array([[0.78686944]]),
#   array([[0.71053607]]),
#   array([[0.75482972]]),
#   array([[0.74648167]]),
#   array([[0.78782313]]),
#   array([[0.45227208]]),
#   array([[0.73793755]]),
#   array([[0.73793755]])],
#  [array([[0.69135575]]),
#   array([[0.62723042]]),
#   array([[0.58025386]]),
#   array([[0.67970906]]),
#   array([[0.6344179]]),
#   array([[0.73218102]]),
#   array([[0.6386305]]),
#   array([[0.82009399]]),
#   array([[0.65992913]]),
#   array([[0.66504954]]),
#   array([[0.66434693]]),
#   array([[0.68435598]]),
#   array([[0.73064299]]),
#   array([[0.75654525]]),
#   array([[0.63435295]]),
#   array([[0.68270205]]),
#   array([[0.72055271]]),
#   array([[0.57271707]]),
#   array([[0.65530339]]),
#   array([[0.71663996]]),
#   array([[0.57223925]]),
#   array([[0.70422521]]),
#   array([[0.70237927]]),
#   array([[0.64246026]]),
#   array([[0.68316713]]),
#   array([[0.63001939]]),
#   array([[0.72116271]]),
#   array([[0.4978086]]),
#   array([[0.64299094]]),
#   array([[0.68855052]]),
#   array([[0.53264366]]),
#   array([[0.5999913]]),
#   array([[0.72539095]]),
#   array([[0.80707189]]),
#   array([[0.76894771]]),
#   array([[0.57649734]]),
#   array([[0.72280824]]),
#   array([[0.74904842]]),
#   array([[0.76739374]]),
#   array([[0.59665577]]),
#   array([[0.56549588]]),
#   array([[0.69344062]]),
#   array([[0.69344062]])],
#  [array([[0.76820153]]),
#   array([[0.61211732]]),
#   array([[0.63719961]]),
#   array([[0.67970906]]),
#   array([[0.59032798]]),
#   array([[0.81174702]]),
#   array([[0.60838632]]),
#   array([[0.68288674]]),
#   array([[0.68209075]]),
#   array([[0.69812746]]),
#   array([[0.57910162]]),
#   array([[0.64329882]]),
#   array([[0.79532365]]),
#   array([[0.78774031]]),
#   array([[0.64669155]]),
#   array([[0.57824443]]),
#   array([[0.72319211]]),
#   array([[0.5666773]]),
#   array([[0.56521354]]),
#   array([[0.72470054]]),
#   array([[0.54882836]]),
#   array([[0.7690905]]),
#   array([[0.6780326]]),
#   array([[0.65714492]]),
#   array([[0.78093465]]),
#   array([[0.69484328]]),
#   array([[0.6941829]]),
#   array([[0.45268779]]),
#   array([[0.63657411]]),
#   array([[0.76170016]]),
#   array([[0.53321141]]),
#   array([[0.51496576]]),
#   array([[0.65082561]]),
#   array([[0.78603759]]),
#   array([[0.68607164]]),
#   array([[0.59719286]]),
#   array([[0.67460042]]),
#   array([[0.75042164]]),
#   array([[0.78348129]]),
#   array([[0.58295917]]),
#   array([[0.59679474]]),
#   array([[0.80639063]]),
#   array([[0.80639063]])],
#  [array([[0.75138278]]),
#   array([[0.75506598]]),
#   array([[0.78838064]]),
#   array([[0.6344179]]),
#   array([[0.59032798]]),
#   array([[0.68963105]]),
#   array([[0.89093298]]),
#   array([[0.73658632]]),
#   array([[0.73337865]]),
#   array([[0.69737302]]),
#   array([[0.8226895]]),
#   array([[0.80317053]]),
#   array([[0.72896861]]),
#   array([[0.72313732]]),
#   array([[0.75562711]]),
#   array([[0.7721007]]),
#   array([[0.74696065]]),
#   array([[0.7310019]]),
#   array([[0.79545365]]),
#   array([[0.78640184]]),
#   array([[0.76086674]]),
#   array([[0.67865194]]),
#   array([[0.77375762]]),
#   array([[0.80102237]]),
#   array([[0.72012629]]),
#   array([[0.73032944]]),
#   array([[0.79262076]]),
#   array([[0.80809137]]),
#   array([[0.75045847]]),
#   array([[0.72131543]]),
#   array([[0.72022803]]),
#   array([[0.70821144]]),
#   array([[0.73152265]]),
#   array([[0.72975001]]),
#   array([[0.75274721]]),
#   array([[0.74016194]]),
#   array([[0.77142306]]),
#   array([[0.73982616]]),
#   array([[0.7338111]]),
#   array([[0.79076279]]),
#   array([[0.51497746]]),
#   array([[0.68967461]]),
#   array([[0.68967461]])],
#  [array([[0.82597124]]),
#   array([[0.65609172]]),
#   array([[0.76268137]]),
#   array([[0.73218102]]),
#   array([[0.81174702]]),
#   array([[0.68963105]]),
#   array([[0.70977422]]),
#   array([[0.79110903]]),
#   array([[0.8094828]]),
#   array([[0.80057017]]),
#   array([[0.71035583]]),
#   array([[0.80586399]]),
#   array([[0.84307829]]),
#   array([[0.8456473]]),
#   array([[0.77109994]]),
#   array([[0.69833656]]),
#   array([[0.89301399]]),
#   array([[0.60790642]]),
#   array([[0.67982608]]),
#   array([[0.85665312]]),
#   array([[0.63681188]]),
#   array([[0.78751852]]),
#   array([[0.77766663]]),
#   array([[0.7519923]]),
#   array([[0.87197529]]),
#   array([[0.74722356]]),
#   array([[0.81247463]]),
#   array([[0.54364336]]),
#   array([[0.75716566]]),
#   array([[0.80978144]]),
#   array([[0.6531548]]),
#   array([[0.63167522]]),
#   array([[0.7420491]]),
#   array([[0.88037507]]),
#   array([[0.78189599]]),
#   array([[0.64157641]]),
#   array([[0.77856158]]),
#   array([[0.83937632]]),
#   array([[0.8773009]]),
#   array([[0.68830378]]),
#   array([[0.50189826]]),
#   array([[0.86561733]]),
#   array([[0.86561733]])],
#  [array([[0.75621477]]),
#   array([[0.68018978]]),
#   array([[0.77835482]]),
#   array([[0.6386305]]),
#   array([[0.60838632]]),
#   array([[0.89093298]]),
#   array([[0.70977422]]),
#   array([[0.73021507]]),
#   array([[0.76493754]]),
#   array([[0.719543]]),
#   array([[0.83423831]]),
#   array([[0.76795724]]),
#   array([[0.72866246]]),
#   array([[0.74675951]]),
#   array([[0.81148316]]),
#   array([[0.77847695]]),
#   array([[0.79208481]]),
#   array([[0.68185506]]),
#   array([[0.78789616]]),
#   array([[0.8038199]]),
#   array([[0.73497412]]),
#   array([[0.7075153]]),
#   array([[0.78497837]]),
#   array([[0.79511054]]),
#   array([[0.68646425]]),
#   array([[0.73193282]]),
#   array([[0.76930936]]),
#   array([[0.74223662]]),
#   array([[0.76785183]]),
#   array([[0.69632085]]),
#   array([[0.70481403]]),
#   array([[0.72712966]]),
#   array([[0.77259755]]),
#   array([[0.75966923]]),
#   array([[0.80227407]]),
#   array([[0.64806537]]),
#   array([[0.82342878]]),
#   array([[0.75955474]]),
#   array([[0.73312727]]),
#   array([[0.80035496]]),
#   array([[0.5031157]]),
#   array([[0.73254024]]),
#   array([[0.73254024]])],
#  [array([[0.75988078]]),
#   array([[0.73786959]]),
#   array([[0.70815986]]),
#   array([[0.82009399]]),
#   array([[0.68288674]]),
#   array([[0.73658632]]),
#   array([[0.79110903]]),
#   array([[0.73021507]]),
#   array([[0.77479278]]),
#   array([[0.76442149]]),
#   array([[0.75900204]]),
#   array([[0.7564241]]),
#   array([[0.81154081]]),
#   array([[0.81483483]]),
#   array([[0.75474735]]),
#   array([[0.78920185]]),
#   array([[0.83283206]]),
#   array([[0.72200774]]),
#   array([[0.77000652]]),
#   array([[0.81255497]]),
#   array([[0.71128372]]),
#   array([[0.76623113]]),
#   array([[0.78592281]]),
#   array([[0.80750756]]),
#   array([[0.7629659]]),
#   array([[0.73029864]]),
#   array([[0.83181744]]),
#   array([[0.59273862]]),
#   array([[0.76376683]]),
#   array([[0.78457247]]),
#   array([[0.63332311]]),
#   array([[0.71214652]]),
#   array([[0.77307681]]),
#   array([[0.88271595]]),
#   array([[0.84085122]]),
#   array([[0.64852951]]),
#   array([[0.80687198]]),
#   array([[0.80632984]]),
#   array([[0.86782048]]),
#   array([[0.72573214]]),
#   array([[0.54317509]]),
#   array([[0.77314475]]),
#   array([[0.77314475]])],
#  [array([[0.81055416]]),
#   array([[0.6852927]]),
#   array([[0.75630101]]),
#   array([[0.65992913]]),
#   array([[0.68209075]]),
#   array([[0.73337865]]),
#   array([[0.8094828]]),
#   array([[0.76493754]]),
#   array([[0.77479278]]),
#   array([[0.75645722]]),
#   array([[0.77262057]]),
#   array([[0.76279775]]),
#   array([[0.84034336]]),
#   array([[0.81992919]]),
#   array([[0.79540491]]),
#   array([[0.77175193]]),
#   array([[0.8382746]]),
#   array([[0.68983202]]),
#   array([[0.74458607]]),
#   array([[0.848564]]),
#   array([[0.65162631]]),
#   array([[0.78281565]]),
#   array([[0.82021097]]),
#   array([[0.77813718]]),
#   array([[0.77434977]]),
#   array([[0.7530781]]),
#   array([[0.82747122]]),
#   array([[0.64615692]]),
#   array([[0.83508376]]),
#   array([[0.77951468]]),
#   array([[0.6790878]]),
#   array([[0.73763343]]),
#   array([[0.78515981]]),
#   array([[0.81553114]]),
#   array([[0.77994766]]),
#   array([[0.63547622]]),
#   array([[0.81661432]]),
#   array([[0.8264422]]),
#   array([[0.81740146]]),
#   array([[0.73644298]]),
#   array([[0.53930914]]),
#   array([[0.82896153]]),
#   array([[0.82896153]])],
#  [array([[0.76671452]]),
#   array([[0.69928739]]),
#   array([[0.7108402]]),
#   array([[0.66504954]]),
#   array([[0.69812746]]),
#   array([[0.69737302]]),
#   array([[0.80057017]]),
#   array([[0.719543]]),
#   array([[0.76442149]]),
#   array([[0.75645722]]),
#   array([[0.69602292]]),
#   array([[0.75917355]]),
#   array([[0.79354908]]),
#   array([[0.80331867]]),
#   array([[0.70905552]]),
#   array([[0.71730401]]),
#   array([[0.79408178]]),
#   array([[0.61892293]]),
#   array([[0.69246245]]),
#   array([[0.80636247]]),
#   array([[0.65222582]]),
#   array([[0.70065831]]),
#   array([[0.74473784]]),
#   array([[0.73876402]]),
#   array([[0.78071921]]),
#   array([[0.69130083]]),
#   array([[0.75385299]]),
#   array([[0.58317179]]),
#   array([[0.71941241]]),
#   array([[0.76265149]]),
#   array([[0.61826537]]),
#   array([[0.66154336]]),
#   array([[0.68962178]]),
#   array([[0.79267803]]),
#   array([[0.75236765]]),
#   array([[0.64672439]]),
#   array([[0.75704903]]),
#   array([[0.81236331]]),
#   array([[0.795621]]),
#   array([[0.7111171]]),
#   array([[0.48175263]]),
#   array([[0.77966427]]),
#   array([[0.77966427]])],
#  [array([[0.72988869]]),
#   array([[0.65591677]]),
#   array([[0.77507202]]),
#   array([[0.66434693]]),
#   array([[0.57910162]]),
#   array([[0.8226895]]),
#   array([[0.71035583]]),
#   array([[0.83423831]]),
#   array([[0.75900204]]),
#   array([[0.77262057]]),
#   array([[0.69602292]]),
#   array([[0.77353752]]),
#   array([[0.72577648]]),
#   array([[0.70423206]]),
#   array([[0.7946587]]),
#   array([[0.83123717]]),
#   array([[0.75449571]]),
#   array([[0.67764278]]),
#   array([[0.80692074]]),
#   array([[0.76361411]]),
#   array([[0.73037617]]),
#   array([[0.68035631]]),
#   array([[0.78815723]]),
#   array([[0.78805508]]),
#   array([[0.70521688]]),
#   array([[0.68601147]]),
#   array([[0.78053656]]),
#   array([[0.75793198]]),
#   array([[0.7923291]]),
#   array([[0.69465511]]),
#   array([[0.69463965]]),
#   array([[0.7475202]]),
#   array([[0.80526134]]),
#   array([[0.74513534]]),
#   array([[0.78530386]]),
#   array([[0.66292596]]),
#   array([[0.82045274]]),
#   array([[0.72539592]]),
#   array([[0.72659101]]),
#   array([[0.7907677]]),
#   array([[0.43189803]]),
#   array([[0.71500719]]),
#   array([[0.71500719]])],
#  [array([[0.74240722]]),
#   array([[0.69077009]]),
#   array([[0.8322362]]),
#   array([[0.68435598]]),
#   array([[0.64329882]]),
#   array([[0.80317053]]),
#   array([[0.80586399]]),
#   array([[0.76795724]]),
#   array([[0.7564241]]),
#   array([[0.76279775]]),
#   array([[0.75917355]]),
#   array([[0.77353752]]),
#   array([[0.75443809]]),
#   array([[0.79237048]]),
#   array([[0.77986313]]),
#   array([[0.73513547]]),
#   array([[0.8143568]]),
#   array([[0.7059186]]),
#   array([[0.72333379]]),
#   array([[0.83755933]]),
#   array([[0.67865426]]),
#   array([[0.70647235]]),
#   array([[0.83666999]]),
#   array([[0.73432681]]),
#   array([[0.79805643]]),
#   array([[0.68156565]]),
#   array([[0.81159558]]),
#   array([[0.7145457]]),
#   array([[0.73974982]]),
#   array([[0.74229618]]),
#   array([[0.74921224]]),
#   array([[0.6401175]]),
#   array([[0.73378076]]),
#   array([[0.78899649]]),
#   array([[0.76791079]]),
#   array([[0.76197571]]),
#   array([[0.77735625]]),
#   array([[0.78226299]]),
#   array([[0.80281495]]),
#   array([[0.72655379]]),
#   array([[0.52168447]]),
#   array([[0.74286243]]),
#   array([[0.74286243]])],
#  [array([[0.8504179]]),
#   array([[0.68653416]]),
#   array([[0.71421548]]),
#   array([[0.73064299]]),
#   array([[0.79532365]]),
#   array([[0.72896861]]),
#   array([[0.84307829]]),
#   array([[0.72866246]]),
#   array([[0.81154081]]),
#   array([[0.84034336]]),
#   array([[0.79354908]]),
#   array([[0.72577648]]),
#   array([[0.75443809]]),
#   array([[0.86805708]]),
#   array([[0.73989209]]),
#   array([[0.74259445]]),
#   array([[0.82204876]]),
#   array([[0.66416802]]),
#   array([[0.71209038]]),
#   array([[0.83603101]]),
#   array([[0.64964328]]),
#   array([[0.83435859]]),
#   array([[0.79714841]]),
#   array([[0.76706634]]),
#   array([[0.80411014]]),
#   array([[0.76784871]]),
#   array([[0.82132465]]),
#   array([[0.59482788]]),
#   array([[0.77899802]]),
#   array([[0.82234863]]),
#   array([[0.59446352]]),
#   array([[0.69596394]]),
#   array([[0.77055657]]),
#   array([[0.87039368]]),
#   array([[0.77430544]]),
#   array([[0.64784304]]),
#   array([[0.77931482]]),
#   array([[0.83559589]]),
#   array([[0.85448614]]),
#   array([[0.70196628]]),
#   array([[0.58414546]]),
#   array([[0.87269617]]),
#   array([[0.87269617]])],
#  [array([[0.87075671]]),
#   array([[0.67933699]]),
#   array([[0.71241466]]),
#   array([[0.75654525]]),
#   array([[0.78774031]]),
#   array([[0.72313732]]),
#   array([[0.8456473]]),
#   array([[0.74675951]]),
#   array([[0.81483483]]),
#   array([[0.81992919]]),
#   array([[0.80331867]]),
#   array([[0.70423206]]),
#   array([[0.79237048]]),
#   array([[0.86805708]]),
#   array([[0.76126006]]),
#   array([[0.69198772]]),
#   array([[0.86564777]]),
#   array([[0.67353119]]),
#   array([[0.66525888]]),
#   array([[0.87253282]]),
#   array([[0.60225179]]),
#   array([[0.81559754]]),
#   array([[0.79229508]]),
#   array([[0.74243234]]),
#   array([[0.79538996]]),
#   array([[0.76653509]]),
#   array([[0.84114514]]),
#   array([[0.53829048]]),
#   array([[0.72178276]]),
#   array([[0.84089404]]),
#   array([[0.60484834]]),
#   array([[0.65174216]]),
#   array([[0.73621814]]),
#   array([[0.87697358]]),
#   array([[0.77179327]]),
#   array([[0.64870073]]),
#   array([[0.79348432]]),
#   array([[0.87816609]]),
#   array([[0.88168379]]),
#   array([[0.66602436]]),
#   array([[0.65222348]]),
#   array([[0.85203306]]),
#   array([[0.85203306]])],
#  [array([[0.73541807]]),
#   array([[0.65017945]]),
#   array([[0.8034484]]),
#   array([[0.63435295]]),
#   array([[0.64669155]]),
#   array([[0.75562711]]),
#   array([[0.77109994]]),
#   array([[0.81148316]]),
#   array([[0.75474735]]),
#   array([[0.79540491]]),
#   array([[0.70905552]]),
#   array([[0.7946587]]),
#   array([[0.77986313]]),
#   array([[0.73989209]]),
#   array([[0.76126006]]),
#   array([[0.75495484]]),
#   array([[0.81579515]]),
#   array([[0.65928369]]),
#   array([[0.72208562]]),
#   array([[0.81877344]]),
#   array([[0.6560356]]),
#   array([[0.72326236]]),
#   array([[0.78016677]]),
#   array([[0.77287359]]),
#   array([[0.72548228]]),
#   array([[0.69149225]]),
#   array([[0.77214252]]),
#   array([[0.59932809]]),
#   array([[0.75038617]]),
#   array([[0.71995217]]),
#   array([[0.70125876]]),
#   array([[0.66764134]]),
#   array([[0.72841894]]),
#   array([[0.77516524]]),
#   array([[0.80765143]]),
#   array([[0.63079651]]),
#   array([[0.82257727]]),
#   array([[0.76789076]]),
#   array([[0.78397875]]),
#   array([[0.78110229]]),
#   array([[0.46705302]]),
#   array([[0.7621521]]),
#   array([[0.7621521]])],
#  [array([[0.71118979]]),
#   array([[0.65061942]]),
#   array([[0.7268007]]),
#   array([[0.68270205]]),
#   array([[0.57824443]]),
#   array([[0.7721007]]),
#   array([[0.69833656]]),
#   array([[0.77847695]]),
#   array([[0.78920185]]),
#   array([[0.77175193]]),
#   array([[0.71730401]]),
#   array([[0.83123717]]),
#   array([[0.73513547]]),
#   array([[0.74259445]]),
#   array([[0.69198772]]),
#   array([[0.75495484]]),
#   array([[0.7631191]]),
#   array([[0.67568924]]),
#   array([[0.86293158]]),
#   array([[0.78527704]]),
#   array([[0.78135478]]),
#   array([[0.6958887]]),
#   array([[0.80169384]]),
#   array([[0.82020775]]),
#   array([[0.70424313]]),
#   array([[0.69676472]]),
#   array([[0.78930488]]),
#   array([[0.74777838]]),
#   array([[0.8603363]]),
#   array([[0.67722656]]),
#   array([[0.6785915]]),
#   array([[0.81984028]]),
#   array([[0.80465333]]),
#   array([[0.76924765]]),
#   array([[0.79594093]]),
#   array([[0.63828692]]),
#   array([[0.78270888]]),
#   array([[0.7572358]]),
#   array([[0.75016975]]),
#   array([[0.78080392]]),
#   array([[0.45743257]]),
#   array([[0.69408052]]),
#   array([[0.69408052]])],
#  [array([[0.81135899]]),
#   array([[0.67387691]]),
#   array([[0.80764815]]),
#   array([[0.72055271]]),
#   array([[0.72319211]]),
#   array([[0.74696065]]),
#   array([[0.89301399]]),
#   array([[0.79208481]]),
#   array([[0.83283206]]),
#   array([[0.8382746]]),
#   array([[0.79408178]]),
#   array([[0.75449571]]),
#   array([[0.8143568]]),
#   array([[0.82204876]]),
#   array([[0.86564777]]),
#   array([[0.81579515]]),
#   array([[0.7631191]]),
#   array([[0.64745256]]),
#   array([[0.73142729]]),
#   array([[0.91204162]]),
#   array([[0.67312916]]),
#   array([[0.79881004]]),
#   array([[0.80714552]]),
#   array([[0.79791674]]),
#   array([[0.84053039]]),
#   array([[0.76669388]]),
#   array([[0.85419187]]),
#   array([[0.5715614]]),
#   array([[0.7727907]]),
#   array([[0.78896445]]),
#   array([[0.69396733]]),
#   array([[0.69094105]]),
#   array([[0.74982947]]),
#   array([[0.88823659]]),
#   array([[0.84198819]]),
#   array([[0.58885644]]),
#   array([[0.8161146]]),
#   array([[0.88365018]]),
#   array([[0.89595272]]),
#   array([[0.72137317]]),
#   array([[0.51440419]]),
#   array([[0.85636573]]),
#   array([[0.85636573]])],
#  [array([[0.64664508]]),
#   array([[0.70205525]]),
#   array([[0.68050194]]),
#   array([[0.57271707]]),
#   array([[0.5666773]]),
#   array([[0.7310019]]),
#   array([[0.60790642]]),
#   array([[0.68185506]]),
#   array([[0.72200774]]),
#   array([[0.68983202]]),
#   array([[0.61892293]]),
#   array([[0.67764278]]),
#   array([[0.7059186]]),
#   array([[0.66416802]]),
#   array([[0.67353119]]),
#   array([[0.65928369]]),
#   array([[0.67568924]]),
#   array([[0.64745256]]),
#   array([[0.68923313]]),
#   array([[0.69806382]]),
#   array([[0.66454773]]),
#   array([[0.62243121]]),
#   array([[0.73284751]]),
#   array([[0.7366934]]),
#   array([[0.64140256]]),
#   array([[0.64518797]]),
#   array([[0.75026086]]),
#   array([[0.69615477]]),
#   array([[0.68837371]]),
#   array([[0.65119701]]),
#   array([[0.69141896]]),
#   array([[0.61853495]]),
#   array([[0.65053605]]),
#   array([[0.64027427]]),
#   array([[0.67399908]]),
#   array([[0.72418181]]),
#   array([[0.70019558]]),
#   array([[0.64261564]]),
#   array([[0.70010235]]),
#   array([[0.6929799]]),
#   array([[0.48473107]]),
#   array([[0.61718071]]),
#   array([[0.61718071]])],
#  [array([[0.70092177]]),
#   array([[0.70985495]]),
#   array([[0.76114324]]),
#   array([[0.65530339]]),
#   array([[0.56521354]]),
#   array([[0.79545365]]),
#   array([[0.67982608]]),
#   array([[0.78789616]]),
#   array([[0.77000652]]),
#   array([[0.74458607]]),
#   array([[0.69246245]]),
#   array([[0.80692074]]),
#   array([[0.72333379]]),
#   array([[0.71209038]]),
#   array([[0.66525888]]),
#   array([[0.72208562]]),
#   array([[0.86293158]]),
#   array([[0.73142729]]),
#   array([[0.68923313]]),
#   array([[0.76126465]]),
#   array([[0.77156664]]),
#   array([[0.68680775]]),
#   array([[0.78972491]]),
#   array([[0.80284657]]),
#   array([[0.71634209]]),
#   array([[0.68099631]]),
#   array([[0.78185259]]),
#   array([[0.77532579]]),
#   array([[0.79609504]]),
#   array([[0.67712909]]),
#   array([[0.68401673]]),
#   array([[0.79087575]]),
#   array([[0.81593468]]),
#   array([[0.74838248]]),
#   array([[0.80786145]]),
#   array([[0.69312502]]),
#   array([[0.79596469]]),
#   array([[0.73802897]]),
#   array([[0.73433227]]),
#   array([[0.81660531]]),
#   array([[0.43507933]]),
#   array([[0.68591905]]),
#   array([[0.68591905]])],
#  [array([[0.84696347]]),
#   array([[0.71796925]]),
#   array([[0.81990727]]),
#   array([[0.71663996]]),
#   array([[0.72470054]]),
#   array([[0.78640184]]),
#   array([[0.85665312]]),
#   array([[0.8038199]]),
#   array([[0.81255497]]),
#   array([[0.848564]]),
#   array([[0.80636247]]),
#   array([[0.76361411]]),
#   array([[0.83755933]]),
#   array([[0.83603101]]),
#   array([[0.87253282]]),
#   array([[0.81877344]]),
#   array([[0.78527704]]),
#   array([[0.91204162]]),
#   array([[0.69806382]]),
#   array([[0.76126465]]),
#   array([[0.73046805]]),
#   array([[0.8112196]]),
#   array([[0.84996683]]),
#   array([[0.81775593]]),
#   array([[0.8657342]]),
#   array([[0.79131816]]),
#   array([[0.85770469]]),
#   array([[0.64347477]]),
#   array([[0.77827978]]),
#   array([[0.82222449]]),
#   array([[0.7062466]]),
#   array([[0.71780544]]),
#   array([[0.7537079]]),
#   array([[0.86844693]]),
#   array([[0.81206476]]),
#   array([[0.66453723]]),
#   array([[0.80111872]]),
#   array([[0.89162348]]),
#   array([[0.87813723]]),
#   array([[0.76923811]]),
#   array([[0.57857927]]),
#   array([[0.83360416]]),
#   array([[0.83360416]])],
#  [array([[0.65197291]]),
#   array([[0.65804938]]),
#   array([[0.71909187]]),
#   array([[0.57223925]]),
#   array([[0.54882836]]),
#   array([[0.76086674]]),
#   array([[0.63681188]]),
#   array([[0.73497412]]),
#   array([[0.71128372]]),
#   array([[0.65162631]]),
#   array([[0.65222582]]),
#   array([[0.73037617]]),
#   array([[0.67865426]]),
#   array([[0.64964328]]),
#   array([[0.60225179]]),
#   array([[0.6560356]]),
#   array([[0.78135478]]),
#   array([[0.67312916]]),
#   array([[0.66454773]]),
#   array([[0.77156664]]),
#   array([[0.73046805]]),
#   array([[0.64346146]]),
#   array([[0.73147251]]),
#   array([[0.79032629]]),
#   array([[0.6611313]]),
#   array([[0.68833788]]),
#   array([[0.69403389]]),
#   array([[0.74371874]]),
#   array([[0.72572306]]),
#   array([[0.67409719]]),
#   array([[0.69092428]]),
#   array([[0.73066873]]),
#   array([[0.66001604]]),
#   array([[0.68176743]]),
#   array([[0.66699133]]),
#   array([[0.65752789]]),
#   array([[0.6857788]]),
#   array([[0.64535021]]),
#   array([[0.68538208]]),
#   array([[0.73520234]]),
#   array([[0.42509408]]),
#   array([[0.60001731]]),
#   array([[0.60001731]])],
#  [array([[0.81843312]]),
#   array([[0.65363119]]),
#   array([[0.69358081]]),
#   array([[0.70422521]]),
#   array([[0.7690905]]),
#   array([[0.67865194]]),
#   array([[0.78751852]]),
#   array([[0.7075153]]),
#   array([[0.76623113]]),
#   array([[0.78281565]]),
#   array([[0.70065831]]),
#   array([[0.68035631]]),
#   array([[0.70647235]]),
#   array([[0.83435859]]),
#   array([[0.81559754]]),
#   array([[0.72326236]]),
#   array([[0.6958887]]),
#   array([[0.79881004]]),
#   array([[0.62243121]]),
#   array([[0.68680775]]),
#   array([[0.8112196]]),
#   array([[0.64346146]]),
#   array([[0.76554031]]),
#   array([[0.72231462]]),
#   array([[0.76784379]]),
#   array([[0.75822794]]),
#   array([[0.79008654]]),
#   array([[0.52937413]]),
#   array([[0.73920836]]),
#   array([[0.78526231]]),
#   array([[0.5662755]]),
#   array([[0.67279144]]),
#   array([[0.74409559]]),
#   array([[0.81445578]]),
#   array([[0.77982898]]),
#   array([[0.60196024]]),
#   array([[0.75447571]]),
#   array([[0.77769344]]),
#   array([[0.82003948]]),
#   array([[0.65805958]]),
#   array([[0.561702]]),
#   array([[0.82211601]]),
#   array([[0.82211601]])],
#  [array([[0.7779822]]),
#   array([[0.71704651]]),
#   array([[0.77566751]]),
#   array([[0.70237927]]),
#   array([[0.6780326]]),
#   array([[0.77375762]]),
#   array([[0.77766663]]),
#   array([[0.78497837]]),
#   array([[0.78592281]]),
#   array([[0.82021097]]),
#   array([[0.74473784]]),
#   array([[0.78815723]]),
#   array([[0.83666999]]),
#   array([[0.79714841]]),
#   array([[0.79229508]]),
#   array([[0.78016677]]),
#   array([[0.80169384]]),
#   array([[0.80714552]]),
#   array([[0.73284751]]),
#   array([[0.78972491]]),
#   array([[0.84996683]]),
#   array([[0.73147251]]),
#   array([[0.76554031]]),
#   array([[0.785486]]),
#   array([[0.78098346]]),
#   array([[0.73894945]]),
#   array([[0.79700941]]),
#   array([[0.72307154]]),
#   array([[0.79287731]]),
#   array([[0.76119077]]),
#   array([[0.69922783]]),
#   array([[0.73932767]]),
#   array([[0.80499225]]),
#   array([[0.80028539]]),
#   array([[0.79809833]]),
#   array([[0.73215314]]),
#   array([[0.81482794]]),
#   array([[0.79766204]]),
#   array([[0.81032836]]),
#   array([[0.78458715]]),
#   array([[0.56838423]]),
#   array([[0.7848264]]),
#   array([[0.7848264]])],
#  [array([[0.73049599]]),
#   array([[0.72987158]]),
#   array([[0.75648859]]),
#   array([[0.64246026]]),
#   array([[0.65714492]]),
#   array([[0.80102237]]),
#   array([[0.7519923]]),
#   array([[0.79511054]]),
#   array([[0.80750756]]),
#   array([[0.77813718]]),
#   array([[0.73876402]]),
#   array([[0.78805508]]),
#   array([[0.73432681]]),
#   array([[0.76706634]]),
#   array([[0.74243234]]),
#   array([[0.77287359]]),
#   array([[0.82020775]]),
#   array([[0.79791674]]),
#   array([[0.7366934]]),
#   array([[0.80284657]]),
#   array([[0.81775593]]),
#   array([[0.79032629]]),
#   array([[0.72231462]]),
#   array([[0.785486]]),
#   array([[0.74943085]]),
#   array([[0.7608644]]),
#   array([[0.7929916]]),
#   array([[0.70868558]]),
#   array([[0.83010602]]),
#   array([[0.74870045]]),
#   array([[0.69493865]]),
#   array([[0.72479684]]),
#   array([[0.74465712]]),
#   array([[0.79696032]]),
#   array([[0.79747208]]),
#   array([[0.68269018]]),
#   array([[0.80308806]]),
#   array([[0.74043753]]),
#   array([[0.79375364]]),
#   array([[0.77602104]]),
#   array([[0.47528159]]),
#   array([[0.73197026]]),
#   array([[0.73197026]])],
#  [array([[0.78577445]]),
#   array([[0.71236097]]),
#   array([[0.78955813]]),
#   array([[0.68316713]]),
#   array([[0.78093465]]),
#   array([[0.72012629]]),
#   array([[0.87197529]]),
#   array([[0.68646425]]),
#   array([[0.7629659]]),
#   array([[0.77434977]]),
#   array([[0.78071921]]),
#   array([[0.70521688]]),
#   array([[0.79805643]]),
#   array([[0.80411014]]),
#   array([[0.79538996]]),
#   array([[0.72548228]]),
#   array([[0.70424313]]),
#   array([[0.84053039]]),
#   array([[0.64140256]]),
#   array([[0.71634209]]),
#   array([[0.8657342]]),
#   array([[0.6611313]]),
#   array([[0.76784379]]),
#   array([[0.78098346]]),
#   array([[0.74943085]]),
#   array([[0.72151611]]),
#   array([[0.7829079]]),
#   array([[0.57103863]]),
#   array([[0.7116466]]),
#   array([[0.78422881]]),
#   array([[0.66153816]]),
#   array([[0.62692392]]),
#   array([[0.71879084]]),
#   array([[0.80788012]]),
#   array([[0.78087973]]),
#   array([[0.70101644]]),
#   array([[0.73047468]]),
#   array([[0.81261159]]),
#   array([[0.86609072]]),
#   array([[0.71846565]]),
#   array([[0.48639759]]),
#   array([[0.82216382]]),
#   array([[0.82216382]])],
#  [array([[0.74854324]]),
#   array([[0.66988137]]),
#   array([[0.70005545]]),
#   array([[0.63001939]]),
#   array([[0.69484328]]),
#   array([[0.73032944]]),
#   array([[0.74722356]]),
#   array([[0.73193282]]),
#   array([[0.73029864]]),
#   array([[0.7530781]]),
#   array([[0.69130083]]),
#   array([[0.68601147]]),
#   array([[0.68156565]]),
#   array([[0.76784871]]),
#   array([[0.76653509]]),
#   array([[0.69149225]]),
#   array([[0.69676472]]),
#   array([[0.76669388]]),
#   array([[0.64518797]]),
#   array([[0.68099631]]),
#   array([[0.79131816]]),
#   array([[0.68833788]]),
#   array([[0.75822794]]),
#   array([[0.73894945]]),
#   array([[0.7608644]]),
#   array([[0.72151611]]),
#   array([[0.75724209]]),
#   array([[0.61767208]]),
#   array([[0.71090246]]),
#   array([[0.75494896]]),
#   array([[0.6074896]]),
#   array([[0.66668286]]),
#   array([[0.71214056]]),
#   array([[0.7779528]]),
#   array([[0.73057371]]),
#   array([[0.63560647]]),
#   array([[0.74041301]]),
#   array([[0.77564842]]),
#   array([[0.7815269]]),
#   array([[0.71556538]]),
#   array([[0.60547497]]),
#   array([[0.76397722]]),
#   array([[0.76397722]])],
#  [array([[0.81482561]]),
#   array([[0.7088409]]),
#   array([[0.79769605]]),
#   array([[0.72116271]]),
#   array([[0.6941829]]),
#   array([[0.79262076]]),
#   array([[0.81247463]]),
#   array([[0.76930936]]),
#   array([[0.83181744]]),
#   array([[0.82747122]]),
#   array([[0.75385299]]),
#   array([[0.78053656]]),
#   array([[0.81159558]]),
#   array([[0.82132465]]),
#   array([[0.84114514]]),
#   array([[0.77214252]]),
#   array([[0.78930488]]),
#   array([[0.85419187]]),
#   array([[0.75026086]]),
#   array([[0.78185259]]),
#   array([[0.85770469]]),
#   array([[0.69403389]]),
#   array([[0.79008654]]),
#   array([[0.79700941]]),
#   array([[0.7929916]]),
#   array([[0.7829079]]),
#   array([[0.75724209]]),
#   array([[0.67567336]]),
#   array([[0.80640243]]),
#   array([[0.78076669]]),
#   array([[0.70027915]]),
#   array([[0.72307306]]),
#   array([[0.78288502]]),
#   array([[0.84831233]]),
#   array([[0.82145633]]),
#   array([[0.68741492]]),
#   array([[0.81847063]]),
#   array([[0.83316917]]),
#   array([[0.83922899]]),
#   array([[0.75732936]]),
#   array([[0.55562168]]),
#   array([[0.81074133]]),
#   array([[0.81074133]])],
#  [array([[0.60668862]]),
#   array([[0.6176531]]),
#   array([[0.69399584]]),
#   array([[0.4978086]]),
#   array([[0.45268779]]),
#   array([[0.80809137]]),
#   array([[0.54364336]]),
#   array([[0.74223662]]),
#   array([[0.59273862]]),
#   array([[0.64615692]]),
#   array([[0.58317179]]),
#   array([[0.75793198]]),
#   array([[0.7145457]]),
#   array([[0.59482788]]),
#   array([[0.53829048]]),
#   array([[0.59932809]]),
#   array([[0.74777838]]),
#   array([[0.5715614]]),
#   array([[0.69615477]]),
#   array([[0.77532579]]),
#   array([[0.64347477]]),
#   array([[0.74371874]]),
#   array([[0.52937413]]),
#   array([[0.72307154]]),
#   array([[0.70868558]]),
#   array([[0.57103863]]),
#   array([[0.61767208]]),
#   array([[0.67567336]]),
#   array([[0.72479573]]),
#   array([[0.56918798]]),
#   array([[0.68153554]]),
#   array([[0.70123163]]),
#   array([[0.6983843]]),
#   array([[0.57475067]]),
#   array([[0.60627428]]),
#   array([[0.70746303]]),
#   array([[0.66358443]]),
#   array([[0.58582297]]),
#   array([[0.55081678]]),
#   array([[0.72694304]]),
#   array([[0.43317904]]),
#   array([[0.51753675]]),
#   array([[0.51753675]])],
#  [array([[0.7508488]]),
#   array([[0.65305782]]),
#   array([[0.76322999]]),
#   array([[0.64299094]]),
#   array([[0.63657411]]),
#   array([[0.75045847]]),
#   array([[0.75716566]]),
#   array([[0.76785183]]),
#   array([[0.76376683]]),
#   array([[0.83508376]]),
#   array([[0.71941241]]),
#   array([[0.7923291]]),
#   array([[0.73974982]]),
#   array([[0.77899802]]),
#   array([[0.72178276]]),
#   array([[0.75038617]]),
#   array([[0.8603363]]),
#   array([[0.7727907]]),
#   array([[0.68837371]]),
#   array([[0.79609504]]),
#   array([[0.77827978]]),
#   array([[0.72572306]]),
#   array([[0.73920836]]),
#   array([[0.79287731]]),
#   array([[0.83010602]]),
#   array([[0.7116466]]),
#   array([[0.71090246]]),
#   array([[0.80640243]]),
#   array([[0.72479573]]),
#   array([[0.70567021]]),
#   array([[0.66775188]]),
#   array([[0.78903343]]),
#   array([[0.79968101]]),
#   array([[0.79236165]]),
#   array([[0.78767367]]),
#   array([[0.61245172]]),
#   array([[0.82565041]]),
#   array([[0.72929595]]),
#   array([[0.74326582]]),
#   array([[0.7496242]]),
#   array([[0.4433451]]),
#   array([[0.76223615]]),
#   array([[0.76223615]])],
#  [array([[0.84334356]]),
#   array([[0.71737129]]),
#   array([[0.7090969]]),
#   array([[0.68855052]]),
#   array([[0.76170016]]),
#   array([[0.72131543]]),
#   array([[0.80978144]]),
#   array([[0.69632085]]),
#   array([[0.78457247]]),
#   array([[0.77951468]]),
#   array([[0.76265149]]),
#   array([[0.69465511]]),
#   array([[0.74229618]]),
#   array([[0.82234863]]),
#   array([[0.84089404]]),
#   array([[0.71995217]]),
#   array([[0.67722656]]),
#   array([[0.78896445]]),
#   array([[0.65119701]]),
#   array([[0.67712909]]),
#   array([[0.82222449]]),
#   array([[0.67409719]]),
#   array([[0.78526231]]),
#   array([[0.76119077]]),
#   array([[0.74870045]]),
#   array([[0.78422881]]),
#   array([[0.75494896]]),
#   array([[0.78076669]]),
#   array([[0.56918798]]),
#   array([[0.70567021]]),
#   array([[0.63626266]]),
#   array([[0.65886516]]),
#   array([[0.70693434]]),
#   array([[0.82270531]]),
#   array([[0.71770931]]),
#   array([[0.67167427]]),
#   array([[0.76205129]]),
#   array([[0.79802835]]),
#   array([[0.81376761]]),
#   array([[0.65878842]]),
#   array([[0.59889187]]),
#   array([[0.76749934]]),
#   array([[0.76749934]])],
#  [array([[0.60442462]]),
#   array([[0.64205702]]),
#   array([[0.73562325]]),
#   array([[0.53264366]]),
#   array([[0.53321141]]),
#   array([[0.72022803]]),
#   array([[0.6531548]]),
#   array([[0.70481403]]),
#   array([[0.63332311]]),
#   array([[0.6790878]]),
#   array([[0.61826537]]),
#   array([[0.69463965]]),
#   array([[0.74921224]]),
#   array([[0.59446352]]),
#   array([[0.60484834]]),
#   array([[0.70125876]]),
#   array([[0.6785915]]),
#   array([[0.69396733]]),
#   array([[0.69141896]]),
#   array([[0.68401673]]),
#   array([[0.7062466]]),
#   array([[0.69092428]]),
#   array([[0.5662755]]),
#   array([[0.69922783]]),
#   array([[0.69493865]]),
#   array([[0.66153816]]),
#   array([[0.6074896]]),
#   array([[0.70027915]]),
#   array([[0.68153554]]),
#   array([[0.66775188]]),
#   array([[0.63626266]]),
#   array([[0.59550817]]),
#   array([[0.65053579]]),
#   array([[0.64743873]]),
#   array([[0.64555807]]),
#   array([[0.65332068]]),
#   array([[0.66948094]]),
#   array([[0.64183542]]),
#   array([[0.67057929]]),
#   array([[0.71627897]]),
#   array([[0.4221718]]),
#   array([[0.59047102]]),
#   array([[0.59047102]])],
#  [array([[0.70436354]]),
#   array([[0.62566022]]),
#   array([[0.66247771]]),
#   array([[0.5999913]]),
#   array([[0.51496576]]),
#   array([[0.70821144]]),
#   array([[0.63167522]]),
#   array([[0.72712966]]),
#   array([[0.71214652]]),
#   array([[0.73763343]]),
#   array([[0.66154336]]),
#   array([[0.7475202]]),
#   array([[0.6401175]]),
#   array([[0.69596394]]),
#   array([[0.65174216]]),
#   array([[0.66764134]]),
#   array([[0.81984028]]),
#   array([[0.69094105]]),
#   array([[0.61853495]]),
#   array([[0.79087575]]),
#   array([[0.71780544]]),
#   array([[0.73066873]]),
#   array([[0.67279144]]),
#   array([[0.73932767]]),
#   array([[0.72479684]]),
#   array([[0.62692392]]),
#   array([[0.66668286]]),
#   array([[0.72307306]]),
#   array([[0.70123163]]),
#   array([[0.78903343]]),
#   array([[0.65886516]]),
#   array([[0.59550817]]),
#   array([[0.77833367]]),
#   array([[0.68408784]]),
#   array([[0.72703986]]),
#   array([[0.58859098]]),
#   array([[0.73215192]]),
#   array([[0.67506957]]),
#   array([[0.68114154]]),
#   array([[0.6818465]]),
#   array([[0.43419357]]),
#   array([[0.6292828]]),
#   array([[0.6292828]])],
#  [array([[0.73789919]]),
#   array([[0.65904407]]),
#   array([[0.70647421]]),
#   array([[0.72539095]]),
#   array([[0.65082561]]),
#   array([[0.73152265]]),
#   array([[0.7420491]]),
#   array([[0.77259755]]),
#   array([[0.77307681]]),
#   array([[0.78515981]]),
#   array([[0.68962178]]),
#   array([[0.80526134]]),
#   array([[0.73378076]]),
#   array([[0.77055657]]),
#   array([[0.73621814]]),
#   array([[0.72841894]]),
#   array([[0.80465333]]),
#   array([[0.74982947]]),
#   array([[0.65053605]]),
#   array([[0.81593468]]),
#   array([[0.7537079]]),
#   array([[0.66001604]]),
#   array([[0.74409559]]),
#   array([[0.80499225]]),
#   array([[0.74465712]]),
#   array([[0.71879084]]),
#   array([[0.71214056]]),
#   array([[0.78288502]]),
#   array([[0.6983843]]),
#   array([[0.79968101]]),
#   array([[0.70693434]]),
#   array([[0.65053579]]),
#   array([[0.77833367]]),
#   array([[0.78549579]]),
#   array([[0.82417291]]),
#   array([[0.66810033]]),
#   array([[0.81848061]]),
#   array([[0.74482024]]),
#   array([[0.75381773]]),
#   array([[0.76510304]]),
#   array([[0.52602694]]),
#   array([[0.75238945]]),
#   array([[0.75238945]])],
#  [array([[0.84620825]]),
#   array([[0.68964363]]),
#   array([[0.73975667]]),
#   array([[0.80707189]]),
#   array([[0.78603759]]),
#   array([[0.72975001]]),
#   array([[0.88037507]]),
#   array([[0.75966923]]),
#   array([[0.88271595]]),
#   array([[0.81553114]]),
#   array([[0.79267803]]),
#   array([[0.74513534]]),
#   array([[0.78899649]]),
#   array([[0.87039368]]),
#   array([[0.87697358]]),
#   array([[0.77516524]]),
#   array([[0.76924765]]),
#   array([[0.88823659]]),
#   array([[0.64027427]]),
#   array([[0.74838248]]),
#   array([[0.86844693]]),
#   array([[0.68176743]]),
#   array([[0.81445578]]),
#   array([[0.80028539]]),
#   array([[0.79696032]]),
#   array([[0.80788012]]),
#   array([[0.7779528]]),
#   array([[0.84831233]]),
#   array([[0.57475067]]),
#   array([[0.79236165]]),
#   array([[0.82270531]]),
#   array([[0.64743873]]),
#   array([[0.68408784]]),
#   array([[0.78549579]]),
#   array([[0.81773875]]),
#   array([[0.62473457]]),
#   array([[0.82741181]]),
#   array([[0.87886867]]),
#   array([[0.88857483]]),
#   array([[0.71096741]]),
#   array([[0.59406862]]),
#   array([[0.85883818]]),
#   array([[0.85883818]])],
#  [array([[0.74976576]]),
#   array([[0.70538805]]),
#   array([[0.78686944]]),
#   array([[0.76894771]]),
#   array([[0.68607164]]),
#   array([[0.75274721]]),
#   array([[0.78189599]]),
#   array([[0.80227407]]),
#   array([[0.84085122]]),
#   array([[0.77994766]]),
#   array([[0.75236765]]),
#   array([[0.78530386]]),
#   array([[0.76791079]]),
#   array([[0.77430544]]),
#   array([[0.77179327]]),
#   array([[0.80765143]]),
#   array([[0.79594093]]),
#   array([[0.84198819]]),
#   array([[0.67399908]]),
#   array([[0.80786145]]),
#   array([[0.81206476]]),
#   array([[0.66699133]]),
#   array([[0.77982898]]),
#   array([[0.79809833]]),
#   array([[0.79747208]]),
#   array([[0.78087973]]),
#   array([[0.73057371]]),
#   array([[0.82145633]]),
#   array([[0.60627428]]),
#   array([[0.78767367]]),
#   array([[0.71770931]]),
#   array([[0.64555807]]),
#   array([[0.72703986]]),
#   array([[0.82417291]]),
#   array([[0.81773875]]),
#   array([[0.65611296]]),
#   array([[0.84475337]]),
#   array([[0.79724405]]),
#   array([[0.83291051]]),
#   array([[0.79012031]]),
#   array([[0.46193926]]),
#   array([[0.78873543]]),
#   array([[0.78873543]])],
#  [array([[0.64572982]]),
#   array([[0.69729917]]),
#   array([[0.71053607]]),
#   array([[0.57649734]]),
#   array([[0.59719286]]),
#   array([[0.74016194]]),
#   array([[0.64157641]]),
#   array([[0.64806537]]),
#   array([[0.64852951]]),
#   array([[0.63547622]]),
#   array([[0.64672439]]),
#   array([[0.66292596]]),
#   array([[0.76197571]]),
#   array([[0.64784304]]),
#   array([[0.64870073]]),
#   array([[0.63079651]]),
#   array([[0.63828692]]),
#   array([[0.58885644]]),
#   array([[0.72418181]]),
#   array([[0.69312502]]),
#   array([[0.66453723]]),
#   array([[0.65752789]]),
#   array([[0.60196024]]),
#   array([[0.73215314]]),
#   array([[0.68269018]]),
#   array([[0.70101644]]),
#   array([[0.63560647]]),
#   array([[0.68741492]]),
#   array([[0.70746303]]),
#   array([[0.61245172]]),
#   array([[0.67167427]]),
#   array([[0.65332068]]),
#   array([[0.58859098]]),
#   array([[0.66810033]]),
#   array([[0.62473457]]),
#   array([[0.65611296]]),
#   array([[0.66635681]]),
#   array([[0.62964335]]),
#   array([[0.66710564]]),
#   array([[0.73006772]]),
#   array([[0.54805963]]),
#   array([[0.62217954]]),
#   array([[0.62217954]])],
#  [array([[0.78208251]]),
#   array([[0.7096145]]),
#   array([[0.75482972]]),
#   array([[0.72280824]]),
#   array([[0.67460042]]),
#   array([[0.77142306]]),
#   array([[0.77856158]]),
#   array([[0.82342878]]),
#   array([[0.80687198]]),
#   array([[0.81661432]]),
#   array([[0.75704903]]),
#   array([[0.82045274]]),
#   array([[0.77735625]]),
#   array([[0.77931482]]),
#   array([[0.79348432]]),
#   array([[0.82257727]]),
#   array([[0.78270888]]),
#   array([[0.8161146]]),
#   array([[0.70019558]]),
#   array([[0.79596469]]),
#   array([[0.80111872]]),
#   array([[0.6857788]]),
#   array([[0.75447571]]),
#   array([[0.81482794]]),
#   array([[0.80308806]]),
#   array([[0.73047468]]),
#   array([[0.74041301]]),
#   array([[0.81847063]]),
#   array([[0.66358443]]),
#   array([[0.82565041]]),
#   array([[0.76205129]]),
#   array([[0.66948094]]),
#   array([[0.73215192]]),
#   array([[0.81848061]]),
#   array([[0.82741181]]),
#   array([[0.84475337]]),
#   array([[0.66635681]]),
#   array([[0.81278162]]),
#   array([[0.80805091]]),
#   array([[0.79370895]]),
#   array([[0.4855817]]),
#   array([[0.79003201]]),
#   array([[0.79003201]])],
#  [array([[0.83940032]]),
#   array([[0.68708975]]),
#   array([[0.74648167]]),
#   array([[0.74904842]]),
#   array([[0.75042164]]),
#   array([[0.73982616]]),
#   array([[0.83937632]]),
#   array([[0.75955474]]),
#   array([[0.80632984]]),
#   array([[0.8264422]]),
#   array([[0.81236331]]),
#   array([[0.72539592]]),
#   array([[0.78226299]]),
#   array([[0.83559589]]),
#   array([[0.87816609]]),
#   array([[0.76789076]]),
#   array([[0.7572358]]),
#   array([[0.88365018]]),
#   array([[0.64261564]]),
#   array([[0.73802897]]),
#   array([[0.89162348]]),
#   array([[0.64535021]]),
#   array([[0.77769344]]),
#   array([[0.79766204]]),
#   array([[0.74043753]]),
#   array([[0.81261159]]),
#   array([[0.77564842]]),
#   array([[0.83316917]]),
#   array([[0.58582297]]),
#   array([[0.72929595]]),
#   array([[0.79802835]]),
#   array([[0.64183542]]),
#   array([[0.67506957]]),
#   array([[0.74482024]]),
#   array([[0.87886867]]),
#   array([[0.79724405]]),
#   array([[0.62964335]]),
#   array([[0.81278162]]),
#   array([[0.87224785]]),
#   array([[0.7631316]]),
#   array([[0.61726049]]),
#   array([[0.85917629]]),
#   array([[0.85917629]])],
#  [array([[0.80672969]]),
#   array([[0.74118572]]),
#   array([[0.76739374]]),
#   array([[0.78348129]]),
#   array([[0.7338111]]),
#   array([[0.8773009]]),
#   array([[0.73312727]]),
#   array([[0.86782048]]),
#   array([[0.81740146]]),
#   array([[0.795621]]),
#   array([[0.72659101]]),
#   array([[0.80281495]]),
#   array([[0.85448614]]),
#   array([[0.88168379]]),
#   array([[0.78397875]]),
#   array([[0.75016975]]),
#   array([[0.89595272]]),
#   array([[0.70010235]]),
#   array([[0.73433227]]),
#   array([[0.87813723]]),
#   array([[0.68538208]]),
#   array([[0.82003948]]),
#   array([[0.81032836]]),
#   array([[0.79375364]]),
#   array([[0.86609072]]),
#   array([[0.7815269]]),
#   array([[0.83922899]]),
#   array([[0.55081678]]),
#   array([[0.74326582]]),
#   array([[0.81376761]]),
#   array([[0.67057929]]),
#   array([[0.68114154]]),
#   array([[0.75381773]]),
#   array([[0.88857483]]),
#   array([[0.83291051]]),
#   array([[0.66710564]]),
#   array([[0.80805091]]),
#   array([[0.87224785]]),
#   array([[0.72932427]]),
#   array([[0.56307347]]),
#   array([[0.86369893]]),
#   array([[0.86369893]])],
#  [array([[0.68024306]]),
#   array([[0.67264167]]),
#   array([[0.78782313]]),
#   array([[0.59665577]]),
#   array([[0.58295917]]),
#   array([[0.79076279]]),
#   array([[0.68830378]]),
#   array([[0.80035496]]),
#   array([[0.72573214]]),
#   array([[0.73644298]]),
#   array([[0.7111171]]),
#   array([[0.7907677]]),
#   array([[0.72655379]]),
#   array([[0.70196628]]),
#   array([[0.66602436]]),
#   array([[0.78110229]]),
#   array([[0.78080392]]),
#   array([[0.72137317]]),
#   array([[0.6929799]]),
#   array([[0.81660531]]),
#   array([[0.76923811]]),
#   array([[0.73520234]]),
#   array([[0.65805958]]),
#   array([[0.78458715]]),
#   array([[0.77602104]]),
#   array([[0.71846565]]),
#   array([[0.71556538]]),
#   array([[0.75732936]]),
#   array([[0.72694304]]),
#   array([[0.7496242]]),
#   array([[0.65878842]]),
#   array([[0.71627897]]),
#   array([[0.6818465]]),
#   array([[0.76510304]]),
#   array([[0.71096741]]),
#   array([[0.79012031]]),
#   array([[0.73006772]]),
#   array([[0.79370895]]),
#   array([[0.7631316]]),
#   array([[0.72932427]]),
#   array([[0.47867091]]),
#   array([[0.72295102]]),
#   array([[0.72295102]])],
#  [array([[0.57901189]]),
#   array([[0.50987721]]),
#   array([[0.45227208]]),
#   array([[0.56549588]]),
#   array([[0.59679474]]),
#   array([[0.51497746]]),
#   array([[0.50189826]]),
#   array([[0.5031157]]),
#   array([[0.54317509]]),
#   array([[0.53930914]]),
#   array([[0.48175263]]),
#   array([[0.43189803]]),
#   array([[0.52168447]]),
#   array([[0.58414546]]),
#   array([[0.65222348]]),
#   array([[0.46705302]]),
#   array([[0.45743257]]),
#   array([[0.51440419]]),
#   array([[0.48473107]]),
#   array([[0.43507933]]),
#   array([[0.57857927]]),
#   array([[0.42509408]]),
#   array([[0.561702]]),
#   array([[0.56838423]]),
#   array([[0.47528159]]),
#   array([[0.48639759]]),
#   array([[0.60547497]]),
#   array([[0.55562168]]),
#   array([[0.43317904]]),
#   array([[0.4433451]]),
#   array([[0.59889187]]),
#   array([[0.4221718]]),
#   array([[0.43419357]]),
#   array([[0.52602694]]),
#   array([[0.59406862]]),
#   array([[0.46193926]]),
#   array([[0.54805963]]),
#   array([[0.4855817]]),
#   array([[0.61726049]]),
#   array([[0.56307347]]),
#   array([[0.47867091]]),
#   array([[0.56753967]]),
#   array([[0.56753967]])],
#  [array([[0.81875488]]),
#   array([[0.6442771]]),
#   array([[0.73793755]]),
#   array([[0.69344062]]),
#   array([[0.80639063]]),
#   array([[0.68967461]]),
#   array([[0.86561733]]),
#   array([[0.73254024]]),
#   array([[0.77314475]]),
#   array([[0.82896153]]),
#   array([[0.77966427]]),
#   array([[0.71500719]]),
#   array([[0.74286243]]),
#   array([[0.87269617]]),
#   array([[0.85203306]]),
#   array([[0.7621521]]),
#   array([[0.69408052]]),
#   array([[0.85636573]]),
#   array([[0.61718071]]),
#   array([[0.68591905]]),
#   array([[0.83360416]]),
#   array([[0.60001731]]),
#   array([[0.82211601]]),
#   array([[0.7848264]]),
#   array([[0.73197026]]),
#   array([[0.82216382]]),
#   array([[0.76397722]]),
#   array([[0.81074133]]),
#   array([[0.51753675]]),
#   array([[0.76223615]]),
#   array([[0.76749934]]),
#   array([[0.59047102]]),
#   array([[0.6292828]]),
#   array([[0.75238945]]),
#   array([[0.85883818]]),
#   array([[0.78873543]]),
#   array([[0.62217954]]),
#   array([[0.79003201]]),
#   array([[0.85917629]]),
#   array([[0.86369893]]),
#   array([[0.72295102]]),
#   array([[0.56753967]])],
#  [array([[0.81875488]]),
#   array([[0.6442771]]),
#   array([[0.73793755]]),
#   array([[0.69344062]]),
#   array([[0.80639063]]),
#   array([[0.68967461]]),
#   array([[0.86561733]]),
#   array([[0.73254024]]),
#   array([[0.77314475]]),
#   array([[0.82896153]]),
#   array([[0.77966427]]),
#   array([[0.71500719]]),
#   array([[0.74286243]]),
#   array([[0.87269617]]),
#   array([[0.85203306]]),
#   array([[0.7621521]]),
#   array([[0.69408052]]),
#   array([[0.85636573]]),
#   array([[0.61718071]]),
#   array([[0.68591905]]),
#   array([[0.83360416]]),
#   array([[0.60001731]]),
#   array([[0.82211601]]),
#   array([[0.7848264]]),
#   array([[0.73197026]]),
#   array([[0.82216382]]),
#   array([[0.76397722]]),
#   array([[0.81074133]]),
#   array([[0.51753675]]),
#   array([[0.76223615]]),
#   array([[0.76749934]]),
#   array([[0.59047102]]),
#   array([[0.6292828]]),
#   array([[0.75238945]]),
#   array([[0.85883818]]),
#   array([[0.78873543]]),
#   array([[0.62217954]]),
#   array([[0.79003201]]),
#   array([[0.85917629]]),
#   array([[0.86369893]]),
#   array([[0.72295102]]),
#   array([[0.56753967]])]]

# %%
len(cosines[0])
# Out:
# 43

# %%
np.argmin(cosines[0])
np.argmax(cosines[0])
#cosines[0].index(np.array(0.05218427))
cosines[0][1][0][0]
# Out:
# 0.7280332383269781

# %%
def column_organization_to_validation(list_text):
    final_list=[]
    for i in range(0,len(list_text)):
        temp=[]
        for j in range(0,len(list_text[i])):
            temp.append(list_text[i][j][0][0])
        final_list.append(temp)
    return(final_list)

# %%
final_cosines = column_organization_to_validation(cosines)

# %%
sorted(final_cosines[2])
# Out:
# [0.45227208297405935,
#  0.5802538595630533,
#  0.6371996145087332,
#  0.6624777101520625,
#  0.6757690400581784,
#  0.6805019423211722,
#  0.6935808088344291,
#  0.6939958366209682,
#  0.7000554548940222,
#  0.7064742095230332,
#  0.7081598591284082,
#  0.7090969039686411,
#  0.7105360741108706,
#  0.7108402028441352,
#  0.712414664568505,
#  0.7142154791525823,
#  0.7190918672357104,
#  0.726800696675618,
#  0.7280332383269781,
#  0.7356232499906519,
#  0.7379375496736026,
#  0.7379375496736026,
#  0.7397566681701415,
#  0.7464816678123041,
#  0.7548297216315121,
#  0.7563010059740883,
#  0.7564885947623876,
#  0.7611432382481054,
#  0.7626813722115378,
#  0.7632299861567455,
#  0.775072024836407,
#  0.775667509108605,
#  0.7783548213680684,
#  0.7868694386770054,
#  0.7878231321844543,
#  0.7883806378205411,
#  0.789558125692486,
#  0.7976960506415952,
#  0.8034483994189376,
#  0.807648151331054,
#  0.8199072657534597,
#  0.8322362022293913]

# %%
a=sorted(final_cosines[0])
a[0]
a.index(a[0])
# Out:
# 0

# %%
def data_validation_classification(cosines,tweets):
    total=[]
    for i in range(0,len(cosines)):
        #print(i)
        temp=[]
        organized=sorted(cosines[i])
        min1=organized[0]
        min2=organized[1]
        max1=organized[len(organized)-1]
        pos_min_1=cosines[i].index(min1)
        pos_min_2=cosines[i].index(min2)
        pos_max_1=cosines[i].index(max1)
        temp.append(tweets[i])
        if pos_max_1>=i:
            temp.append(tweets[(pos_max_1+1)])
        else:
            temp.append(tweets[pos_max_1])
        if pos_min_1>=i:
            temp.append(tweets[(pos_min_1+1)])
        else:
            temp.append(tweets[pos_min_1])
        if pos_min_2>=i:
            temp.append(tweets[(pos_min_2+1)])
        else:
            temp.append(tweets[pos_min_2])
        total.append(temp)
    return(total)

# %%
u=data_validation_classification(final_cosines, test_tweets)

# %%
import xlsxwriter as ws

# %%
workbook = ws.Workbook('validation.csv') 
worksheet = workbook.add_worksheet()

# %%
row=0
for i in range(0,len(u)):
    worksheet.write(row, 0, u[i][0])
    worksheet.write(row, 1, u[i][1]) 
    worksheet.write(row, 2, u[i][2]) 
    worksheet.write(row, 3, u[i][3])
    row+=1
workbook.close()

# %% [markdown]
# ### First solution: pre-trained embeddings
# We will work with predefined train and validation:
#
# - train corpus contains similar sentences at the same row.
# - validation corpus contains the following columns: tweet, similar tweet, negative example 1, negative example 2.

# %%
def read_corpus(filename):
    data = []
    for line in open(filename, encoding='utf-8'):
        data.append(line.strip().split(','))
    return data

# %%
validation = read_corpus('validation.csv')

# %%
print(validation)
# Out:
# [['\ufefffor the company and investment is that you and your family can eat and enjoy the means for you parasites to live because a pawned shovel works easier than a single mamertos of you to move and something for this country lives from kidnapping cap extortion and they camouflage themselves as leaders;Well', ' to live in Colombia and have a life you have already seen very little in what your country refers to', ' it is easy to talk shit when you do not touch or do not suffer the consequences of corruption and war. nothing;claaaaro are you happy with the invasion of cuba russia china iran eln farc terrorism shit like you etc etc;what was missing from that putrefaction of a terrorism support agency'], ['this man seems to only read the news headline both uruguay mexico colombia and chile has been applying distance education many years ago here a genocide supported the chicha press and killed university students a suicide kidnapped teachers and thus hypocritical;the farc are still alive only that its dome is no longer in the bush it is in the rest congress all the same extortion catatumbo nariño cauca etc selective murders kidnappings arms and drug trafficking links to cartels child recruitment support from vzla;claaaaro are you happy with the invasion of cuba russia china iran eln farc terrorism shit like you etc etc;honorable dr abelardodelaesprilla thank you very much for helping to save colombia let me congratulate you you are a fearless front person to sing the table in front of terrorism my appreciation and admiration for your good job as a lawyer a happy hug late'], ['the accomplice of santrich in colombia enjoys the full support of the magistrates legally it could be said that there is complicity with terrorism;that this sinister character does have to make intelligence because he was born without it or if he has it', ' he uses it to justify evil and be complicit in drug trafficking and terrorism in Colombia;With the appointment of the general faecal to end the judiciary and now with the military and police armed support', ' Spain has a Chavista dictatorship', ' all that remains is to give arms to the podemite and Psoevite paramilitary groups to be the perfect tyranny;because Colombia supported the Korean war', ' maybe they remember and send us a bombshell'], ['because Colombia supported the Korean war', ' maybe they remember and send us a bombshell;hey bangtan has to know about ColombiaColombia because at school they should have been taught in history that Colombia was the only Latin country that sent soldiers to support South Korea in the war against North Korea we owe many bangtan we deserve more face_with_steam_from_nose;militias from the urban front manuel cepeda vargas reorganizes the support networks for terrorism of the farc in the valle del cauca controls drug trafficking extortion illegal mining plans terrorist attacks against the population and the public force;what was missing from that putrefaction of a terrorism support agency'], ['honorable dr abelardodelaesprilla thank you very much for helping to save colombia let me congratulate you you are a fearless front person to sing the table in front of terrorism my appreciation and admiration for your good job as a lawyer a happy hug late;It would be perfect because the virus would help to end the farc', ' but his father did not make him want to leave a country in peace. Peace does not work. Uribistas need conflict', ' war', ' death', " and his father's traitor took it from us. Now we have to invent another", ' thank you. to farcsantos;militias from the urban front manuel cepeda vargas reorganizes the support networks for terrorism of the farc in the valle del cauca controls drug trafficking extortion illegal mining plans terrorist attacks against the population and the public force;The Colombia agro produce program financed projects of large entrepreneurs in 94 and only 2 for peasants facing internal war because', ' due to pressure from ranchers', ' they inten ...

# %%
def rank_candidates(tweet, candidates, embeddings, dim=300):


    t_vecs = np.array([tweets_to_vec(tweet, embeddings, dim) for i in range(len(candidates))])
    cand_vecs = np.array([tweets_to_vec(candidate, embeddings, dim) for candidate in candidates])
    cosines = np.array(cosine_similarity(t_vecs, cand_vecs)[0])
    merged_list = list(zip(cosines, range(len(candidates)), candidates))
    #print(merged_list)
    sorted_list  = sorted(merged_list, key=lambda x: x[0], reverse=True)
    result = [(b,c) for a,b,c in sorted_list]
    
    return result

# %%
wv_ranking = []
for line in validation:
    for l in line:
        t, *ex = l
        ranks = rank_candidates(t, ex, wv_embeddings)
        wv_ranking.append([r[0] for r in ranks].index(0) + 1)

# %%
for k in [1, 5, 10, 100, 500, 1000]:
    print("DCG@%4d: %.3f | Hits@%4d: %.3f" % (k, dcg_score(wv_ranking, k), k, hits_count(wv_ranking, k)))
# Out:
# DCG@   1: 0.764 | Hits@   1: 0.764
# DCG@   5: 0.780 | Hits@   5: 0.798
# DCG@  10: 0.782 | Hits@  10: 0.803
# DCG@ 100: 0.806 | Hits@ 100: 0.921
# DCG@ 500: 0.814 | Hits@ 500: 0.983
# DCG@1000: 0.816 | Hits@1000: 1.000

# %%
from util import text_prepare

# %%
prepared_validation = []
for line in validation:
    for l in line:
        prepared_validation.append([text_prepare(sentence) for sentence in l])

# %%
wv_prepared_ranking = []
for line in prepared_validation:
    q, *ex = line
    ranks = rank_candidates(q, ex, wv_embeddings)
    wv_prepared_ranking.append([r[0] for r in ranks].index(0) + 1)

# %%
for k in [1, 5, 10, 100, 500, 1000]:
    print("DCG@%4d: %.3f | Hits@%4d: %.3f" % (k, dcg_score(wv_prepared_ranking, k), 
                                              k, hits_count(wv_prepared_ranking, k)))
# Out:
# DCG@   1: 0.865 | Hits@   1: 0.865
# DCG@   5: 0.879 | Hits@   5: 0.893
# DCG@  10: 0.879 | Hits@  10: 0.893
# DCG@ 100: 0.891 | Hits@ 100: 0.955
# DCG@ 500: 0.897 | Hits@ 500: 1.000
# DCG@1000: 0.897 | Hits@1000: 1.000
