# %% [markdown]
# # Detecting cybercrimes using similarity models

# %% [markdown]
# ## OS

# %%
# !pip install transformers[sentencepiece]
# !pip install emoji
# !pip install xlsxwriter
# !pip install gensim
# !pip install pandas
# !pip install openpyxl
# Out:
# Requirement already satisfied: transformers[sentencepiece] in /home/daniel/.local/lib/python3.8/site-packages (4.20.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers[sentencepiece]) (5.3.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (0.12.1)
# Requirement already satisfied: tqdm>=4.27 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (2022.7.9)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (0.8.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers[sentencepiece]) (2.22.0)
# Requirement already satisfied: numpy>=1.17 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (1.23.1)
# Requirement already satisfied: filelock in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (3.7.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91; extra == "sentencepiece" in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (0.1.96)
# Requirement already satisfied: protobuf<=3.20.1; extra == "sentencepiece" in /usr/lib/python3/dist-packages (from transformers[sentencepiece]) (3.6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/daniel/.local/lib/python3.8/site-packages (from packaging>=20.0->transformers[sentencepiece]) (3.0.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/daniel/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers[sentencepiece]) (4.3.0)
# Requirement already satisfied: emoji in /home/daniel/.local/lib/python3.8/site-packages (1.7.0)
# Requirement already satisfied: xlsxwriter in /home/daniel/.local/lib/python3.8/site-packages (3.0.3)
# Requirement already satisfied: gensim in /home/daniel/.local/lib/python3.8/site-packages (4.2.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/daniel/.local/lib/python3.8/site-packages (from gensim) (1.23.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/daniel/.local/lib/python3.8/site-packages (from gensim) (6.0.0)
# Requirement already satisfied: scipy>=0.18.1 in /home/daniel/.local/lib/python3.8/site-packages (from gensim) (1.8.1)
# Requirement already satisfied: pandas in /home/daniel/.local/lib/python3.8/site-packages (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in /home/daniel/.local/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /home/daniel/.local/lib/python3.8/site-packages (from pandas) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/daniel/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.14.0)
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 686 kB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %%
import os # The OS module in Python provides a way of using operating system dependent functionality
import pandas as pd # Read data from file

# %%
 # Reads and shows files in entered location
#os.chdir("C:/My_Path/NLP-Model-for-prevention-of-Cybercrimes/Proyecto/")
os.chdir("/home/daniel/Downloads/Lunes11Julio/NLP-Model-for-prevention-of-Cybercrimes-master/Project")

# %% [markdown]
# ## Data

# %%
data = pd.read_excel("protests.xlsx",sheet_name="Archive") # Importing the database (tweets)

# %%
data.head() # Returns the first rows of the database
# Out:
#                 id_str        from_user  \
# 0  1268168014605713409  DiegoTorresCast
# 1  1268167979579080709    dariocaicedo0
# 2  1268167507048792067    dariocaicedo0
# 3  1268167186021076995      rockero1901
# 4  1268166853446316038       Insurrsion
#
#                                                 text  \
# 0  Marchas programadas para el 15 de junio en ple...
# 1  #Marcha15DeJunio vamos a marchar nadie se va e...
# 2  Ok vamos a regresar  a marchar bien chimba hp ...
# 3  #Marcha15DeJunio no podemos dsrle espera a las...
# 4  Los uga uga cavernícolas onvres y mugerez que ...
#
#                        created_at                time        day  \
# 0  Wed Jun 03 13:09:50 +0000 2020 2020-06-03 14:09:50 1900-01-03
# 1  Wed Jun 03 13:09:42 +0000 2020 2020-06-03 14:09:42 1900-01-03
# 2  Wed Jun 03 13:07:49 +0000 2020 2020-06-03 14:07:49 1900-01-03
# 3  Wed Jun 03 13:06:33 +0000 2020 2020-06-03 14:06:33 1900-01-03
# 4  Wed Jun 03 13:05:13 +0000 2020 2020-06-03 14:05:13 1900-01-03
#
#    geo_coordinates  user_lang  in_reply_to_user_id_str  \
# 0              NaN        NaN                      NaN
# 1              NaN        NaN                      NaN
# 2              NaN        NaN                      NaN
# 3              NaN        NaN                      NaN
# 4              NaN        NaN                      NaN
#
#   in_reply_to_screen_name     from_user_id_str  in_reply_to_status_id_str  \
# 0                     NaN  1016450294350262278                        NaN
# 1                     NaN            594165334                        NaN
# 2                     NaN            594165334                        NaN
# 3                     NaN           2984786121                        NaN
# 4                     NaN            332574323                        NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1237073660...                 356.0
# 1  http://pbs.twimg.com/profile_images/1262371600...                2138.0
# 2  http://pbs.twimg.com/profile_images/1262371600...                2138.0
# 3  http://pbs.twimg.com/profile_images/1232441216...                 597.0
# 4  http://pbs.twimg.com/profile_images/1251824422...                 106.0
#
#    user_friends_count           user_location  \
# 0               375.0                     NaN
# 1               188.0  Bogotá, D.C., Colombia
# 2               188.0  Bogotá, D.C., Colombia
# 3               557.0                     NaN
# 4               723.0                 Bogotá
#
#                                           status_url  \
# 0  http://twitter.com/DiegoTorresCast/statuses/12...
# 1  http://twitter.com/dariocaicedo0/statuses/1268...
# 2  http://twitter.com/dariocaicedo0/statuses/1268...
# 3  http://twitter.com/rockero1901/statuses/126816...
# 4  http://twitter.com/Insurrsion/statuses/1268166...
#
#                                         entities_str
# 0  {"hashtags":[{"text":"Marcha15DeJunio","indice...
# 1  {"hashtags":[{"text":"Marcha15DeJunio","indice...
# 2  {"hashtags":[{"text":"Marcha15DeJunio","indice...
# 3  {"hashtags":[{"text":"Marcha15DeJunio","indice...
# 4  {"hashtags":[{"text":"Marcha15DeJunio","indice...

# %%
# converting to list the column "text" where it contains the tweets
cols = ['from_user', 'text']
text = data[cols].values.tolist()

# %%
print(text) # printing the tweets
# Out:
# [['DiegoTorresCast', 'Marchas programadas para el 15 de junio en plena pandemia? Definitivamente la insensatez reina en Colombia! #Marcha15DeJunio'], ['dariocaicedo0', '#Marcha15DeJunio vamos a marchar nadie se va enfermar xd todos estaremos con muchos cuidados'], ['dariocaicedo0', 'Ok vamos a regresar  a marchar bien chimba hp contra este gobierno de mierda #Marcha15DeJunio'], ['rockero1901', '#Marcha15DeJunio no podemos dsrle espera a las causas sociales, es sierto que enfrentamos una pandemia, pero y las muertes a causas de las fuerzas armadas q deberian cuidaenos?, la cuarentena que es un privilegio de clases? La corrupción, la de forestación el abandono? CON TODA15'], ['Insurrsion', 'Los uga uga cavernícolas onvres y mugerez que se oponen a la #Marcha15DeJunio son los que comen como borregos de rcn y paracol.'], ['Antonio163016', '#Marcha15DeJunio https://t.co/hUrLeuaiv9'], ['Margari97231178', '#Marcha15DeJunio  la hipocresía de los noticiero colombianos, vendidos y corruptos https://t.co/gxOik2Ji7A'], ['DePorDiosMayer', "#Marcha15DeJunio Avisenme si esta vez si vamos a tomar en serio la protesta y vamos a armar una verdadera revolución porque si es pa' tomar chocolate con los del ESMAD, prefiero quedarme en mi casa. Gracias."], ['Paozroca1', '#mecuidotecuido #Marcha15DeJunio no salgo a marchar por nuestra salud!!! Pero no significa que no Levante mi voz de protesta por todo lo que está mal en este país !! Usaré mis redes sociales como medio para protestar.'], ['Carolin15498454', '#Marcha15DeJunio \nNo seas como #JBalvin que sólo apoya a USA, tenemos que hacer algo por el país https://t.co/Uw53N656JH'], ['CazaSarcasmos', 'Y en que cambia el país? No a la marcha del 15 de junio.  Respeto la vida de los médicos #Marcha15DeJunio'], ['licethpao123', '#Marcha15DeJunio el gobierno empezará una semana antes a "aplacar" la curva del covid19 y después de la marcha.."AUMENTARÁ" la cifra de contagios 🙄🙄Nuestra Polombia... Sumergidos en la Ignorancia de la ultraderecha!'], ['ETV1122', '#Marcha15DeJunio\nNo... Que les pasa, son retrasados mentales o que¿‽ Ya estamos en bajada de casos, no hagan eso, háganlo después, cuándo tenga suficiente neuronas para pensar y que aprenda a tender la cama, no se tiren más el país #RETRASADOS'], ['Astro27350111', 'Yo voy a demandar a el presidente por vulnerar mis derechos !!! Si me muero de hambre el presidente tiene la culpa y si me muero por covid-19 es por que el precidente se robo la plata y no hay respiradores. #Marcha15DeJunio'], ['CazaSarcasmos', 'Me van odiar por esto pero... y si salen los que no tienen empleo, los que no tienen recursos, porque los que tienen no se van a exponer. Entonces esos que salen se enferman y toca ver cuantos tienen salud (porque si el sistema no es bueno) pero para que retarlo? #Marcha15DeJunio'], ['juanfel16448123', '#Marcha15DeJunio por una colombia libre de corrupcion! https://t.co/zX9OLJjBG0'], ['Oscar_GCh', '@YolandaRuizCe Y 100 LÍDERES ASESINADOS también lo que va corrido del año y para eso si hay Esmad, Fuerzas Militares, Armamento para defensa y asesoría gringa.\n\n#UribeEs el artífice de esta matanza\n#Marcha15DeJunio https://t.co/ygINR5rHCq'], ['GLondoo2', '@VickyDavilaH Protestas en vivo en Washington D.C    \n https://t.co/z1m4VD2z7k #Marcha15DeJunio'], ['hernanmorenoe', '@CConstitucional está cerrando las puertas de la democracia.  Así rechaza la búsqueda de soluciones. El país quiere Paz con Justicia,  no el Estado tomado por la mafia y la corrupción #DejenJugarALaColombiaHumana #Marcha15DeJunio @petrogustavo @GustavoBolivar https://t.co/6TOupsh2bo'], ['BobaHijueputaaa', '#Marcha15DeJunio'], ['BobaHijueputaaa', '#Marcha15DeJunio'], ['BobaHijueputaaa', '#Marcha15DeJunio'], ['BobaHijueputaaa', '#Marcha15DeJunio'], ['Angie_SM98', '#Marcha15DeJunio\nYo: Se necesita hacer justicia, soy una persona insignificante pero tengo mis derechos y por eso marcho, hay que alzar la voz y hacer que todos esos malditos paguen.\nMi mamá: https://t.co/w2erDWgtws'], ['_ka ...

# %%
text[0][1] # accessing to the first tweet from the list 'text'
# Out:
# 'Marchas programadas para el 15 de junio en plena pandemia? Definitivamente la insensatez reina en Colombia! #Marcha15DeJunio'

# %%
len(text) # number of tweets
# Out:
# 1287

# %%
tweets = [text[i][1] for i in range(len(text))]
len(tweets)
#len(tweets) # length of tweets
# Out:
# 1287

# %%
for i in range(0,1287):
  print(text[i])
# Out:
# ['DiegoTorresCast', 'Marchas programadas para el 15 de junio en plena pandemia? Definitivamente la insensatez reina en Colombia! #Marcha15DeJunio']
# ['dariocaicedo0', '#Marcha15DeJunio vamos a marchar nadie se va enfermar xd todos estaremos con muchos cuidados']
# ['dariocaicedo0', 'Ok vamos a regresar  a marchar bien chimba hp contra este gobierno de mierda #Marcha15DeJunio']
# ['Generalsandrita', '@ELMASGODO Pretedenden quebrar la economía. Que se pare la producción ya que es el estado ideal en socialismo. \n\nPilas @FenalcoNacional @MincomercioCo @camaracomerbog después no digan que no le avisaron.\n\n#Marcha15DeJunio']
# ['Jorgetolds1219', '@Davidc_CB @GustavoBolivar Vamos a marchar no mas #Marcha15DeJunio vamos con toda no importa la pandemia mire todo europa como esta estados unidos y a nosotros nos matan mas lideres y nadie hace nada @petrogustavo']
# ['NatieeeG', '@jerojasrodrigue Acabo de ver que #Marcha15DeJunio es tendencia también por la indignación que provocan decenas de asesinatos de líderes sociales en Colombia.']
# ['AngleleeB', 'COLOMBIA NECESITA PAZ #Marcha15DeJunio']
# ['AngleleeB', 'SALGAMOS A MARCHAR A PROTESTAR Y LA VERDAD DUELE EN EL ALMA COLOMBIA AL SABER DE QUE NO SOMOS CAPACES DE LUCHAR POR NUESTROS DERECHOS,PIENSEN EN LO QUE NOS ESPERA A LA FUTURA GENERACIÓN.\n#Marcha15DeJunio']
# ['PijAnon', '#Anonymous \n\n#UribeEs el que quiere llevar fútbol a la TV, más agro ingreso solidario, más mano dura, etc.., con tal de distraer la opinión pública del problema real. #UribeEs el veneno de Colombia.\n#Marcha15DeJunio #NoMasImpunidad #ElPeorGobiernoDeLaHistoria https://t.co/w0A92m5QC0']
# ['AngleleeB', 'No entiendo y no me cabe en mi cabeza como hay gente que todavía preguntan que por cual razón debemos salir a las calles a protestar en Colombia . QUEREMOS QUE EL GOBIERNO LE VEA LA CARA AL PUEBLO QUE LUCHEMOS POR LO QUE QUEREMOS , QUE SE ACABE ESTA DESIGUALDAD #Marcha15DeJunio']
# ['javiwar', '@GustavoBolivar #Marcha15DeJunio es la estupidez más grande de gente con cerebro pequeño como este petardo Y QUE SIGA LA PROPAGACIÓN DEL VIRUS NOJODA es que no pueden ser más brutos']
# ['AndersonAlzateL', 'Realmente sino estuviéramos en un proceso obligatorio de Salud yo saldría a la #Marcha15DeJunio hay muchas razones: Exigir Justicia ante los escándalos, una ley más fuerte contra los corruptos, seguridad en el territorio, implementación del Gobierno, y, la plata de la emergencia?']
# ['EdisonStevenRi1', 'Los que quieren iniciar la #Marcha15DeJunio en Colombia saldrán a protestar de verdad? ¿O a desbaratar las ciudades y generar disturbios con actos vandálicos como en la Casa Blanca?... Luego dicen que la autoridad abusa cuando el único objetivo de algunos es salir a  robar!!']
# ['Javi_ERH', 'Porque en Colombia nos debe doler primero los más de 200 líderes sociales asesinados, en los últimos 2 años #Marcha15DeJunio']
# ['lopezfco', '@RobertoMTico El problema es que el #Marcha15DeJunio nos van a mandar a encerrar en la casa, con alguna excusa, así actúan las dictaduras #Matarife']
# ['Lictius', '#Marcha15DeJunio Locombia, país en que en plena pandemia FECODE organiza una marcha, es decir anuncia que va a cometer un delito para propagar el virus que nos tiene confinados a muchos desde hace dos meses. Van a dar los permisos para marchar los alcaldes ?.']
# ['sheriith', 'Yo me considero una persona ignorante en cuanto a historia y las fechorías de los políticos, pero siempre apoyaré el hecho de que los dejen en evidencia y me sumo a #Marcha15DeJunio']
# ['Jose58608041', '#Marcha15DeJunio\n\nYa marchamos en paz\nYa marchamos en orden\nYa marchamos dando abrazos \n\nY aun asi estos NARCOS nos siguen matando, intimidando, menospresiando, humillando y robandonos cualquier oportunidad y derecho.\n\nA DARLES DURO ESTA VEZ !!']

# %%
users = [text[i][0] for i in range(len(text))]
users
len(users) # length of users
# Out:
# 1287

# %% [markdown]
# ## Data Preparation
#
# - ## Functions to remove URL links, @mention, #hashtags

# %%
import string # String contains methods that allow the use of characters which are considered punctuation characters, 
                # digits, uppercase, lowercase, etc.
import re # Regular expression operations

# %%
#This function replaces URLs by ', ' for each tweet
#Input: Single tweet to be processed
#Output: Single tweet where URLs were replaced by ', '
#You may use https://regex101.com/ to understand the regular expression
def strip_links(text):
    link_regular_expression = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links = re.findall(link_regular_expression, text)
    for link in links:
        text = text.replace(link[0], ', ')   
    return text

# %%
#Testing the function strip_links with a single sentence
#Test the function with another twext that you may image that contains links
text1 = 'Inconformismo en la ciudadania por tantas acciones represivas http://whatever.com https://anotherlink'
text1 = strip_links (text1)
print(text1)
# Out:
# Inconformismo en la ciudadania por tantas acciones represivas ,  ,

# %%
#Task: Test the function strip_links with the list 'text'
#You may use a for function

#for ? in range(len(?)):
#  ?
#print(text)

# %%
#This function removes mentions, hashtags and characters from tweets
#Input: Single tweet to be processed
#Output: Single tweet where mentions, hastags and characters were removed
def strip_all_entities(text):
    entity_prefixes = ['@','#','\\','_']
    for separator in  string.punctuation: 
        if separator not in entity_prefixes :
            text = text.replace(separator,' ') #Any separator different of 'entity_prefixes' is replaced by an space
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes: #If the word starts by any of the 'entity_prefixes' the word is not appended
                words.append(word)
    return ' '.join(words)

# %%
#Testing the function strip_all_entities with a single sentence
text1 = 'Inconformismo en la ciudadania por tantas - acciones represivas #resistencia @andresg'
text1 = strip_all_entities (text1)
print(text1)
# Out:
# Inconformismo en la ciudadania por tantas acciones represivas

# %%
#Task: Test the function strip_all_entities with the list 'text'
#for ? in range(len(?)):
#  ?
#print(text)
# Out:
# [['DiegoTorresCast', 'Marchas programadas para el 15 de junio en plena pandemia Definitivamente la insensatez reina en Colombia'], ['dariocaicedo0', 'vamos a marchar nadie se va enfermar xd todos estaremos con muchos cuidados'], ['dariocaicedo0', 'Ok vamos a regresar a marchar bien chimba hp contra este gobierno de mierda'], ['rockero1901', 'no podemos dsrle espera a las causas sociales es sierto que enfrentamos una pandemia pero y las muertes a causas de las fuerzas armadas q deberian cuidaenos la cuarentena que es un privilegio de clases La corrupción la de forestación el abandono CON TODA15'], ['Insurrsion', 'Los uga uga cavernícolas onvres y mugerez que se oponen a la son los que comen como borregos de rcn y paracol'], ['Antonio163016', ''], ['Margari97231178', 'la hipocresía de los noticiero colombianos vendidos y corruptos'], ['DePorDiosMayer', 'Avisenme si esta vez si vamos a tomar en serio la protesta y vamos a armar una verdadera revolución porque si es pa tomar chocolate con los del ESMAD prefiero quedarme en mi casa Gracias'], ['Paozroca1', 'no salgo a marchar por nuestra salud Pero no significa que no Levante mi voz de protesta por todo lo que está mal en este país Usaré mis redes sociales como medio para protestar'], ['Carolin15498454', 'No seas como que sólo apoya a USA tenemos que hacer algo por el país'], ['CazaSarcasmos', 'Y en que cambia el país No a la marcha del 15 de junio Respeto la vida de los médicos'], ['licethpao123', 'el gobierno empezará una semana antes a aplacar la curva del covid19 y después de la marcha AUMENTARÁ la cifra de contagios 🙄🙄Nuestra Polombia Sumergidos en la Ignorancia de la ultraderecha'], ['ETV1122', 'No Que les pasa son retrasados mentales o que¿‽ Ya estamos en bajada de casos no hagan eso háganlo después cuándo tenga suficiente neuronas para pensar y que aprenda a tender la cama no se tiren más el país'], ['Astro27350111', 'Yo voy a demandar a el presidente por vulnerar mis derechos Si me muero de hambre el presidente tiene la culpa y si me muero por covid 19 es por que el precidente se robo la plata y no hay respiradores'], ['CazaSarcasmos', 'Me van odiar por esto pero y si salen los que no tienen empleo los que no tienen recursos porque los que tienen no se van a exponer Entonces esos que salen se enferman y toca ver cuantos tienen salud porque si el sistema no es bueno pero para que retarlo'], ['juanfel16448123', 'por una colombia libre de corrupcion'], ['Oscar_GCh', 'Y 100 LÍDERES ASESINADOS también lo que va corrido del año y para eso si hay Esmad Fuerzas Militares Armamento para defensa y asesoría gringa el artífice de esta matanza'], ['GLondoo2', 'Protestas en vivo en Washington D C'], ['hernanmorenoe', 'está cerrando las puertas de la democracia Así rechaza la búsqueda de soluciones El país quiere Paz con Justicia no el Estado tomado por la mafia y la corrupción'], ['BobaHijueputaaa', ''], ['BobaHijueputaaa', ''], ['BobaHijueputaaa', ''], ['BobaHijueputaaa', ''], ['Angie_SM98', 'Yo Se necesita hacer justicia soy una persona insignificante pero tengo mis derechos y por eso marcho hay que alzar la voz y hacer que todos esos malditos paguen Mi mamá'], ['_kaatooo', 'ya sabes cuándo'], ['GLondoo2', 'Siguen las Protestas en vivo en Washington D C Live video protest protestas en vivo'], ['Astro27350111', 'Vamos todas a exojir lo que es de nosotros Estudio salud trabajo y 0 maltrato de la policía Ah y que renuncien todas esas ratas de políticos'], ['AcademicallAse1', ''], ['dana13_31', ''], ['Calcor70', '🤣 Sin tapa bocas sin gel anti bacterias y sin distanciamiento social 🖕hagan lo que les dé la puta gana después NO se quejen si les da COVID 19 Y que los atienda quien los convoca a su marcha 👌'], ['ElVueloVacio', 'Buenos días a todos menos a esos humanos que les da por convocar marchas con distanciamiento social en medio de una pandemia a esos no por demagogos e irresponsables'], ['_kaatooo', 'Yo salgo a la Por la CORRUPCIÓN en medio de la pandemia por la ÑEÑEPOLITICA por cada LÍ ...

# %% [markdown]
# source: https://stackoverflow.com/questions/8376691/how-to-remove-hashtag-user-link-of-a-tweet-using-regular-expression

# %%
#This function removes URLS, mentions, hashtags and characters from tweets
#Input: List of tweets to be processed
#Output: List of clean tweets
def strip_all(list_text):
    list_stripped = []
    for t in list_text:
        word = strip_all_entities(strip_links(t))
        list_stripped.append(word)
    return(list_stripped)

# %%
tweets = strip_all([text[i][1] for i in range(len(text))])
text = [[users[i],tweets[i]] for i in range(len(users))]
text
# Out:
# [['DiegoTorresCast',
#   'Marchas programadas para el 15 de junio en plena pandemia Definitivamente la insensatez reina en Colombia'],
#  ['dariocaicedo0',
#   'vamos a marchar nadie se va enfermar xd todos estaremos con muchos cuidados'],
#  ['dariocaicedo0',
#   'Ok vamos a regresar a marchar bien chimba hp contra este gobierno de mierda'],
#  ['rockero1901',
#   'no podemos dsrle espera a las causas sociales es sierto que enfrentamos una pandemia pero y las muertes a causas de las fuerzas armadas q deberian cuidaenos la cuarentena que es un privilegio de clases La corrupción la de forestación el abandono CON TODA15'],
#  ['Insurrsion',
#   'Los uga uga cavernícolas onvres y mugerez que se oponen a la son los que comen como borregos de rcn y paracol'],
#  ['Antonio163016', ''],
#  ['Margari97231178',
#   'la hipocresía de los noticiero colombianos vendidos y corruptos'],
#  ['DePorDiosMayer',
#   'Avisenme si esta vez si vamos a tomar en serio la protesta y vamos a armar una verdadera revolución porque si es pa tomar chocolate con los del ESMAD prefiero quedarme en mi casa Gracias'],
#  ['Paozroca1',
#   'no salgo a marchar por nuestra salud Pero no significa que no Levante mi voz de protesta por todo lo que está mal en este país Usaré mis redes sociales como medio para protestar'],
#  ['Carolin15498454',
#   'No seas como que sólo apoya a USA tenemos que hacer algo por el país'],
#  ['CazaSarcasmos',
#   'Y en que cambia el país No a la marcha del 15 de junio Respeto la vida de los médicos'],
#  ['licethpao123',
#   'el gobierno empezará una semana antes a aplacar la curva del covid19 y después de la marcha AUMENTARÁ la cifra de contagios 🙄🙄Nuestra Polombia Sumergidos en la Ignorancia de la ultraderecha'],
#  ['ETV1122',
#   'No Que les pasa son retrasados mentales o que¿‽ Ya estamos en bajada de casos no hagan eso háganlo después cuándo tenga suficiente neuronas para pensar y que aprenda a tender la cama no se tiren más el país'],
#  ['Astro27350111',
#   'Yo voy a demandar a el presidente por vulnerar mis derechos Si me muero de hambre el presidente tiene la culpa y si me muero por covid 19 es por que el precidente se robo la plata y no hay respiradores'],
#  ['CazaSarcasmos',
#   'Me van odiar por esto pero y si salen los que no tienen empleo los que no tienen recursos porque los que tienen no se van a exponer Entonces esos que salen se enferman y toca ver cuantos tienen salud porque si el sistema no es bueno pero para que retarlo'],
#  ['juanfel16448123', 'por una colombia libre de corrupcion'],
#  ['Oscar_GCh',
#   'Y 100 LÍDERES ASESINADOS también lo que va corrido del año y para eso si hay Esmad Fuerzas Militares Armamento para defensa y asesoría gringa el artífice de esta matanza'],
#  ['GLondoo2', 'Protestas en vivo en Washington D C'],
#  ['hernanmorenoe',
#   'está cerrando las puertas de la democracia Así rechaza la búsqueda de soluciones El país quiere Paz con Justicia no el Estado tomado por la mafia y la corrupción'],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['Angie_SM98',
#   'Yo Se necesita hacer justicia soy una persona insignificante pero tengo mis derechos y por eso marcho hay que alzar la voz y hacer que todos esos malditos paguen Mi mamá'],
#  ['_kaatooo', 'ya sabes cuándo'],
#  ['GLondoo2',
#   'Siguen las Protestas en vivo en Washington D C Live video protest protestas en vivo'],
#  ['Astro27350111',
#   'Vamos todas a exojir lo que es de nosotros Estudio salud trabajo y 0 maltrato de la policía Ah y que renuncien todas esas ratas de políticos'],
#  ['AcademicallAse1', ''],
#  ['dana13_31', ''],
#  ['Calcor70',
#   '🤣 Sin tapa bocas sin gel anti bacterias y sin distanciamiento social 🖕hagan lo que les dé la puta gana después NO se quejen si les da COVID 19 Y que los atienda quien los convoca a su marcha 👌'],
#  ['ElVueloVacio',
#   'Buenos días a todos menos a esos humanos que les da por convocar marchas con distanciamiento social en medio de una pandemia a esos no por demagogos e irresponsables'],
#  ['_kaatooo',
#   'Yo salgo a la Por la CORRUPCIÓN en medio de la pandemia por la ÑEÑEPOLITICA por cada LÍDER SOCIAL ASESINADO por los INDÍGENAS y AFROS por la NATURALEZA y su CUIDADO ¿HAY MOTIVOS PARA NO SALIR A MARCHAR Prefiero morir de que de indiferencia'],
#  ['PamelaVelezH', 'Me fuiii'],
#  ['Oscar_GCh',
#   'Aquí uno de los barra brava y defensores del mal en épocas cuando el razocinio aún lo acompañaba Hoy qué pensará al saber que el perfilador de periodistas y PATROCINADOR de paramilitares a quienes entrenó Yair Klein es el'],
#  ['edwarkenw861245', 'los esperan para el baile pero con el ataúd de cartón'],
#  ['CrisFlorez07',
#   'Aquí nos tratan de vándalos pero allá sí legitiman la marcha'],
#  ['lopezfco', ''],
#  ['Marcela6C', 'Esos deseos me dan más ganas de apoyar la'],
#  ['oskarciber',
#   'Contra un gobierno Corrupto que se tomó el poder SI EL PUEBLO SE LEVANTA SE LES ACABA EL JUEGO'],
#  ['Generalsandrita',
#   'Pretedenden quebrar la economía Que se pare la producción ya que es el estado ideal en socialismo Pilas después no digan que no le avisaron'],
#  ['Jorgetolds1219',
#   'Vamos a marchar no mas vamos con toda no importa la pandemia mire todo europa como esta estados unidos y a nosotros nos matan mas lideres y nadie hace nada'],
#  ['NatieeeG',
#   'Acabo de ver que es tendencia también por la indignación que provocan decenas de asesinatos de líderes sociales en Colombia'],
#  ['AngleleeB', 'COLOMBIA NECESITA PAZ'],
#  ['AngleleeB',
#   'SALGAMOS A MARCHAR A PROTESTAR Y LA VERDAD DUELE EN EL ALMA COLOMBIA AL SABER DE QUE NO SOMOS CAPACES DE LUCHAR POR NUESTROS DERECHOS PIENSEN EN LO QUE NOS ESPERA A LA FUTURA GENERACIÓN'],
#  ['PijAnon',
#   'el que quiere llevar fútbol a la TV más agro ingreso solidario más mano dura etc con tal de distraer la opinión pública del problema real el veneno de Colombia'],
#  ['AngleleeB',
#   'No entiendo y no me cabe en mi cabeza como hay gente que todavía preguntan que por cual razón debemos salir a las calles a protestar en Colombia QUEREMOS QUE EL GOBIERNO LE VEA LA CARA AL PUEBLO QUE LUCHEMOS POR LO QUE QUEREMOS QUE SE ACABE ESTA DESIGUALDAD'],
#  ['javiwar',
#   'es la estupidez más grande de gente con cerebro pequeño como este petardo Y QUE SIGA LA PROPAGACIÓN DEL VIRUS NOJODA es que no pueden ser más brutos'],
#  ['AndersonAlzateL',
#   'Realmente sino estuviéramos en un proceso obligatorio de Salud yo saldría a la hay muchas razones Exigir Justicia ante los escándalos una ley más fuerte contra los corruptos seguridad en el territorio implementación del Gobierno y la plata de la emergencia'],
#  ['EdisonStevenRi1',
#   'Los que quieren iniciar la en Colombia saldrán a protestar de verdad ¿O a desbaratar las ciudades y generar disturbios con actos vandálicos como en la Casa Blanca Luego dicen que la autoridad abusa cuando el único objetivo de algunos es salir a robar'],
#  ['Javi_ERH',
#   'Porque en Colombia nos debe doler primero los más de 200 líderes sociales asesinados en los últimos 2 años'],
#  ['lopezfco',
#   'El problema es que el nos van a mandar a encerrar en la casa con alguna excusa así actúan las dictaduras'],
#  ['Lictius',
#   'Locombia país en que en plena pandemia FECODE organiza una marcha es decir anuncia que va a cometer un delito para propagar el virus que nos tiene confinados a muchos desde hace dos meses Van a dar los permisos para marchar los alcaldes'],
#  ['sheriith',
#   'Yo me considero una persona ignorante en cuanto a historia y las fechorías de los políticos pero siempre apoyaré el hecho de que los dejen en evidencia y me sumo a'],
#  ['EduardoAbelRom1',
#   'Todos a las calles no podemos seguir callados mientras el porcino se roba nuestros recursos'],
#  ['PaolaAn85777033',
#   'En serio nos encerramos 3 meses para salir a marchar bobotes'],
#  ['Alejand32574510', 'Nooo'],
#  ['germanecabrerao', ''],
#  ['CarlosReey',
#   'de verdad Van a poner a prueba las UCI No jueguen con la suerte así que irresponsables'],
#  ['wverodr79',
#   'por favor que marchen todos sin tapabocas Y antes de la marcha firmar el desestimiento de la UCI gracias buenos para nada'],
#  ['germanecabrerao', ''],
#  ['germanecabrerao', 'no debemos graduarnos de pendejos'],
#  ['KlausGoebel',
#   'Tenemos derechos y libertades También tenemos deberes Marchas sin Violencia Es un momento difícil en Colombia y en el mundo Construir país en paz en sana convivencia y respeto Sin odios Si se puede Hermosa Colombia adelante'],
#  ['verdolaga2323',
#   'Es irresponsable salir en pleno pico epidémicologico la protesta es un derecho por supuesto pero por qué hacerlo en plena pandemia Y ojala recuerden esos colombianos que mueren por pisar minas y combatir el nacotrafico'],
#  ['jusepu', '¿No más goles'],
#  ['JuanGuarin11', ''],
#  ['alexcastellan07',
#   'Y si salimos desde ya Eso de programar marchar hace que esté más preparada la maquinaria corrupta en complicidad con el smad para vulnerar nuestros derechos y para que se infiltren y generen caos'],
#  ['JohanMa20', ''],
#  ['BENJAMINGARZON7', 'Listos'],
#  ['oskar4791', ''],
#  ['Donatell131', 'para la calle los superamos 1 en un millon'],
#  ['PUBLINET8', ''],
#  ['Donatell131', ''],
#  ['ARicardoBenitez',
#   'Porque a diario mueren más por el virus de la corrupción'],
#  ['mochilaWayuu',
#   'Ya lo teníamos son los líderes y lideresas sociales asesinadas son los niños que mueren de desnutrición por olvido del Estado son los niños muertos en el bombardeo son los falsos positivos Etc'],
#  ['PaitoCas',
#   'esa gente que pregunta porque salir a protestar en plena pandemia es la misma gente que está cómoda con la realidad del país solo les recuerdo que si no nos mata el virus nos va a matar la desigualdad la injusticia y la corrupción'],
#  ['SergioM0614',
#   'Los que querían que Claudia López quitara la cuarentena ahora si critican qué haya'],
#  ['mafaldagallego',
#   'Muy valiente desde la comodidad de su casa llamar a los pendejos a una marcha para que se contagien y uds ni siquiera han ido al congreso a trabajar🤬 irresponsable'],
#  ['Andresg0689', 'contra este puto gobierno corrupto'],
#  ['GREG09751392',
#   'La marcha de los idiotas para intentar tapar la volada del jefe Petro a Cuba No se salva'],
#  ['pposejo',
#   'ojalá salgan todos sus seguidores y los del y entre todos se abracen y protesten para que el virus haga lo suyo Se llama selección natural lo dijo Darwin'],
#  ['andercal24', ''],
#  ['javier_zulia', 'Un Marcapasos para Aida'],
#  ['ARicardoBenitez', 'Con bandera y tapabocas salgo'],
#  ['sevilla11_karol',
#   'Tengo mucha impotencia todo lo que esta pasando en este mundo cuando será que la policía no va abusar de su autoridad y no van a matar a negros por ser racistas creo que me voy a quedar esperando este cambio por que nunca va a pasar'],
#  ['yeison_fox',
#   'no estaban luego ayer poniendo imágenes negras en sus perfiles hipócritas de Mierda Se les pide aquí actuar y les da miedo'],
#  ['arleytrujillo7', 'tod@s a las calles por q se haga justicia'],
#  ['sevilla11_karol', 'Motivo'],
#  ['sevilla11_karol',
#   'Todos piensan en la pandemia y todo en parte tienen razón pero parce acá uno tiene valer su vida los policías somo por que son autoridad tiene derechos hacer esas cosas pues no acá todos somos humanos que esa marcha se haga por gente que está arriba sin ningún'],
#  ['yeison_fox',
#   'Aplauden protestas en Estados Unidos pero se convoca en Colombia y les asusta la pandemia Me asusta ma sola pandemia de hambre y sangre que agobia este platanal'],
#  ['TutaDiego',
#   'Todos a las calles por más aglomeraciones más contagios más muertes más Coronavirus más aislamiento y cuarentena más crisis hospitalaria más crisis económica más decretos de Duque'],
#  ['mafaldagallego',
#   'la economía cerrada negocios en quiebra y preparan marcha😱 que irresponsables mejor no se hubiese implementado la cuarentena y todos contagiados pero con empleo'],
#  ['yeison_fox',
#   'Contra el fascismo que estos sometidos durante está pandemia'],
#  ['arleytrujillo7', 'para q metan a a la carcel'],
#  ['SteffaniaRo', 'Salgo'],
#  ['JohnGO92',
#   'cule marcha organizada con dos semanas de anticipación sin cero espontaneidad de parte de nosotros no valemos es verga'],
#  ['sevilla11_karol',
#   'Vamos a marchar por todas esas personas que no pudieron estar y vamos a pelear por todos'],
#  ['Carlosa83209358', ''],
#  ['OracionesPara',
#   'No asistiré porque respeto mi vida y cuido a mi familia pero me gusta que muchos 🐷 vayan a la Esa depuración le sirve a Colombia 😁'],
#  ['Elquenadasabeo1',
#   'Señor y Colombia Humana están dispuestos a lo que sea por llegar al poder incluso a por sobre la sangre se la gente como pasó a principio de año cuando decían que eran toda Colombia cuando en realidad solo era el petrismo'],
#  ['FilosofoImpuro', 'Esto no se logra con marchas Ya está demostrado'],
#  ['Elquenadasabeo1',
#   'Los mismos que criticaban al gov por no cerrar el aeropuerto por el asilamiento inteligente por abrir reactivar el mercado son los mismos que están promoviendo la Yo les digo no mas manipulación de la disque oposición'],
#  ['David08642453', ''],
#  ['jomach35',
#   'Muero de ganas de ver estrenar los nuevos juguetes del ESMAD 👏👏👏👏👏👏#Marcha15DeJunio'],
#  ['Ivager69',
#   'ciudades en el mundo marchan contra el odio y racismo policial que también se ve en Btá Es hora de despertar de verdad Dónde están estudiantes maestros desempleados sindicatos Es hora de reclamar y decirles NO Más a los corruptos y a los violadores de DDHH'],
#  ['Gaso40321953',
#   'todos los contagios y muertes de adultos y abuelos después del 15 de junio son culpa de Petro Bolívar Cepeda Claudia etc y de los adolecentes que van a llevar el virus a sus casas no hay escusas serán asesinos de sus padres y abuelos'],
#  ['David08642453', ''],
#  ['TutaDiego',
#   'en pleno aislamiento en plena cuarentena En plena pandemia Es enserio Los que promueven esto de verdad que son inconscientes e irresponsables si lo que quieren es destruir las ciudades y el país ya tendrán tiempo después cuando No tengo ni puta idea'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['MiguelP51520329',
#   'Lo bueno de la es que saldrán muchos mamertos de izquierda y el CoronaVirus estará presente para aniquilarlos para siempre Todo puede pasar se aniquilan sólitos señores sólitos'],
#  ['joseale30251145',
#   'Mamados de tantos decretos Presidenciales tan mediocres'],
#  ['alejorcasta',
#   'a las calles por todos nuestros muertos Lideres Sociales indigenas estudiantes profesores'],
#  ['hernangarcia98',
#   '“Tenemos que despertar y no quedarnos callados” Spike Lee'],
#  ['cesfit7',
#   'otra de las razones por la cual marcharemos Que verguenza de congreso ahora no solo tenemos que lidiar con su manera de robarnos si no que hay que sumarle la desfachatez para realizar su labor'],
#  ['Elquenadasabeo1',
#   'A los que promueven la absurda ustedes no son oposición no representan nada sabemos que son el vano intento de un político de cuyo nombre no quiero ni recordar por ser elegido en las próximas elecciones presidenciales'],
#  ['redcajapandora', ''],
#  ['maleja_28_', 'será como el'],
#  ['Ang_Altamirano',
#   'el desempleo por encima del 20 la reforma tributaria que se nos viene para tapar el hueco gigante de lo poco que han repartido más lo mucho que se han robado la corrupción cada día más descarada y la justicia creada para librar al que tiene motivos existen'],
#  ['Elquenadasabeo1',
#   'La disque oposición lista para mandar todo al garete en la Es por eso q esta gente no puede ser considerada oposición ni nada mas que un grupo criminal Acaso no entienden que ha una pandemia no ven q sus disque protestas pacificas han hecho mas daño q bien'],
#  ['LaGwens',
#   'pa’ mi es una irresponsabilidad Sí hay infinitas razones para salir a protestar pero no es el momento Yo por allá no voy'],
#  ['Vladmizar6',
#   'Buen dia hombre mucha para vos y toda la genté hoy Cierto que quedo decente Agradeco si ayudas a difundir La Buena compa y prepararse con toda para 🇨🇴🐵💪'],
#  ['o_agudelo75',
#   'En una economía golpeada a los genios de siempre se les ocurre ¿Por qué no practican un deporte Que pereza la gente inconsciente'],
#  ['LuIsOvEjO', ''],
#  ['latriplehp5678', ''],
#  ['delmontonsoy',
#   'para que los hps salgan a contagiarse masivamente de Covid19 y lleguen a sus casas a Joder a sus familias ASESINOS'],
#  ['JaimeAlonsoPar6',
#   'a la calle para exigir al narcogobierno o a la narcodictadura que cese su hostilidad contra el Pueblo'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['josevecinop',
#   'el efecto dominó del derecho a la justa protesta y la responsabilidad de cuidar a la familia'],
#  ['mariafe37834240', 'Nos vemos en las calles'],
#  ['mrwatch808',
#   '¿En serio Y porque esta única vez los afrodescendientes si importan es una HIPOCRESIA cuando en Choco y otras tantas partes de Colombia hay muchos ANDERSON sin oportunidades e inmersos en una guerra causada por el famoso ACUERDO pero esos no merecen marcha'],
#  ['nano1960',
#   'La apoyo PERO 1 día Suficiente para desahogarnos pero no servirá para cambiar mejorar el pais SERA OTRO SALUDO A LA BANDERA Un mes paro'],
#  ['Alfredoboita1',
#   'se acabó la valeriana en colombia el matarife se la tomo toda'],
#  ['tostadadeatun1',
#   'El mundo necesita la verdad Ironia Una organización con máscara contando más que toda la iglesia nada más que cuentos de disney'],
#  ['sin_praxis',
#   'Las protestas y reclamos que se quiere hacer al gobierno son legítimos pero no olviden que EN COLOMBIA el Solo es una campaña publicitaria No esperen condescendencia de nuestros medios de comunicación a las causas colombianas'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['jairoroa171',
#   'aquí el mundo nos está mostrando que ni los gobiernos ni autoridades van a seguir abusando y en Colombia una de las razones de éstos abusos es la permisividad de la justicia con el y sus secuaces por éso como pueblo vamos a derrotar ésas injusticias'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['rpegazo',
#   'el símbolo de la gente Imbecil y demasiada enferma de este país Álvaro Uribe Vélez Argiro Corte Suprema en repudio por el asesinato de Anderson a manos de criminales policías Yair Klein juanpis gonzález Corte Suprema'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['luchocontrerasp',
#   'Cómo puede decir que REBERLDE CON CAUSA si has estado en todas las mermeladas presidenciales Ahora el pueblo es quiénes deberíamos ser los REBEELDES CON JUSTA CAUSA'],
#  ['So_lecito',
#   'En Colombia matan diariamente a líderes sociales e indígenas y yo no los veo poniendo una imagen negra en redes Es que los muertos extranjeros valen más'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['EliasLavoz1',
#   '¿Y ahora cuál es el motivo de la famosa marcha Estamos en una situación de la cual debemos estar unidos como país para salir adelante no para “revolucionar” el corazón de otros'],
#  ['robertpenuela',
#   'que no se quejen déspues Es un delito contra la salud pública y violación de medida sanitaria Pero el que llego de Cuba no le importa enviar incautos a la calle a contagiar y contagiarse con tal de incendiar el país por su sed de poder'],
#  ['oskarciber',
#   'A MARCHAR y PROTESTAR contra el NARCO ESTADO LA ÑEÑE POLÍTICA y el silencio cómplice del gobierno de URIDUQUE por Narco Embajador Sanclemente'],
#  ['Andres_Lopez13',
#   '¿Y nuestra indignación pa cuándo Pal 15 de Junio todos a las calles'],
#  ['Vcv173',
#   'se suponía que ud iva a expropiar las tierras si ganaba las elecciones ahora que dirán los uribestias pobres tirados a capitalistas que tienen fincas pequeñas heredadas de su familiar indígena que detestatan y no producen por qué son de derecha'],
#  ['PATRICI20413620',
#   'A estas alturas de la vida para mi marcha es sinónimo de destrucción y también de contagio'],
#  ['Alfredoboita1', 'el líder de la banca criminal más grande de Colombia'],
#  ['occiauditores',
#   'No a marchas no aglomeraciones ni clases en aulas no saben ni imagina qué es no poder respirar Deberían los medios hacer más publicidad con testimonios de los que se están ahogando con el virus por dentro Incredulidad hasta cuando se ahoguen'],
#  ['oskarciber',
#   'contra el SAQUEO SOLIDARIO robar plata en plena Pandemia es un acto criminal'],
#  ['cesp2010', 'Con Toda'],
#  ['Sebastian_xdxd1', '¿Listos para quemar tombos este día'],
#  ['PaoSalazT',
#   'es real O va a pasar como con el paro que llegó diciembre y el paro también se fue a vacaciones Porque ahí el referente fue Chile Qué se haga por convicción no solo porque el mundo alrededor está ardiendo y pues cómo nos quedamos atrás en tendencia'],
#  ['OGalvisC',
#   'Son muchos los llamados que se le han hecho al Gobierno pidiendo protección a los líderes sociales núnca han querido atender los llamados por eso'],
#  ['AlexMartinez258', ''],
#  ['oskarciber',
#   'POR LA SOBERANÍA NO A LAS BASES MILITARES GRINGAS EN COLOMBIA no somos el Patio trasero de Trump'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['sanntiago_er', ''],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['Alfredoboita1',
#   'investigado por homicidio por masacres por narcotrafico por chuzadas por corrupción por paramilitar no hay delito donde no esté involucrado el matarife de Uribe ya es hora que pague carcel'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['weinsh3z',
#   'un escudero de las Convivir Él concibe la paz únicamente como resultado de una victoria militar sobre los alzados en armas Iván Duque Al parecer el Duque del pasado les da sopa y seco a los periodistas del presente 🤦👇'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', ''],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['juanpariasl',
#   'es el reflejo de lo que quieren y representan para este país Muchos tratando de ver como sacan adelante a y otros como poner palos en la rueda'],
#  ['oskarciber', ''],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', 'Éstas son las razones para'],
#  ['juanpariasl',
#   'es en serio Cuando estamos ante la peor tragedia de la historia y pensando en esto'],
#  ['cabrales_ospino', ''],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['Alfredoboita1',
#   'estos son los policías que asesinaron a Dylan Cruz y Anderson arboleda demosle retwees para que no se olvide'],
#  ['milostickersas', 'Acabo de ver que se está convocando a'],
#  ['oskarciber',
#   'NO MÁS ESMAD y abuso policial derecho a la Protesta Social legítima'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', ''],
#  ['cabrales_ospino',
#   'maldito comunismo maldito socialismo salgan ustedes manada de borregos'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['oskarciber',
#   'por las víctimas del Paramilitarismo en Colombia NO MÁS NARCO PARACO URIBISMO'],
#  ['trampastejo',
#   'Petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['alejo2000_2000',
#   'Las marchas para el 15 de junio nos permitirá ver que tan letal es el virus sin confinamiento de las personas si el virus es muy contagioso y letal reducirá el número de manifestantes en el futuro cercano'],
#  ['OGalvisC', 'No más asesinatos justicia ya'],
#  ['oskarciber',
#   'NO MÁS NARCO PARACO URIBISMO ASESINO EN COLOMBIA 🇨🇴 NO más genocidios y asesinatos'],
#  ['OGalvisC', 'Justicia ya'],
#  ['Liliana09695487',
#   'yo no estoy de acuerdo con esta marcha no ven que estamos pasando por una terrible epidemia que ganan con eso propagar más este virus si no se hizo nada antes de esta pandemia mucho menos ahora alcontrario van a empeorar esto 😡'],
#  ['OGalvisC', 'Por los miles de líderes sociales asesinados justicia ya'],
#  ['Oscar08464952',
#   'si comparan el socialismo con desigualdad porque no equiparan el capitalismo con riquezas para todas'],
#  ['Angela9637', 'El verdadero y más peligro virus ves el estado'],
#  ['OGalvisC', 'Justicia ya'],
#  ['chocante25',
#   'por racismo y no se acuerdan que un señor metió varias personas en una iglesia y las quemó Lo más hijueputa es que esta con una curul en el Senado chimba de país'],
#  ['oskarciber',
#   'En Colombia cada día asesinan cobardemente Lideres Sociales defensores de Derechos humanos ambientalistas ex guerrilleros que dejaron sus armas reclamantes de tierras y no pasa nada NO MÁS INDIFERENCIA CÓMPLICE VAMOS A LAS CALLES'],
#  ['jorgelopez59', ''],
#  ['jorgelopez59', ''],
#  ['jorgelopez59', 'Hipocresía'],
#  ['OGalvisC', ''],
#  ['Angela9637',
#   'Despertar ya este gobierno farandulero y banquero Es un derecho vque tenemos'],
#  ['Edna_moliina',
#   'Ustedes lo que quieren es contagiarse de Covid 19 para culpar al gobierno y pedir mas ayudas'],
#  ['iSamuelES', 'Vamos'],
#  ['oskarciber',
#   'los del ESMAD saldrán a estrenar sus uniformes para reprimir la Protesta Social legítima mientras personal médico no tiene dotación para enfrentar Pandemia'],
#  ['SebazZz_14',
#   'Que impotencia no poder hacer ni mierda para evitar la hijueputa'],
#  ['Antonio163016',
#   'Vamos Colombia Entusiasmo Con DIGNIDAD y AMOR sin COBARDÍA'],
#  ['ReyLenidas3',
#   'Desde que la lo llama a indagatoria es porque tiene pruebas a la mano contra y ahora sí se le acabó el derroche porque se le vienen las otras con extinción de dominio'],
#  ['croactibo',
#   'Vamos apoyar a en esta marcha que sea multitudinaria que sea la marcha más grande nunca vista en Colombia con abrazaton besaton cojida de teta al aire de las feministas y tal Y que repartan hasta para llevarles a la casa de sus padres 🤣'],
#  ['oskarciber', ''],
#  ['algrano_ibarra',
#   'Las ganas de generar violencia son infinitas ACAB justicia para todo el mundo no al abuso de autoridad todos a las calles'],
#  ['oskarciber',
#   'en memoria aDilan Cruz y George Floy Asesinados por un Policía'],
#  ['Matto04981427', 'Cuenten conmi apoyo'],
#  ['JuanDiego_CG', ''],
#  ['JuanDiego_CG', ''],
#  ['Antonio163016', 'Contra estos sinvergüenzas también es la'],
#  ['elkin197628', ''],
#  ['Lachavitadel8', 'Recomendaciones para la primero la salud'],
#  ['JuanRicardoAgu8',
#   'de verdad piensan salir a una marcha Por las calles en 12 días Verdad hay alguien que lo va a hacer Pero lo más tenaz creen que sirve de algo De verdad'],
#  ['_sancheezp', 'Cómo sería entonces para la'],
#  ['Antonio163016', ''],
#  ['Antonio163016',
#   'La Puta de Babilonia quiere acallar los gritos de hambre de inconformismo QUIERE ACALLAR LAS MARCHAS'],
#  ['group_pepe', ''],
#  ['group_pepe', 'Trece días es demaciado tiempo pero hay estaremos'],
#  ['Antonio163016', 'Colombia'],
#  ['elkin197628', ''],
#  ['Leonorgs_24',
#   'Por él por nuestros afros por la brutalidad policial por la educación por la ñeñe política'],
#  ['Antonio163016', ''],
#  ['Antonio163016', ''],
#  ['Antonio163016', 'necesitamos de su energía al igual que el 8 12 2019'],
#  ['SebazZz_14',
#   'Me parecen las razones lo que no me parece es el momento para hacerlo ignoran por completo el tema'],
#  ['Arquiman2', 'ñeros peligrosos'],
#  ['Arquiman2', 'Saqueos'],
#  ['Arquiman2', 'Robos'],
#  ['RobertoMTico', 'TODOS A LAS CALLES Me sigues te sigo'],
#  ['septimoartecol',
#   'ESPECIAL 👩\u200d🎨 Parte 4 Edmonia Lewis 1844 1907 Escultora de origen haitiana y Ojibwe La Liendra'],
#  ['Merseysound23',
#   'Por Anderson Por Dylan por nuestr@s muert@s nos volveremos a encontrar'],
#  ['iam_jhoanp', ''],
#  ['bolivarjk',
#   'Ya es hora de sacar a la mafia del poder si queremos un futuro'],
#  ['ingdeas',
#   'Una mentalidad destructiva y poco sensata quieren el caos perse y tienen como forma de hacer política la primitiva búsqueda del odio'],
#  ['RobertChilito',
#   'Enrique Oramas Agricultor orgánico y productor de alimentos saludables Asesinado en su casa Ya son 100'],
#  ['RobertoMTico',
#   'ME UNO A ESTA INICIATIVA Un Estado en sus tres ramas del poder público completamente arrodillado a la cultura d la muerte al a la corrupción al narcotráfico a la compra d votos a la injusticia al sistema financiero etc SOLO MERECE DESPRECIO'],
#  ['iam_jhoanp', ''],
#  ['andrudel',
#   'Concuerdo con y en qué la situación no es la adecuada para la pero la situación del país indigna a la mayoría de los colombianos y las personas ya no aguantan más'],
#  ['Mar_Cherbonneau',
#   'Y a esto hay que sumar Incumplimientos del acuerdo de paz Políticas favoreciendo tenedores de mala fe Chuzadas ilegales del ejército cuyo destinatario es el señor Uribe Tropas extranjeras sin consultar al congreso Ingreso Solidario para artistas millonarios'],
#  ['Mar_Cherbonneau',
#   '¿Por qué NUNCA leo ni veo ni escucho Por pelmazos hipócritas y descriteriados como este tipo'],
#  ['Sroldang', 'Que de poder'],
#  ['GoDiegoGo017',
#   'Por la brutalidad policiaca Por Anderson Arboleda Por los líderes asesinados Por la corrupción de derecha e izquierda Porque solo marchando se sentiran acorraladas las ratas esas'],
#  ['iam_jhoanp', ''],
#  ['KillerDoge',
#   'Para todos los que ven y apoyan las marchas en Estados Unidos a causa de la brutalidad policial en nuestros paises pasa todos los días'],
#  ['iam_jhoanp', ''],
#  ['iam_jhoanp', 'Unamos esfuerzos para combatir lo que nos pasa en el país'],
#  ['Ferjoher1',
#   'yo marcharé porque ya me canse de que el matarife haga lo que se le dé la gana jarto del gobierno títere y de las porquerias que hace esa es mi razón'],
#  ['Numa08053160',
#   'Esa me lo mamá y estoy dispuesto a peliar con argumentos 😟'],
#  ['gonzzo91',
#   'Les recuerdo que las marchas son para que se haga justicia por el racismo y el abuso policial no para tomar cosas personales en contra de un lado político'],
#  ['Oscar08464952',
#   'no tenemos miedo no tenemos miedo matarife prensa arrodillada si no se ponen a favor del pueblo también para la mierda Hptas'],
#  ['KevinMarinOC', 'Ahora nos toca ha nosotros ✊🏼🖤'],
#  ['natsinpena',
#   'marica yo no sé si sea buena idea esta marcha Estoy entre sí y no tal vez no debamos no es el momento dado estamos en mitad de pandemia suerte a los que vayan cuídense mucho Psdt Será que pega tanto como el 21 de noviembre K nervios'],
#  ['Gar4780',
#   'Me preocupa que el sistema de salud está a punto de colapsar por esta pandemia y ante todo debemos evitar aglomeraciones Las protestas son un derecho pero bajo estas Circunstancias es irresponsable Por eso no apoyo la'],
#  ['LaTropaChibcha',
#   'entre otras por que Uribe debe pagar algún día por ser el jefe de corrupción y paramilitarismo mas grande que haya visto Colombia'],
#  ['didiersanchez26',
#   '5 tips no más en colombia no mas racismo no tropas estadounidense abuso de los policías colombiana la corrupción en plena cuarentena no mas violencia a nivel país colombiano'],
#  ['jhonnisjk',
#   'PORQUE NOS PROGRAMAMOS PARA ASER EL RIDICULO donde tenemos que salir a pedir justicia estamos hartos de el abuso de poder tanto como politicos como la policia que en ves de proteger lo que asen es lucrarse de la nesesidad ajena'],
#  ['ReyesSalmha',
#   'Por qué al igual que aquel periodista y líder para muchos Jaime garzón yo creo que esto tiene salvación Y somos nosotros la juventud quienes tenemos la dirección correcta hacia un mejor país'],
#  ['paissinyugos', 'reaccionaaaaa'],
#  ['Oscar08464952', 'que pena y Jesús también era comunista'],
#  ['momofronaldo',
#   'Si muy bueno lo de pero si lo van a hacer bien porque si es para alborotar por 5 días y después cada uno para su casa como todas las perras marchas de este país que no logran nada mejor se quedan y no arriesgan a un contagio'],
#  ['daniellozada99',
#   'A manifestar las inconformidades contra este inneficiente sistema político y económico creemos en la paz y los cambios radicales no se justifica ningún tipo de violencia'],
#  ['alexcrios1999',
#   'Tenemos miedo pero también queremos un mejor país un mejor futuro una mejor educación un plato donde comer una casa donde vivir una mejor salud Tenemos miedo pero este gobierno NOS TIENE QUE ESCUCHAR'],
#  ['wmejialo', ''],
#  ['RumikoStephanie',
#   'Lo sé y estoy de acuerdo Pero considero que n este momento son importantes nuestros padres abuelos e hijos Ellos serían los perjudicados No el gob Y Obvio que a las calles debemos volver para que seamos escuchados Pero no poniendo en riesgo a los nuestros'],
#  ['Marcha15deJunio',
#   'Un botellazo en la cabeza de un patrullero de la Gloriosa acabó su vida'],
#  ['ssssssebas',
#   'Si de veras supieras por qué criticamos al gobierno los que promovemos la borrarías este tweet'],
#  ['Anascupar',
#   'Le dije a mi mamá Gorda si hay que salir a marchar acá tú sabes que yo tendré que salir verdad Ajá pero llevas tapabocas y no te toques mucho la cara Si mami me compro la careta de la gorra'],
#  ['Marcha15deJunio', 'En Colombia el racismo también es sistemático y letal'],
#  ['Marcha15deJunio', ''],
#  ['Marcha15deJunio', ''],
#  ['RumikoStephanie',
#   'Critican al gobierno porque no consigue que la gente respete la cuarentena pero van a salír el 15 de Junio En fin la hipertensión XD'],
#  ['Marcha15deJunio', 'Caerá el que dio la orden'],
#  ['Marcha15deJunio', 'Colombia se cansó'],
#  ['CAROLINAD10A', 'Recuerden no hay tanqueta pa tanta gente'],
#  ['AngieVal2226',
#   'Hay que luchar juntos por El amor la paz la igualdad el respeto el país y NUESTRO PUEBLO Maldito sea el soldado que apunte su arma contra el pueblo Simón Bolívar'],
#  ['Likar105',
#   'vamos Salgamos a las calles Exigimos nuestros derechos Justicia social La brutalidad de la fuerza pública Los falsos positivos que se activaron otra ves'],
#  ['stevenoosd',
#   'no estoy de acuerdo con que salgan a marchar en estos momentos si no lo hicieron antes de la pandemia ahora si piensen en sus familias marchar ahora solo hará aglomerar más personas e incrementar más casos y más muertas por el virus Quédense en casa'],
#  ['TenoriKoi',
#   'Quería hacer una lista de razones para marchar pero ¿en serio hay que nombrarlas ¿hay algo bien en este país ¿en serio no vamos a cambiar Muy lindo que apoyen protestas en otros países pero a ver si hacemos algo con el nuestro y apoyamos al mismo pueblo'],
#  ['juanshootss',
#   'Los héroes en Colombia si existen y son esos mismos que por empatía con el cuerpo médico no saldrán a la a contagiarse u colapsar el sistema de salud crack'],
#  ['ldsjota16', 'todos son todos'],
#  ['Harol72860060',
#   'Cómo todo en este país ¿ Que hacemos nosotros para mejorarlo Criticando e insultando no hacemos nada'],
#  ['Harol72860060',
#   'Protesto por las Miles de familias que hoy en día están esperando a sus familiares desaparecido protesto por la muerte de muchos líderes sociales por estás y muchas razones más'],
#  ['CamilaL75539792',
#   'Yo marchó por la Colombia olvidada donde los crímenes no salen a la luz pública donde el estado solo llega en forma de guerra y represión Donde los grupos secretos del estado águilas negras desplazan asesinan violan e imponen su feudalismo moderno'],
#  ['YesicaMylano',
#   'en serio bueno con tanto desocupado un 20 de desempleo se entiende pero la verdad espero que UNA marcha traiga alguna solución de los enormes problema que tenemos ahora una marcha pacifica y no violenta'],
#  ['peznaranjaTweet', 'Ya te lavaste las manos'],
#  ['Leonard20514252', ''],
#  ['gloqui20',
#   'A esos brutos de la les recuerdo que la marcha feminista en Madrid fue la que ayudo a regar el virus y los llevo al pico Tienen toda una vida para protestar no cuando vamos para el pico de una pandemia No se les pudo ocurrir en peor epoca Idiotas'],
#  ['Leonard20514252', ''],
#  ['AhhDiga',
#   'Marcha marcha marchaaaaaa 🙏 pero que se infecte todos los marchantes por favor 🙏🙏🙏🙏🙏#Marcha15DeJunio'],
#  ['alterahuevos', 'Yo marcho por ellos porque merecen justicia'],
#  ['AhhDiga',
#   'Eso marchen pero eso si Infectence todos Oooosssss 🙏#Marcha15DeJunio'],
#  ['fulrecos7',
#   'No se sabe que es peor en 🇨🇴 si morir de Covid o Morir de hambre'],
#  ['alterahuevos',
#   'Yo marcho porque estoy cansada del abuso de estos que dicen proteger al pueblo y lo único que hacen es reprimirlo y matarlo'],
#  ['otratremenda',
#   'Y así como tanto le indignó la muerte de George Floyd que me duela también su país Anderson Arango asesinado de un bolillazo por un policía en el Cauca Que no se derrame más sangre inocente Queremos justicia'],
#  ['Migux_0',
#   'prefiero que un virus acabe conmigo y mi libertad a que un estado injusto y corrupto lo haga justicia es lo que necesita Colombia y el mundo entero por sobre cualquier virus el humano sin libertad no es humano'],
#  ['MiguelCab1989',
#   'Me gustaría saber qué opina sobre este ridículo HT dejen de buscar lo que no se nos ha perdido Esto del Coronavirus apenas está empezando'],
#  ['UnBufonMas',
#   'Si si y si de una u otra manera nos tenemos que hacer escuchar y que sepan que ya estamos cansados de lo mismo y de los mismos'],
#  ['Certero331',
#   'piden las hordas petrofarcistas castrochavistas FARC HISTORIA PLAGADA DE CRÍMENES ATROCES Al Secretariado FARC le perdonarán 16 siglos de cárcel'],
#  ['Cristhi96660434', '¡SALGAMOS A LAS CALLES EN UNA SOLA VOZ'],
#  ['Sthefania_820', ''],
#  ['ElgritoAfroo',
#   'El gobierno duque Uribe debe caer el abuso policial debe caer el racismo debe caer el machismo debe caer la violencia de genero debe caer la homofóbica debe caer la corrupcion debe caer y para que caigan nosotros nos debemos levantar'],
#  ['FelipeM22851767', ''],
#  ['Juanpineda2802', 'Algo así creo que pasará en los noticieros'],
#  ['ColombiaStyle', 'Así se estará realizando los test para Covid20 en la 🌡'],
#  ['monotovar1989',
#   'Se pueden es infectar todos en esas marchas y puede pasar qué ya tenga el 100 de camas UCI’s y respiradores copados Para qué entonces las marchas del 15 sea pero de cajones'],
#  ['DavidGamezXD', '¿Y si mejor cierras em hocico y te unes a la marcha'],
#  ['Cristiancami_lo',
#   'Las revueltas sociales de las grandes capitales del mundo deben servir como aliento a este país marginado por una moral conservadora clasista y opresora'],
#  ['josedcuellars',
#   'En Florencia Caquetá un hombre presuntamente violo a un niño de tan solo 8 años algo más para la'],
#  ['ImHenao', 'Yo no marcho por el virus osea guevon'],
#  ['Andreafiresb',
#   'Si porque el país esta cansado de tanta corrupción y violencia orquestada por el estado ñeñepolitica fiscal de bolsillo asesinatos de lideres abuso policial cartel del covid y muchas injusticias mas 🚫'],
#  ['Pipec_137',
#   'sin falta y tempranito estaré allí marchando a todo pulmón y de todo corazón'],
#  ['1970Yesid',
#   'Por lo general al año se robaban 50 billones Pero el par se picaros y carrasquilla Rompieron guinnes record en dos meses de curentena ya los desaparecieron'],
#  ['Daniel_stikk',
#   'NO AL RACISMO NO A LA HOMOFOBIA NO A LOS FEMINICIDIOS Y ACOSOS NO A LA MATERNIDAD OBLIGATORIA'],
#  ['monotovar1989',
#   'Lo malo es que el tiene una tasa de letalidad baja De un 5 a un 7 maximo Si usted tiene un hijo que es mantenido y mamerto y quiere ir a el 4 y 12 y ya sabe Claudia ya tiene casi el 70 de UCI’s ocupada'],
#  ['arleytrujillo7',
#   'tod@s a las calles No falta esa persona q dirá q es por petro 🤦\u200d♂️ lucha es por nuestros derechos q nos están vulnerando'],
#  ['NatalyMora_',
#   'Por eso estaré prénsenle en la porque estoy cansada de la injusticia cansada de sentir impotencia por no poder hacer nada por aquellos que alzan su voz y mueren por eso saldré a las calles a luchar por mi futuro y el futuro de mi país'],
#  ['Laubassmusic', 'Por Dylan por Alejandra por Anderson'],
#  ['Sttteven_', 'Como putas harán una marcha aca en Colombia'],
#  ['snavarro161',
#   'Para el gobierno La muerte de un hombre es una tragedia y La muerte de millones es estadística'],
#  ['LeFaltaLaC',
#   'todos los que salgan a mariquear el 15 deberían dejar estipulado que no se les permita ocupar una cama de UCI cuando les pegue el virus'],
#  ['atomocartun', 'La pirámide'],
#  ['Don_Juan62', 'Jajajajaja la peinada que le pegaron 😂😂'],
#  ['ElDaIaiLama',
#   '¿Alguna duda de que El Cacas estuvo en Cuba definiendo con su círculo regional cuál será agenda de los próximos meses para seguir quemando el país Añora que el sistema de salud y la economía colapsen Zombies ñeros listos a sus órdenes es lo que sabe que tiene👇🏽'],
#  ['Alexeprz',
#   'Bueno creo que influenciamos a petro se supone que el apoye es la oposición 🤷\u200d♂️ igualmente te quiero recordar que inicio en fb con una publicación de un ciudadano x'],
#  ['killingMe_boy', 'Este 15 de junio también salimos a marchar por Alejandra'],
#  ['Oscar08464952',
#   'ustedes conocen algún colombiano que haya libertado ha nuestro pueblo de la opresión Ni bolivar ni benkos biohó fueron paridos por esta tierra de cobardes'],
#  ['fungusxxs', 'Esta mierda no se justifica 🌲⚒'],
#  ['Gav_LoM', 'Yo a punto de salir rumbo a la por Narnia Mamá'],
#  ['sszzz__', ''],
#  ['d_padilla_93', ''],
#  ['Anahismr6',
#   'En Colombia hay una marcha el 15 de junio en contra del racismo no podré asistir por mi familia recuerden llevar tapabocas cuidarse y gritar SOBRE TODO GRITAR Y EMPRENDER ESE RUMBO AL CAMBIO SOCIAL E IGUALDAD TQM'],
#  ['BCertuche',
#   'Mi estimado señor si su compresión lectora es mala mediana o buena podrá entender que me refiero a que sigan posteando con el hastagh porque es el el que vale en este momento El senador se une a postear por la tendencia en qué se convirtió'],
#  ['Oscar08464952',
#   'Quién se iba a imaginar que el covid 19 era nuestro Simón bolivar'],
#  ['OscarPavi',
#   'Los padres de familia que enseñan a sus hijos en casa pueden marchar con Fecode 😅😅😅'],
#  ['profet538', ''],
#  ['Fredy_GuerraA', '✊🏾'],
#  ['Davinci_Hugh',
#   'Los hijueputas que pedian el fin de la cuarentena ahora quejándose de la No más abusos de la policia ejercito No más líderes sociales asesinados Por Dilan y Anderson ✊✊✊✊✊'],
#  ['oropesatoledo',
#   'no tiene que ver nada en pero le dice que lo postee jejejeje muy coherente'],
#  ['kukoflowpaisa',
#   '🗣️ ESPEREN UN MOMENTO TíTERES Uno de sus Lideres el Doctor Bobolivar les quiere decir algo o Quizás Ya No'],
#  ['OscarPavi',
#   'Salgan a marchar con proyectos productivos y de generar empresa en las manos no con una piedra y banderas comunistas para que todo se lo regalen'],
#  ['rolistongs',
#   'Los héroes en Colombia 🇨🇴 si existen y son todos los que usan su voz son todos los estudiantes líderes sociales docentes y cada una de las personas que lucha por un país diferente LA MISMA LUCHA DEL 21N PERO CON PRUEBAS 🔥🔥'],
#  ['andrespaz1',
#   'Este país no aguanta más El corrupto y ladrón La asesinando jóvenes y maltratando ancianos y el presidente gobernando por decreto y regalando plata a los bancos Hay que levantarse y luchar'],
#  ['ColProgresista',
#   'Existen muchas razones para salir a la 1 Asesinatos a lideres sociales 2 Abuso Policial 3 Corrupción en colombia y sobrecostos en la pandemia 4 Agro ingreso seguro 2 0 5 Violación de la soberanía en la llegada de las tropas americanas 6 Ñeñe política'],
#  ['GoldenC34634053', 'Esto es increíble Colombia'],
#  ['sacamargov',
#   'creo que esto no se da en un momento bueno Son algo estúpidos en cuanto a la convocatoria en estos momentos aunque las razones son muy válidas'],
#  ['GoldenC34634053', 'Esto es increíble'],
#  ['OscarPavi',
#   'Con esta marcha fortalecerán al gobierno nacional la gente del común entenderán que solo les importa vandalizar el comercio y generar el caos'],
#  ['lnicorojasl',
#   'Otra marcha fracasada para darnos golpes de pecho de que despertamos Y la siguiente pa cuando Pa l 15 de julio Yo veré Por el andén bolitas de pintura para el congreso y piedras para el local del ciudadano'],
#  ['watosyss',
#   'Que esté bien la protesta pero sino se comportan bien se van del culo para el estanco con el covid Ese les protesta por camas en las UCI'],
#  ['camilo58466717',
#   'Tenemos miles de motivos desde los años 90 la historia de colombia la domina la Violancia'],
#  ['LaPocholina',
#   'El es real que mierda les pasa Ahora En es serio ey Jodanse todes de verdad es lo más estudiado que se puede hacer en estos momentos pero bueno ahora si en plena pandemia coman mucha mierda'],
#  ['littledaughte11',
#   'Ya que tanto les gusta desobedecer las indicaciones de no salir debido a la pandemia ¡ENTONCES SALGAN pero con motivos de sobra no por cacorradas'],
#  ['OscarPavi',
#   'El Virus nos demostró que tenemos un sistema de salud muy bueno comparado con otras naciones Pero como nos les conviene eso los izquierdosos lo quieren colapasar'],
#  ['Aana31378828',
#   'La es totalmente entendible y necesaria pero hay que tener en cuenta varios factores como 1 Va a pasar como 21N donde nada pasó por que la gente no sabía ni por qué marchaba 2 El pico de contagio va a aumentar hablando desde la lógica'],
#  ['And_mellet', ''],
#  ['Elian_Dv15',
#   'Yo no sé si es que me estoy volviendo locó o es que está pasando de todo en este hijueputa año 🤦🏻\u200d♂️ QUE MONDAA 🤦🏻\u200d♂️'],
#  ['OscarPavi',
#   'Espero no ver a en los noticieros explicando el cerco epidemiológico de las marchas 😅😅😅'],
#  ['GodDragonSlifer',
#   'El silencio del Inpec sobre el motín de La Modelo Después de las 7 horas de angustia en La Modelo los familiares de los 24 internos muertos y 83 heridos muchos con heridas tiros de fusil tuvieron que enfrentar un silencio del Inpec'],
#  ['OscarPavi',
#   'Si deja realizar la marcha se entenderá que nunca le importó la salud de los Bogotanos solo su carrera política'],
#  ['CastanoValbuena', 'Las razones sobran'],
#  ['JorgeAJ9',
#   'Si no eres de Colombia no opines porque no sabes la realidad ni la has vivido si por el contrario eres de Colombia o vives acá entonces no sabes nada Mejor cállate el hocico 🤫🤐 🤭✌️☮️'],
#  ['JeissonDuenas',
#   'El ESMAD se va a dar gusto estrenando toda la compra que les hizo duque'],
#  ['andrudel',
#   'Quiero ver a los mismos que están indignados con lo qué pasa en EEUU apoyando esto'],
#  ['DianaMHurtado',
#   'Los colombianos somos tan cagados que no salimos de inmediato sino que hay que esperar la tal'],
#  ['OscarPavi', 'Ya entendemos los fines de la reunión en Cuba'],
#  ['CindySarmientoZ',
#   'Bueno ahora que los que convocan a la repartan las máscaras y los tapabocas'],
#  ['OscarPavi',
# ...
#  ['GuilleSwd', ''],
#  ['KIKERIV56583861', '💪🏾🇨🇴'],
#  ['EnriqueTeacher1',
#   'cuántos asesinatos debe cometer la policía para detener este país'],
#  ['christian_atlh',
#   'ya que es incapaz de controlar marchas y controlar el Covid propongo que rocíen con desinféctate a los manifestantes'],
#  ['Horacio57527276', ''],
#  ['FranciscoA_L',
#   '¿Es en serio lo de la Sus promotores de forma mezquina van a hacer que se contagien y posiblemente mueran miles de ciudadanos Que bajeza'],
#  ['PatriciaDurn11',
#   'George Floy levantó EEUU En Colombia 347 ASESINATOS desde 2018 Duque y 88 2020 Q esperamos q nos maté el Matarife el Virus el hambre Juego mi vida d todas maneras la llevo Pérdida'],
#  ['andersoncasta16', 'de una'],
#  ['Lvcastillog',
#   'Ridículos la gente no entiende por la pandemia que estamos pasando y la cantidad de contagiados Muchos quieren activarse en sus empresas en su día a día todos queremos salir de este encierro de una vez por todas POR FAVOR DEJEN DE INCENTIVAR ESTA MARICADA'],
#  ['Ceblue101',
#   'El que convoca a esto o es Uribista o es la persona más estúpida de este país'],
#  ['Mediarse',
#   'Duque alargará la 40rentena por las protestas que están por estallar en toda Colombia Lo de contener el virus ya no va a ser lo importante'],
#  ['Anglica14128255',
#   'Por nuestros muertos ni un minuto de silencio ¡A las calles'],
#  ['soysantialarcon',
#   'después aumentan los contagios y ahí si lloran esos líderes que se aprovechan de la nobleza de sus seguidores producen rabia'],
#  ['Ritmica_Roja',
#   'porque si no nos mata el virus nos mata la inequidad 🦠୧ ಠ Д ಠ ୨'],
#  ['CarolGonzalez5', ''],
#  ['Juanchocar80',
#   'vamos con toda el futuro es de los valientes he inteligentes acuérdense de salir sin tapa bocas y cogidos de la mano siii se puede'],
#  ['_castrosebas', 'Yo me apunto ♥️'],
#  ['slayingrocky',
#   'Dios mío por favor que mi mamá me deje ir a la marcha del 15 de junio'],
#  ['Cletrado10',
#   'En plena pandemia es completamente ilógico proponer Esta claro que hay que seguir protestando pero hay que cuidar la salud de nuestros familiares'],
#  ['JuahnPis', ''],
#  ['Venusislife_',
#   'No más racismo No más homofobia No más feminicidios No más acosos No más violaciones a nuestros derechos Basta de ignorancia'],
#  ['WilliamAFGarcia',
#   'pero que no incluya cacerolazo ni besaton y que no termine convirtiéndose en un festival recreativo'],
#  ['Felipe_sa_c',
#   '¿Y si mejor iniciamos un levantamiento cívico basados en nuestras propias luchas Porque salir a la calle a pintar ACAB y FuckThePolice no es nuestro culturalmente no despierta nada'],
#  ['MateRodriguezB', ''],
#  ['Joserextirano',
#   'Los mamertos son tan brutos que primero exigieron que se decretara la cuarentena por mas de 60 dias con los cual se aumentaron los indices de pobreza ahora quieren contagiarse en forma diciendole a su sequito de idiotas'],
#  ['DraGranadilla',
#   'Veo el luego pienso en lo reventados que estamos tratando de contener esta mierda y pues'],
#  ['ManosLimpiasCo',
#   'Protesta con distanciamiento interpersonal daría dos mensajes que si podemos con el auto cuidado y que no somos pendejos'],
#  ['marlyntuiran', ''],
#  ['DORIACABRERA', 'Con todo a la'],
#  ['posso0654', ''],
#  ['FelipeV2210',
#   'Hasta que la DIGNIDAD se haga costumbre No más abuso policial No más Escuadrón de la muerte No más lideres sociales asesinado'],
#  ['OrtizDirley', 'Yo estoy listo marcho por mis hijos y marcho con mis hijos'],
#  ['Diego_Ibarra13',
#   'Ojalá todos los que se andan quejando del en Estados Unidos tengan la valentía de salir este 15 de Junio a la'],
#  ['danovislozano', 'En Colombia el racismo también es sistemático y letal'],
#  ['Estrada0222',
#   'La verdad si viviera sola no me la pensaría para salir a marchar Pero como no ni de chiste No voy a exponer a mi familia al puto virus'],
#  ['alexreyescast', 'Cuando y son HIPÓCRITAS'],
#  ['anibalom', ''],
#  ['ComiteDeParo', ''],
#  ['StefanBravo3',
#   'Soy Moisés galan Gaitán un pueblo ahora marchen por nuestro líder social EEUU Increíble tanta estupidez petrista'],
#  ['oscarabeja',
#   'Que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['oscarabeja',
#   'Que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['tomatetrip',
#   'casi que no El Gobierno sosteniendo la cuarentena a punta de mentiras y decretos cual dictadura dejando más que claro que no les importa nuestra salud sino su bolsillo El 15 nos vemos'],
#  ['PasosPazzini',
#   'No nunca se saldra de la eterna cuarentena Quieren bajar los contagios Cuidense y mantengan el distanciamiento social Las cosas se arreglan en las urnas se arreglan con inteligencia no con manifestaciones multi propósito sin objetivo claro'],
#  ['oscarabeja',
#   'Que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['Marcosval01',
#   'Sera que este es el verdadero proposito Sacrificar a los idiotas utiles del socialismo para aumentar el número de contagios'],
#  ['CamiloPinzn17',
#   'Alcaldes robando mercados sobrefacturando Ingreso solidario para muertos los médic@s y enfermer@s sin sus trajes el desempleo por las nubes la Policía abusando de su poder entre otras Que estas razones te muevan pero sal con los cuidados necesarios'],
#  ['_Jack_Naipe',
#   'Y como acá nos gusta darle largas a todo esperen una carentena general antes de la'],
#  ['robertoortega02', 'El COVID_19 esperando la'],
#  ['HijueputaCasa', 'sin miedo'],
#  ['CSarahelenht',
#   'Pido a todas las personas que van salir a con justa razón que piensen en todos los daños colaterales que esto dejará Cargaremos con un genocidio en nuestras espaldas y haremos quedar a los tiranos como héroes'],
#  ['CamiloMejaR1',
#   'Muchos dicen que es ignorante salir a marchar mientras estamos en el pico de la pandemia yo digo que es ignorante dejarnos manejar por la corrupción y el abuso de poder'],
#  ['HHsotelo27', 'No me imagine que el rencuentro seria en una marcha'],
#  ['lispinmaya',
#   'No entiendo a la gente si salen a marchar solo conseguirán que hayan más muertos piensen en que cuando vuelvan a sus casa van a estar sus padres tíos abuelos hermanos los jóvenes no somos inmunes es nuestro deber cuidarnos y a nuestros seres queridos'],
#  ['Piensa__', 'Irresponsable es no hacer nada y quejarme en redes sociales'],
#  ['nana56973518',
#   'salgan vagos bandidos flojos ridículos irresponsables y demás estúpidos'],
#  ['Dannapa10653407', 'Asi es'],
#  ['FCarri',
#   'Los invitó a buscar otras formas de manifestarse Hay que hacerlo Pero reventando el sistema de salud los contagios y con muertes de manifestantes solo benefician el status quo Mejor un cacerolazo o semejantes Oigo ideas'],
#  ['JuanLindarteP',
#   'Con esto de la se comprueba que más se demoraron en enviar el vuelo humanitario para traer a que este en desplegar las ordenes recibidas por parte del eln para vandalizar nuevamente el país'],
#  ['Sansarita',
#   'se alborotaron los bodegueros Vayan pues qué el covid haga una buena limpieza social'],
#  ['memitodiez',
#   'Si la la van a hacer con bozal y distanciamiento apague y vamonos Me decantaría mejor por la de anden y festivo'],
#  ['Sombreroooooo',
#   'Tengo tantas cosas porque marchar que no sé cuántas pancartas llevar Que gonorrea que todos los sistemas y sectores estén en la mierda en este País'],
#  ['SoyMonicaMar', ''],
#  ['ElCapucchino', 'razones sobran no dan ayudas pero dan bolillo'],
#  ['Antifa55460356', 'democracia usurpada por el gobierno fascista'],
#  ['jostin_panza',
#   'Espero que la no sea violenta eso lo único que provoca es el desprestigio del movimiento y se opaca el mensaje del mismo'],
#  ['CataGaviiriia',
#   'Ojalá no mal entiendan mi punto porque yo estoy muy firme apoyando esto pero siempre nos ponemos a esperar y estas cosas son ya'],
#  ['SebastinForer15',
#   'NO NOS DEJEMOS VER LA CARA SALGAMOS A LAS CALLES A RETOMAR EL 21N PERO CON MÁS RESISTENCIA MÁS FUERZA Y MÁS FURIA A PELEAR POR NUESTROS DERECHOS'],
#  ['Laura_Rod10',
#   'creí que era broma pero hay gente que lo apoya de verdad Definitivamente la estupidez humana no conoce el límite'],
#  ['Soniaguer',
#   'todos a contagiarnos que con los problemas que tenemos no es suficiente'],
#  ['Baub__', ''],
#  ['iLordPorky',
#   'Les da miedo salir a buscar trabajo pero Gustavo Petro los manda a marchar y la pandemia no existe'],
#  ['DSOTELOZ', ''],
#  ['richar10rock',
#   'Los Dioses de las marchas son los gringos ellos sí tienen adrenalina lo llevan en la sangre AGUANTE U S A 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🤘'],
#  ['Os56351001', 'Policía CRIMINAL'],
#  ['BizarroMesa', '✊🏽'],
#  ['JorgeMr_Paez',
#   'esto fue que fue petro a Cuba a planear que iba a hacer y miren con la que salió'],
#  ['ili_llanos',
#   'Eso de me parece la estupidez más grande Como es que en plena pandemia van a convocar miles de personas a aglomerarse ESA NO ES LA FORMA'],
#  ['wilson9503',
#   'Esto se debe tener muy en discusión de la forma política que quieren tomar esta consigna mucho cuidado'],
#  ['Cloqlitos',
#   'Tú yo una marcha por los derechos de los ciudadanos no sé piénsalo chiquibeibi 😳'],
#  ['gersonpailitas', 'Va a volver trizas el sistema de salud'],
#  ['karenel11199500',
#   'Me pregunto qué piensa el personal de salud a que convoquen'],
#  ['Ribartolo',
#   'Jodian y jodian para que no levantaran la cuerentena porque todos iban a morir y ahora van a jajajaja esa coherencia me encanta'],
#  ['GigiVirviescas',
#   'porque si no nos mata el virus nos mata este gobierno nos mata la indiferencia'],
#  ['nataliabenavidd',
#   'En serio 🤦🏼\u200d♀️ Motivos sobran SI pero NO es el momento'],
#  ['escuelathemrdog', 'Gobiernos de mafiosos con la biblia en mano'],
#  ['lord17572',
#   'Señora Alcaldesa claramente por la pandemia no se podría autorizar una marcha verdad'],
#  ['Piensa__', 'Por la defensa de nuestros derechos humanos también marcho'],
#  ['Oscar_GCh',
#   'Me acuerdo cuando todos le recordábamos al que tenía 276 investigaciones Meses después Él H P completa 300 ¿y todavía se atreve demandar con el fin de protejer su buen nombre'],
#  ['CataGaviiriia',
#   'Mi duda es ¿por que vamos a esperar hasta el 15 para salir a marchar De aquí a allá se inventan algo para desviar la atención en mi opinion deberíamos dejar de darle tantas largas a las cosas que se note de verdad que estamos emputados'],
#  ['RAFAELF02343473',
#   'Es justo y necesario más de 100 leyes aprobadas a puerta cerrada sin control político y hablan de TRANSPARENCIA y luego el gringo llega a violar niñas y DUQUE se limpia el culo con la constitución no más DICTADURA CORRUPTA NARCO TRAFICANTE PARAcolombianos'],
#  ['Perreoapocaluzz', 'estoy preparado y listo hasta mi mamá va a salir'],
#  ['SantiMoncada_', 'allá los espero 💪'],
#  ['rozo_juan',
#   'Toda la izquierda puede salir a la que la selección natural se encarga del resto 😘'],
#  ['carduar1',
#   'Una en donde no se sabe si marcharán la gente civilizada o los violentos como siempre dañan todo'],
#  ['Antifa55460356',
#   'Es hora de levantar nuestras voces frente a los líderes sociales asesinados el desempleo y el hambre del pueblo oprimido temas pasados desapercibidos por una pandemia'],
#  ['Carlosbedoya_',
#   'Por los asesinatos diario de lideres sociales por la corrupción de alcaldes y gobernadores por la ñeñepolítica etc 🇨🇴'],
#  ['Juanding',
#   'En colombia también la policía nos mata pero acá a nadie le importa'],
#  ['LazyProfe', ''],
#  ['lunapower88', 'Really'],
#  ['CSarahelenht',
#   'La verdad hay que decirla Sería muy hipocrita de nuestra parte criticar al gobierno por reactivar la economía mientras nosotros promovemos una marcha empezando el pico de la pandemia Amigos sin impulsividad No apoyo'],
#  ['CnprCol',
#   'A las calles las veces que sea necesario por nuestros muertos ni un minuto de silencio 🔥🔥'],
#  ['Camarada109',
#   'Llego la hora de despertar es inaudito que sigamos dejando a los que juegan a ser Dios en Colombia seguir con este régimen de terror'],
#  ['Juandatorres24',
#   'Por las politicas neoliberal de por los 9 mil millones de pesos que se gasto para sus camionetas blindadas por la invasión de los militares gringos en Colombia por todo eso yo marcho este'],
#  ['Gaso40321953',
#   'pregunto Petro Claudia y sus compinches a quien le van a echar la culpa por el aumento exponencial de contagios y muertes de adultos y abuelos producidos por los adolecentes que envian a las calles y que van a llevar el virus a sus casas ADuque A Uribe'],
#  ['fsalasparra',
#   'un festivo no es fecha para una marcha 🤦\u200d♂️ de igual forma necesitamos un cambio y para eso tenemos que seguirla el martes miércoles y los días necesarios aprendamos de los gringos una semana seguida en las calles aprendamos de Ecuador y Chile todos los días'],
#  ['matarife82', 'Marchamos por esto maldito paramilitar'],
#  ['DianitaMartin',
#   'Definitivamente está vez digo Desde casa podemos protestar'],
#  ['La26974565', 'Gritemos juntos'],
#  ['gracias_uribe', 'MAMERTOS HIJOS DE PUTA'],
#  ['EliabRangel2', 'Muy pronto en Colombia'],
#  ['Dannapa10653407', ''],
#  ['barbie_ensus30',
#   'Ojalá a la se unan de alguna forma los abogados litigantes Llevamos más de dos meses sin juzgados parece que se nos olvidó que la administración de justifica es un servicio público y el acceso a ésta un derecho fundamental'],
#  ['Son15Letras', 'En nuestras redes ¿Pa qué Es en la calle y por millones'],
#  ['lord17572',
#   'Eso salgan a marchar el 15 y así tendremos cuarentena hasta bueno quien sabe hasta cuando y después peleando por qué la economía y muchas cosas están mal'],
#  ['Oscar_GCh',
#   'Aquí uno de los pestilente abogados del mal en épocas cuando el razocinio lo acompañaba Hoy que pensará al saber que el perfilador de periodistas y PATROCINADOR de paramilitares a quienes entrenó Yair Klein es el'],
#  ['DotorMataLawyer',
#   'Esos mismos fanáticos son los convocantes y posibles marchantes de la que por supuesto'],
#  ['Esteban55603333', ''],
#  ['Vlad_xciv',
#   'Han sufrido por el control y la opresión que les han infundido por algo que ha existido millones de años ha sido la excusa perfecta para jugar con tus miedos y confinandolos en casa frente a una caja diciendo supuestos y entreteniendolos todo esto es pura falacia'],
#  ['Son15Letras',
#   'pero todos sin pendejadas y con constancia Un solo día no un solo día no sirve de nada'],
#  ['elunicoeldivino', 'Estas son las razones a favor de la Favor de y hacerlo'],
#  ['Avargasg131',
#   'En Colombia tenemos mil vainas por las cuales protestar Sin embargo marchar en medio de una PANDEMIA donde la principal arma es el aislamiento y distanciamiento social las convocatorias resultan bastante irresponsables'],
#  ['LcolombiaM', ''],
#  ['JuanDavidC_',
#   'Por Anderson por Dylan por la corrupción con las ayudas humanitarias en esta crisis del covid19 por los líderes sociales que son muchos por el sistema de salud tan pésimo que tenemos y por cientos de cosas más'],
#  ['peznaranjaTweet',
#   'Peznaranja LAB es el sistema de tus sueños ya sea que tengas un negocio pequeño una megacorporación o tu oficina LAB es la mejor opción'],
#  ['brayanprieto95',
#   'Definitivamente la inconsciencia moral de la gente en plena cuarentena y piensan marchar claro sigan como borregos a los que quieren que esto estalle y por fin empiecen a haber muertos en las calles Al fin y a cabo un pobre menos para ellos'],
#  ['dana13_31', ''],
#  ['SoyMonicaMar', 'el 30 de junio'],
#  ['JUANBABYLAN', 'Que falla ponerle fecha a una marcha 🤦🏻\u200d♂️'],
#  ['Estrella_Calva',
#   'comparto tu opinion se unio todo el mundo para apoyar a Estados Unidos y quien nos apoya porfavor los que tengan influencia ayudar ayuden que nos escuchen'],
#  ['mochilaWayuu',
#   'o se marean Si nos vamos a marear que sea por el lacrimógeno mientras protestamos por lo nuestro'],
#  ...]

# %% [markdown]
# - ## Function to convert tweets in lowercase

# %%
#This function lowercase tweets for language processing
#Input: List of tweets to be processed
#Output: List of processed tweets

def lower_case(list_text):
    list_lower_case = []
    for i in list_text:
        word = i.strip()  #The strip method returns a copy of the string by removing both leading and trailing whitespaces characters
        new_word = word.lower()
        list_lower_case.append(new_word)
    return(list_lower_case)

# %%
tweets = lower_case([text[i][1] for i in range(len(text))])
text = [[users[i],tweets[i]] for i in range(len(users))]
text
# Out:
# [['DiegoTorresCast',
#   'marchas programadas para el 15 de junio en plena pandemia definitivamente la insensatez reina en colombia'],
#  ['dariocaicedo0',
#   'vamos a marchar nadie se va enfermar xd todos estaremos con muchos cuidados'],
#  ['dariocaicedo0',
#   'ok vamos a regresar a marchar bien chimba hp contra este gobierno de mierda'],
#  ['rockero1901',
#   'no podemos dsrle espera a las causas sociales es sierto que enfrentamos una pandemia pero y las muertes a causas de las fuerzas armadas q deberian cuidaenos la cuarentena que es un privilegio de clases la corrupción la de forestación el abandono con toda15'],
#  ['Insurrsion',
#   'los uga uga cavernícolas onvres y mugerez que se oponen a la son los que comen como borregos de rcn y paracol'],
#  ['Antonio163016', ''],
#  ['Margari97231178',
#   'la hipocresía de los noticiero colombianos vendidos y corruptos'],
#  ['DePorDiosMayer',
#   'avisenme si esta vez si vamos a tomar en serio la protesta y vamos a armar una verdadera revolución porque si es pa tomar chocolate con los del esmad prefiero quedarme en mi casa gracias'],
#  ['Paozroca1',
#   'no salgo a marchar por nuestra salud pero no significa que no levante mi voz de protesta por todo lo que está mal en este país usaré mis redes sociales como medio para protestar'],
#  ['Carolin15498454',
#   'no seas como que sólo apoya a usa tenemos que hacer algo por el país'],
#  ['CazaSarcasmos',
#   'y en que cambia el país no a la marcha del 15 de junio respeto la vida de los médicos'],
#  ['licethpao123',
#   'el gobierno empezará una semana antes a aplacar la curva del covid19 y después de la marcha aumentará la cifra de contagios 🙄🙄nuestra polombia sumergidos en la ignorancia de la ultraderecha'],
#  ['ETV1122',
#   'no que les pasa son retrasados mentales o que¿‽ ya estamos en bajada de casos no hagan eso háganlo después cuándo tenga suficiente neuronas para pensar y que aprenda a tender la cama no se tiren más el país'],
#  ['Astro27350111',
#   'yo voy a demandar a el presidente por vulnerar mis derechos si me muero de hambre el presidente tiene la culpa y si me muero por covid 19 es por que el precidente se robo la plata y no hay respiradores'],
#  ['CazaSarcasmos',
#   'me van odiar por esto pero y si salen los que no tienen empleo los que no tienen recursos porque los que tienen no se van a exponer entonces esos que salen se enferman y toca ver cuantos tienen salud porque si el sistema no es bueno pero para que retarlo'],
#  ['juanfel16448123', 'por una colombia libre de corrupcion'],
#  ['Oscar_GCh',
#   'y 100 líderes asesinados también lo que va corrido del año y para eso si hay esmad fuerzas militares armamento para defensa y asesoría gringa el artífice de esta matanza'],
#  ['GLondoo2', 'protestas en vivo en washington d c'],
#  ['hernanmorenoe',
#   'está cerrando las puertas de la democracia así rechaza la búsqueda de soluciones el país quiere paz con justicia no el estado tomado por la mafia y la corrupción'],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['Angie_SM98',
#   'yo se necesita hacer justicia soy una persona insignificante pero tengo mis derechos y por eso marcho hay que alzar la voz y hacer que todos esos malditos paguen mi mamá'],
#  ['_kaatooo', 'ya sabes cuándo'],
#  ['GLondoo2',
#   'siguen las protestas en vivo en washington d c live video protest protestas en vivo'],
#  ['Astro27350111',
#   'vamos todas a exojir lo que es de nosotros estudio salud trabajo y 0 maltrato de la policía ah y que renuncien todas esas ratas de políticos'],
#  ['AcademicallAse1', ''],
#  ['dana13_31', ''],
#  ['Calcor70',
#   '🤣 sin tapa bocas sin gel anti bacterias y sin distanciamiento social 🖕hagan lo que les dé la puta gana después no se quejen si les da covid 19 y que los atienda quien los convoca a su marcha 👌'],
#  ['ElVueloVacio',
#   'buenos días a todos menos a esos humanos que les da por convocar marchas con distanciamiento social en medio de una pandemia a esos no por demagogos e irresponsables'],
#  ['_kaatooo',
#   'yo salgo a la por la corrupción en medio de la pandemia por la ñeñepolitica por cada líder social asesinado por los indígenas y afros por la naturaleza y su cuidado ¿hay motivos para no salir a marchar prefiero morir de que de indiferencia'],
#  ['PamelaVelezH', 'me fuiii'],
#  ['Oscar_GCh',
#   'aquí uno de los barra brava y defensores del mal en épocas cuando el razocinio aún lo acompañaba hoy qué pensará al saber que el perfilador de periodistas y patrocinador de paramilitares a quienes entrenó yair klein es el'],
#  ['edwarkenw861245', 'los esperan para el baile pero con el ataúd de cartón'],
#  ['CrisFlorez07',
#   'aquí nos tratan de vándalos pero allá sí legitiman la marcha'],
#  ['lopezfco', ''],
#  ['Marcela6C', 'esos deseos me dan más ganas de apoyar la'],
#  ['oskarciber',
#   'contra un gobierno corrupto que se tomó el poder si el pueblo se levanta se les acaba el juego'],
#  ['Generalsandrita',
#   'pretedenden quebrar la economía que se pare la producción ya que es el estado ideal en socialismo pilas después no digan que no le avisaron'],
#  ['Jorgetolds1219',
#   'vamos a marchar no mas vamos con toda no importa la pandemia mire todo europa como esta estados unidos y a nosotros nos matan mas lideres y nadie hace nada'],
#  ['NatieeeG',
#   'acabo de ver que es tendencia también por la indignación que provocan decenas de asesinatos de líderes sociales en colombia'],
#  ['AngleleeB', 'colombia necesita paz'],
#  ['AngleleeB',
#   'salgamos a marchar a protestar y la verdad duele en el alma colombia al saber de que no somos capaces de luchar por nuestros derechos piensen en lo que nos espera a la futura generación'],
#  ['PijAnon',
#   'el que quiere llevar fútbol a la tv más agro ingreso solidario más mano dura etc con tal de distraer la opinión pública del problema real el veneno de colombia'],
#  ['AngleleeB',
#   'no entiendo y no me cabe en mi cabeza como hay gente que todavía preguntan que por cual razón debemos salir a las calles a protestar en colombia queremos que el gobierno le vea la cara al pueblo que luchemos por lo que queremos que se acabe esta desigualdad'],
#  ['javiwar',
#   'es la estupidez más grande de gente con cerebro pequeño como este petardo y que siga la propagación del virus nojoda es que no pueden ser más brutos'],
#  ['AndersonAlzateL',
#   'realmente sino estuviéramos en un proceso obligatorio de salud yo saldría a la hay muchas razones exigir justicia ante los escándalos una ley más fuerte contra los corruptos seguridad en el territorio implementación del gobierno y la plata de la emergencia'],
#  ['EdisonStevenRi1',
#   'los que quieren iniciar la en colombia saldrán a protestar de verdad ¿o a desbaratar las ciudades y generar disturbios con actos vandálicos como en la casa blanca luego dicen que la autoridad abusa cuando el único objetivo de algunos es salir a robar'],
#  ['Javi_ERH',
#   'porque en colombia nos debe doler primero los más de 200 líderes sociales asesinados en los últimos 2 años'],
#  ['lopezfco',
#   'el problema es que el nos van a mandar a encerrar en la casa con alguna excusa así actúan las dictaduras'],
#  ['Lictius',
#   'locombia país en que en plena pandemia fecode organiza una marcha es decir anuncia que va a cometer un delito para propagar el virus que nos tiene confinados a muchos desde hace dos meses van a dar los permisos para marchar los alcaldes'],
#  ['sheriith',
#   'yo me considero una persona ignorante en cuanto a historia y las fechorías de los políticos pero siempre apoyaré el hecho de que los dejen en evidencia y me sumo a'],
#  ['EduardoAbelRom1',
#   'todos a las calles no podemos seguir callados mientras el porcino se roba nuestros recursos'],
#  ['PaolaAn85777033',
#   'en serio nos encerramos 3 meses para salir a marchar bobotes'],
#  ['Alejand32574510', 'nooo'],
#  ['germanecabrerao', ''],
#  ['CarlosReey',
#   'de verdad van a poner a prueba las uci no jueguen con la suerte así que irresponsables'],
#  ['wverodr79',
#   'por favor que marchen todos sin tapabocas y antes de la marcha firmar el desestimiento de la uci gracias buenos para nada'],
#  ['germanecabrerao', ''],
#  ['germanecabrerao', 'no debemos graduarnos de pendejos'],
#  ['KlausGoebel',
#   'tenemos derechos y libertades también tenemos deberes marchas sin violencia es un momento difícil en colombia y en el mundo construir país en paz en sana convivencia y respeto sin odios si se puede hermosa colombia adelante'],
#  ['verdolaga2323',
#   'es irresponsable salir en pleno pico epidémicologico la protesta es un derecho por supuesto pero por qué hacerlo en plena pandemia y ojala recuerden esos colombianos que mueren por pisar minas y combatir el nacotrafico'],
#  ['jusepu', '¿no más goles'],
#  ['JuanGuarin11', ''],
#  ['alexcastellan07',
#   'y si salimos desde ya eso de programar marchar hace que esté más preparada la maquinaria corrupta en complicidad con el smad para vulnerar nuestros derechos y para que se infiltren y generen caos'],
#  ['JohanMa20', ''],
#  ['BENJAMINGARZON7', 'listos'],
#  ['oskar4791', ''],
#  ['Donatell131', 'para la calle los superamos 1 en un millon'],
#  ['PUBLINET8', ''],
#  ['Donatell131', ''],
#  ['ARicardoBenitez',
#   'porque a diario mueren más por el virus de la corrupción'],
#  ['mochilaWayuu',
#   'ya lo teníamos son los líderes y lideresas sociales asesinadas son los niños que mueren de desnutrición por olvido del estado son los niños muertos en el bombardeo son los falsos positivos etc'],
#  ['PaitoCas',
#   'esa gente que pregunta porque salir a protestar en plena pandemia es la misma gente que está cómoda con la realidad del país solo les recuerdo que si no nos mata el virus nos va a matar la desigualdad la injusticia y la corrupción'],
#  ['SergioM0614',
#   'los que querían que claudia lópez quitara la cuarentena ahora si critican qué haya'],
#  ['mafaldagallego',
#   'muy valiente desde la comodidad de su casa llamar a los pendejos a una marcha para que se contagien y uds ni siquiera han ido al congreso a trabajar🤬 irresponsable'],
#  ['Andresg0689', 'contra este puto gobierno corrupto'],
#  ['GREG09751392',
#   'la marcha de los idiotas para intentar tapar la volada del jefe petro a cuba no se salva'],
#  ['pposejo',
#   'ojalá salgan todos sus seguidores y los del y entre todos se abracen y protesten para que el virus haga lo suyo se llama selección natural lo dijo darwin'],
#  ['andercal24', ''],
#  ['javier_zulia', 'un marcapasos para aida'],
#  ['ARicardoBenitez', 'con bandera y tapabocas salgo'],
#  ['sevilla11_karol',
#   'tengo mucha impotencia todo lo que esta pasando en este mundo cuando será que la policía no va abusar de su autoridad y no van a matar a negros por ser racistas creo que me voy a quedar esperando este cambio por que nunca va a pasar'],
#  ['yeison_fox',
#   'no estaban luego ayer poniendo imágenes negras en sus perfiles hipócritas de mierda se les pide aquí actuar y les da miedo'],
#  ['arleytrujillo7', 'tod@s a las calles por q se haga justicia'],
#  ['sevilla11_karol', 'motivo'],
#  ['sevilla11_karol',
#   'todos piensan en la pandemia y todo en parte tienen razón pero parce acá uno tiene valer su vida los policías somo por que son autoridad tiene derechos hacer esas cosas pues no acá todos somos humanos que esa marcha se haga por gente que está arriba sin ningún'],
#  ['yeison_fox',
#   'aplauden protestas en estados unidos pero se convoca en colombia y les asusta la pandemia me asusta ma sola pandemia de hambre y sangre que agobia este platanal'],
#  ['TutaDiego',
#   'todos a las calles por más aglomeraciones más contagios más muertes más coronavirus más aislamiento y cuarentena más crisis hospitalaria más crisis económica más decretos de duque'],
#  ['mafaldagallego',
#   'la economía cerrada negocios en quiebra y preparan marcha😱 que irresponsables mejor no se hubiese implementado la cuarentena y todos contagiados pero con empleo'],
#  ['yeison_fox',
#   'contra el fascismo que estos sometidos durante está pandemia'],
#  ['arleytrujillo7', 'para q metan a a la carcel'],
#  ['SteffaniaRo', 'salgo'],
#  ['JohnGO92',
#   'cule marcha organizada con dos semanas de anticipación sin cero espontaneidad de parte de nosotros no valemos es verga'],
#  ['sevilla11_karol',
#   'vamos a marchar por todas esas personas que no pudieron estar y vamos a pelear por todos'],
#  ['Carlosa83209358', ''],
#  ['OracionesPara',
#   'no asistiré porque respeto mi vida y cuido a mi familia pero me gusta que muchos 🐷 vayan a la esa depuración le sirve a colombia 😁'],
#  ['Elquenadasabeo1',
#   'señor y colombia humana están dispuestos a lo que sea por llegar al poder incluso a por sobre la sangre se la gente como pasó a principio de año cuando decían que eran toda colombia cuando en realidad solo era el petrismo'],
#  ['FilosofoImpuro', 'esto no se logra con marchas ya está demostrado'],
#  ['Elquenadasabeo1',
#   'los mismos que criticaban al gov por no cerrar el aeropuerto por el asilamiento inteligente por abrir reactivar el mercado son los mismos que están promoviendo la yo les digo no mas manipulación de la disque oposición'],
#  ['David08642453', ''],
#  ['jomach35',
#   'muero de ganas de ver estrenar los nuevos juguetes del esmad 👏👏👏👏👏👏#marcha15dejunio'],
#  ['Ivager69',
#   'ciudades en el mundo marchan contra el odio y racismo policial que también se ve en btá es hora de despertar de verdad dónde están estudiantes maestros desempleados sindicatos es hora de reclamar y decirles no más a los corruptos y a los violadores de ddhh'],
#  ['Gaso40321953',
#   'todos los contagios y muertes de adultos y abuelos después del 15 de junio son culpa de petro bolívar cepeda claudia etc y de los adolecentes que van a llevar el virus a sus casas no hay escusas serán asesinos de sus padres y abuelos'],
#  ['David08642453', ''],
#  ['TutaDiego',
#   'en pleno aislamiento en plena cuarentena en plena pandemia es enserio los que promueven esto de verdad que son inconscientes e irresponsables si lo que quieren es destruir las ciudades y el país ya tendrán tiempo después cuando no tengo ni puta idea'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['MiguelP51520329',
#   'lo bueno de la es que saldrán muchos mamertos de izquierda y el coronavirus estará presente para aniquilarlos para siempre todo puede pasar se aniquilan sólitos señores sólitos'],
#  ['joseale30251145',
#   'mamados de tantos decretos presidenciales tan mediocres'],
#  ['alejorcasta',
#   'a las calles por todos nuestros muertos lideres sociales indigenas estudiantes profesores'],
#  ['hernangarcia98',
#   '“tenemos que despertar y no quedarnos callados” spike lee'],
#  ['cesfit7',
#   'otra de las razones por la cual marcharemos que verguenza de congreso ahora no solo tenemos que lidiar con su manera de robarnos si no que hay que sumarle la desfachatez para realizar su labor'],
#  ['Elquenadasabeo1',
#   'a los que promueven la absurda ustedes no son oposición no representan nada sabemos que son el vano intento de un político de cuyo nombre no quiero ni recordar por ser elegido en las próximas elecciones presidenciales'],
#  ['redcajapandora', ''],
#  ['maleja_28_', 'será como el'],
#  ['Ang_Altamirano',
#   'el desempleo por encima del 20 la reforma tributaria que se nos viene para tapar el hueco gigante de lo poco que han repartido más lo mucho que se han robado la corrupción cada día más descarada y la justicia creada para librar al que tiene motivos existen'],
#  ['Elquenadasabeo1',
#   'la disque oposición lista para mandar todo al garete en la es por eso q esta gente no puede ser considerada oposición ni nada mas que un grupo criminal acaso no entienden que ha una pandemia no ven q sus disque protestas pacificas han hecho mas daño q bien'],
#  ['LaGwens',
#   'pa’ mi es una irresponsabilidad sí hay infinitas razones para salir a protestar pero no es el momento yo por allá no voy'],
#  ['Vladmizar6',
#   'buen dia hombre mucha para vos y toda la genté hoy cierto que quedo decente agradeco si ayudas a difundir la buena compa y prepararse con toda para 🇨🇴🐵💪'],
#  ['o_agudelo75',
#   'en una economía golpeada a los genios de siempre se les ocurre ¿por qué no practican un deporte que pereza la gente inconsciente'],
#  ['LuIsOvEjO', ''],
#  ['latriplehp5678', ''],
#  ['delmontonsoy',
#   'para que los hps salgan a contagiarse masivamente de covid19 y lleguen a sus casas a joder a sus familias asesinos'],
#  ['JaimeAlonsoPar6',
#   'a la calle para exigir al narcogobierno o a la narcodictadura que cese su hostilidad contra el pueblo'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['josevecinop',
#   'el efecto dominó del derecho a la justa protesta y la responsabilidad de cuidar a la familia'],
#  ['mariafe37834240', 'nos vemos en las calles'],
#  ['mrwatch808',
#   '¿en serio y porque esta única vez los afrodescendientes si importan es una hipocresia cuando en choco y otras tantas partes de colombia hay muchos anderson sin oportunidades e inmersos en una guerra causada por el famoso acuerdo pero esos no merecen marcha'],
#  ['nano1960',
#   'la apoyo pero 1 día suficiente para desahogarnos pero no servirá para cambiar mejorar el pais sera otro saludo a la bandera un mes paro'],
#  ['Alfredoboita1',
#   'se acabó la valeriana en colombia el matarife se la tomo toda'],
#  ['tostadadeatun1',
#   'el mundo necesita la verdad ironia una organización con máscara contando más que toda la iglesia nada más que cuentos de disney'],
#  ['sin_praxis',
#   'las protestas y reclamos que se quiere hacer al gobierno son legítimos pero no olviden que en colombia el solo es una campaña publicitaria no esperen condescendencia de nuestros medios de comunicación a las causas colombianas'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['jairoroa171',
#   'aquí el mundo nos está mostrando que ni los gobiernos ni autoridades van a seguir abusando y en colombia una de las razones de éstos abusos es la permisividad de la justicia con el y sus secuaces por éso como pueblo vamos a derrotar ésas injusticias'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['rpegazo',
#   'el símbolo de la gente imbecil y demasiada enferma de este país álvaro uribe vélez argiro corte suprema en repudio por el asesinato de anderson a manos de criminales policías yair klein juanpis gonzález corte suprema'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['luchocontrerasp',
#   'cómo puede decir que reberlde con causa si has estado en todas las mermeladas presidenciales ahora el pueblo es quiénes deberíamos ser los rebeeldes con justa causa'],
#  ['So_lecito',
#   'en colombia matan diariamente a líderes sociales e indígenas y yo no los veo poniendo una imagen negra en redes es que los muertos extranjeros valen más'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['EliasLavoz1',
#   '¿y ahora cuál es el motivo de la famosa marcha estamos en una situación de la cual debemos estar unidos como país para salir adelante no para “revolucionar” el corazón de otros'],
#  ['robertpenuela',
#   'que no se quejen déspues es un delito contra la salud pública y violación de medida sanitaria pero el que llego de cuba no le importa enviar incautos a la calle a contagiar y contagiarse con tal de incendiar el país por su sed de poder'],
#  ['oskarciber',
#   'a marchar y protestar contra el narco estado la ñeñe política y el silencio cómplice del gobierno de uriduque por narco embajador sanclemente'],
#  ['Andres_Lopez13',
#   '¿y nuestra indignación pa cuándo pal 15 de junio todos a las calles'],
#  ['Vcv173',
#   'se suponía que ud iva a expropiar las tierras si ganaba las elecciones ahora que dirán los uribestias pobres tirados a capitalistas que tienen fincas pequeñas heredadas de su familiar indígena que detestatan y no producen por qué son de derecha'],
#  ['PATRICI20413620',
#   'a estas alturas de la vida para mi marcha es sinónimo de destrucción y también de contagio'],
#  ['Alfredoboita1', 'el líder de la banca criminal más grande de colombia'],
#  ['occiauditores',
#   'no a marchas no aglomeraciones ni clases en aulas no saben ni imagina qué es no poder respirar deberían los medios hacer más publicidad con testimonios de los que se están ahogando con el virus por dentro incredulidad hasta cuando se ahoguen'],
#  ['oskarciber',
#   'contra el saqueo solidario robar plata en plena pandemia es un acto criminal'],
#  ['cesp2010', 'con toda'],
#  ['Sebastian_xdxd1', '¿listos para quemar tombos este día'],
#  ['PaoSalazT',
#   'es real o va a pasar como con el paro que llegó diciembre y el paro también se fue a vacaciones porque ahí el referente fue chile qué se haga por convicción no solo porque el mundo alrededor está ardiendo y pues cómo nos quedamos atrás en tendencia'],
#  ['OGalvisC',
#   'son muchos los llamados que se le han hecho al gobierno pidiendo protección a los líderes sociales núnca han querido atender los llamados por eso'],
#  ['AlexMartinez258', ''],
#  ['oskarciber',
#   'por la soberanía no a las bases militares gringas en colombia no somos el patio trasero de trump'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['sanntiago_er', ''],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['Alfredoboita1',
#   'investigado por homicidio por masacres por narcotrafico por chuzadas por corrupción por paramilitar no hay delito donde no esté involucrado el matarife de uribe ya es hora que pague carcel'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['weinsh3z',
#   'un escudero de las convivir él concibe la paz únicamente como resultado de una victoria militar sobre los alzados en armas iván duque al parecer el duque del pasado les da sopa y seco a los periodistas del presente 🤦👇'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', ''],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['juanpariasl',
#   'es el reflejo de lo que quieren y representan para este país muchos tratando de ver como sacan adelante a y otros como poner palos en la rueda'],
#  ['oskarciber', ''],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', 'éstas son las razones para'],
#  ['juanpariasl',
#   'es en serio cuando estamos ante la peor tragedia de la historia y pensando en esto'],
#  ['cabrales_ospino', ''],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['Alfredoboita1',
#   'estos son los policías que asesinaron a dylan cruz y anderson arboleda demosle retwees para que no se olvide'],
#  ['milostickersas', 'acabo de ver que se está convocando a'],
#  ['oskarciber',
#   'no más esmad y abuso policial derecho a la protesta social legítima'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', ''],
#  ['cabrales_ospino',
#   'maldito comunismo maldito socialismo salgan ustedes manada de borregos'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['oskarciber',
#   'por las víctimas del paramilitarismo en colombia no más narco paraco uribismo'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['alejo2000_2000',
#   'las marchas para el 15 de junio nos permitirá ver que tan letal es el virus sin confinamiento de las personas si el virus es muy contagioso y letal reducirá el número de manifestantes en el futuro cercano'],
#  ['OGalvisC', 'no más asesinatos justicia ya'],
#  ['oskarciber',
#   'no más narco paraco uribismo asesino en colombia 🇨🇴 no más genocidios y asesinatos'],
#  ['OGalvisC', 'justicia ya'],
#  ['Liliana09695487',
#   'yo no estoy de acuerdo con esta marcha no ven que estamos pasando por una terrible epidemia que ganan con eso propagar más este virus si no se hizo nada antes de esta pandemia mucho menos ahora alcontrario van a empeorar esto 😡'],
#  ['OGalvisC', 'por los miles de líderes sociales asesinados justicia ya'],
#  ['Oscar08464952',
#   'si comparan el socialismo con desigualdad porque no equiparan el capitalismo con riquezas para todas'],
#  ['Angela9637', 'el verdadero y más peligro virus ves el estado'],
#  ['OGalvisC', 'justicia ya'],
#  ['chocante25',
#   'por racismo y no se acuerdan que un señor metió varias personas en una iglesia y las quemó lo más hijueputa es que esta con una curul en el senado chimba de país'],
#  ['oskarciber',
#   'en colombia cada día asesinan cobardemente lideres sociales defensores de derechos humanos ambientalistas ex guerrilleros que dejaron sus armas reclamantes de tierras y no pasa nada no más indiferencia cómplice vamos a las calles'],
#  ['jorgelopez59', ''],
#  ['jorgelopez59', ''],
#  ['jorgelopez59', 'hipocresía'],
#  ['OGalvisC', ''],
#  ['Angela9637',
#   'despertar ya este gobierno farandulero y banquero es un derecho vque tenemos'],
#  ['Edna_moliina',
#   'ustedes lo que quieren es contagiarse de covid 19 para culpar al gobierno y pedir mas ayudas'],
#  ['iSamuelES', 'vamos'],
#  ['oskarciber',
#   'los del esmad saldrán a estrenar sus uniformes para reprimir la protesta social legítima mientras personal médico no tiene dotación para enfrentar pandemia'],
#  ['SebazZz_14',
#   'que impotencia no poder hacer ni mierda para evitar la hijueputa'],
#  ['Antonio163016',
#   'vamos colombia entusiasmo con dignidad y amor sin cobardía'],
#  ['ReyLenidas3',
#   'desde que la lo llama a indagatoria es porque tiene pruebas a la mano contra y ahora sí se le acabó el derroche porque se le vienen las otras con extinción de dominio'],
#  ['croactibo',
#   'vamos apoyar a en esta marcha que sea multitudinaria que sea la marcha más grande nunca vista en colombia con abrazaton besaton cojida de teta al aire de las feministas y tal y que repartan hasta para llevarles a la casa de sus padres 🤣'],
#  ['oskarciber', ''],
#  ['algrano_ibarra',
#   'las ganas de generar violencia son infinitas acab justicia para todo el mundo no al abuso de autoridad todos a las calles'],
#  ['oskarciber',
#   'en memoria adilan cruz y george floy asesinados por un policía'],
#  ['Matto04981427', 'cuenten conmi apoyo'],
#  ['JuanDiego_CG', ''],
#  ['JuanDiego_CG', ''],
#  ['Antonio163016', 'contra estos sinvergüenzas también es la'],
#  ['elkin197628', ''],
#  ['Lachavitadel8', 'recomendaciones para la primero la salud'],
#  ['JuanRicardoAgu8',
#   'de verdad piensan salir a una marcha por las calles en 12 días verdad hay alguien que lo va a hacer pero lo más tenaz creen que sirve de algo de verdad'],
#  ['_sancheezp', 'cómo sería entonces para la'],
#  ['Antonio163016', ''],
#  ['Antonio163016',
#   'la puta de babilonia quiere acallar los gritos de hambre de inconformismo quiere acallar las marchas'],
#  ['group_pepe', ''],
#  ['group_pepe', 'trece días es demaciado tiempo pero hay estaremos'],
#  ['Antonio163016', 'colombia'],
#  ['elkin197628', ''],
#  ['Leonorgs_24',
#   'por él por nuestros afros por la brutalidad policial por la educación por la ñeñe política'],
#  ['Antonio163016', ''],
#  ['Antonio163016', ''],
#  ['Antonio163016', 'necesitamos de su energía al igual que el 8 12 2019'],
#  ['SebazZz_14',
#   'me parecen las razones lo que no me parece es el momento para hacerlo ignoran por completo el tema'],
#  ['Arquiman2', 'ñeros peligrosos'],
#  ['Arquiman2', 'saqueos'],
#  ['Arquiman2', 'robos'],
#  ['RobertoMTico', 'todos a las calles me sigues te sigo'],
#  ['septimoartecol',
#   'especial 👩\u200d🎨 parte 4 edmonia lewis 1844 1907 escultora de origen haitiana y ojibwe la liendra'],
#  ['Merseysound23',
#   'por anderson por dylan por nuestr@s muert@s nos volveremos a encontrar'],
#  ['iam_jhoanp', ''],
#  ['bolivarjk',
#   'ya es hora de sacar a la mafia del poder si queremos un futuro'],
#  ['ingdeas',
#   'una mentalidad destructiva y poco sensata quieren el caos perse y tienen como forma de hacer política la primitiva búsqueda del odio'],
#  ['RobertChilito',
#   'enrique oramas agricultor orgánico y productor de alimentos saludables asesinado en su casa ya son 100'],
#  ['RobertoMTico',
#   'me uno a esta iniciativa un estado en sus tres ramas del poder público completamente arrodillado a la cultura d la muerte al a la corrupción al narcotráfico a la compra d votos a la injusticia al sistema financiero etc solo merece desprecio'],
#  ['iam_jhoanp', ''],
#  ['andrudel',
#   'concuerdo con y en qué la situación no es la adecuada para la pero la situación del país indigna a la mayoría de los colombianos y las personas ya no aguantan más'],
#  ['Mar_Cherbonneau',
#   'y a esto hay que sumar incumplimientos del acuerdo de paz políticas favoreciendo tenedores de mala fe chuzadas ilegales del ejército cuyo destinatario es el señor uribe tropas extranjeras sin consultar al congreso ingreso solidario para artistas millonarios'],
#  ['Mar_Cherbonneau',
#   '¿por qué nunca leo ni veo ni escucho por pelmazos hipócritas y descriteriados como este tipo'],
#  ['Sroldang', 'que de poder'],
#  ['GoDiegoGo017',
#   'por la brutalidad policiaca por anderson arboleda por los líderes asesinados por la corrupción de derecha e izquierda porque solo marchando se sentiran acorraladas las ratas esas'],
#  ['iam_jhoanp', ''],
#  ['KillerDoge',
#   'para todos los que ven y apoyan las marchas en estados unidos a causa de la brutalidad policial en nuestros paises pasa todos los días'],
#  ['iam_jhoanp', ''],
#  ['iam_jhoanp', 'unamos esfuerzos para combatir lo que nos pasa en el país'],
#  ['Ferjoher1',
#   'yo marcharé porque ya me canse de que el matarife haga lo que se le dé la gana jarto del gobierno títere y de las porquerias que hace esa es mi razón'],
#  ['Numa08053160',
#   'esa me lo mamá y estoy dispuesto a peliar con argumentos 😟'],
#  ['gonzzo91',
#   'les recuerdo que las marchas son para que se haga justicia por el racismo y el abuso policial no para tomar cosas personales en contra de un lado político'],
#  ['Oscar08464952',
#   'no tenemos miedo no tenemos miedo matarife prensa arrodillada si no se ponen a favor del pueblo también para la mierda hptas'],
#  ['KevinMarinOC', 'ahora nos toca ha nosotros ✊🏼🖤'],
#  ['natsinpena',
#   'marica yo no sé si sea buena idea esta marcha estoy entre sí y no tal vez no debamos no es el momento dado estamos en mitad de pandemia suerte a los que vayan cuídense mucho psdt será que pega tanto como el 21 de noviembre k nervios'],
#  ['Gar4780',
#   'me preocupa que el sistema de salud está a punto de colapsar por esta pandemia y ante todo debemos evitar aglomeraciones las protestas son un derecho pero bajo estas circunstancias es irresponsable por eso no apoyo la'],
#  ['LaTropaChibcha',
#   'entre otras por que uribe debe pagar algún día por ser el jefe de corrupción y paramilitarismo mas grande que haya visto colombia'],
#  ['didiersanchez26',
#   '5 tips no más en colombia no mas racismo no tropas estadounidense abuso de los policías colombiana la corrupción en plena cuarentena no mas violencia a nivel país colombiano'],
#  ['jhonnisjk',
#   'porque nos programamos para aser el ridiculo donde tenemos que salir a pedir justicia estamos hartos de el abuso de poder tanto como politicos como la policia que en ves de proteger lo que asen es lucrarse de la nesesidad ajena'],
#  ['ReyesSalmha',
#   'por qué al igual que aquel periodista y líder para muchos jaime garzón yo creo que esto tiene salvación y somos nosotros la juventud quienes tenemos la dirección correcta hacia un mejor país'],
#  ['paissinyugos', 'reaccionaaaaa'],
#  ['Oscar08464952', 'que pena y jesús también era comunista'],
#  ['momofronaldo',
#   'si muy bueno lo de pero si lo van a hacer bien porque si es para alborotar por 5 días y después cada uno para su casa como todas las perras marchas de este país que no logran nada mejor se quedan y no arriesgan a un contagio'],
#  ['daniellozada99',
#   'a manifestar las inconformidades contra este inneficiente sistema político y económico creemos en la paz y los cambios radicales no se justifica ningún tipo de violencia'],
#  ['alexcrios1999',
#   'tenemos miedo pero también queremos un mejor país un mejor futuro una mejor educación un plato donde comer una casa donde vivir una mejor salud tenemos miedo pero este gobierno nos tiene que escuchar'],
#  ['wmejialo', ''],
#  ['RumikoStephanie',
#   'lo sé y estoy de acuerdo pero considero que n este momento son importantes nuestros padres abuelos e hijos ellos serían los perjudicados no el gob y obvio que a las calles debemos volver para que seamos escuchados pero no poniendo en riesgo a los nuestros'],
#  ['Marcha15deJunio',
#   'un botellazo en la cabeza de un patrullero de la gloriosa acabó su vida'],
#  ['ssssssebas',
#   'si de veras supieras por qué criticamos al gobierno los que promovemos la borrarías este tweet'],
#  ['Anascupar',
#   'le dije a mi mamá gorda si hay que salir a marchar acá tú sabes que yo tendré que salir verdad ajá pero llevas tapabocas y no te toques mucho la cara si mami me compro la careta de la gorra'],
#  ['Marcha15deJunio', 'en colombia el racismo también es sistemático y letal'],
#  ['Marcha15deJunio', ''],
#  ['Marcha15deJunio', ''],
#  ['RumikoStephanie',
#   'critican al gobierno porque no consigue que la gente respete la cuarentena pero van a salír el 15 de junio en fin la hipertensión xd'],
#  ['Marcha15deJunio', 'caerá el que dio la orden'],
#  ['Marcha15deJunio', 'colombia se cansó'],
#  ['CAROLINAD10A', 'recuerden no hay tanqueta pa tanta gente'],
#  ['AngieVal2226',
#   'hay que luchar juntos por el amor la paz la igualdad el respeto el país y nuestro pueblo maldito sea el soldado que apunte su arma contra el pueblo simón bolívar'],
#  ['Likar105',
#   'vamos salgamos a las calles exigimos nuestros derechos justicia social la brutalidad de la fuerza pública los falsos positivos que se activaron otra ves'],
#  ['stevenoosd',
#   'no estoy de acuerdo con que salgan a marchar en estos momentos si no lo hicieron antes de la pandemia ahora si piensen en sus familias marchar ahora solo hará aglomerar más personas e incrementar más casos y más muertas por el virus quédense en casa'],
#  ['TenoriKoi',
#   'quería hacer una lista de razones para marchar pero ¿en serio hay que nombrarlas ¿hay algo bien en este país ¿en serio no vamos a cambiar muy lindo que apoyen protestas en otros países pero a ver si hacemos algo con el nuestro y apoyamos al mismo pueblo'],
#  ['juanshootss',
#   'los héroes en colombia si existen y son esos mismos que por empatía con el cuerpo médico no saldrán a la a contagiarse u colapsar el sistema de salud crack'],
#  ['ldsjota16', 'todos son todos'],
#  ['Harol72860060',
#   'cómo todo en este país ¿ que hacemos nosotros para mejorarlo criticando e insultando no hacemos nada'],
#  ['Harol72860060',
#   'protesto por las miles de familias que hoy en día están esperando a sus familiares desaparecido protesto por la muerte de muchos líderes sociales por estás y muchas razones más'],
#  ['CamilaL75539792',
#   'yo marchó por la colombia olvidada donde los crímenes no salen a la luz pública donde el estado solo llega en forma de guerra y represión donde los grupos secretos del estado águilas negras desplazan asesinan violan e imponen su feudalismo moderno'],
#  ['YesicaMylano',
#   'en serio bueno con tanto desocupado un 20 de desempleo se entiende pero la verdad espero que una marcha traiga alguna solución de los enormes problema que tenemos ahora una marcha pacifica y no violenta'],
#  ['peznaranjaTweet', 'ya te lavaste las manos'],
#  ['Leonard20514252', ''],
#  ['gloqui20',
#   'a esos brutos de la les recuerdo que la marcha feminista en madrid fue la que ayudo a regar el virus y los llevo al pico tienen toda una vida para protestar no cuando vamos para el pico de una pandemia no se les pudo ocurrir en peor epoca idiotas'],
#  ['Leonard20514252', ''],
#  ['AhhDiga',
#   'marcha marcha marchaaaaaa 🙏 pero que se infecte todos los marchantes por favor 🙏🙏🙏🙏🙏#marcha15dejunio'],
#  ['alterahuevos', 'yo marcho por ellos porque merecen justicia'],
#  ['AhhDiga',
#   'eso marchen pero eso si infectence todos oooosssss 🙏#marcha15dejunio'],
#  ['fulrecos7',
#   'no se sabe que es peor en 🇨🇴 si morir de covid o morir de hambre'],
#  ['alterahuevos',
#   'yo marcho porque estoy cansada del abuso de estos que dicen proteger al pueblo y lo único que hacen es reprimirlo y matarlo'],
#  ['otratremenda',
#   'y así como tanto le indignó la muerte de george floyd que me duela también su país anderson arango asesinado de un bolillazo por un policía en el cauca que no se derrame más sangre inocente queremos justicia'],
#  ['Migux_0',
#   'prefiero que un virus acabe conmigo y mi libertad a que un estado injusto y corrupto lo haga justicia es lo que necesita colombia y el mundo entero por sobre cualquier virus el humano sin libertad no es humano'],
#  ['MiguelCab1989',
#   'me gustaría saber qué opina sobre este ridículo ht dejen de buscar lo que no se nos ha perdido esto del coronavirus apenas está empezando'],
#  ['UnBufonMas',
#   'si si y si de una u otra manera nos tenemos que hacer escuchar y que sepan que ya estamos cansados de lo mismo y de los mismos'],
#  ['Certero331',
#   'piden las hordas petrofarcistas castrochavistas farc historia plagada de crímenes atroces al secretariado farc le perdonarán 16 siglos de cárcel'],
#  ['Cristhi96660434', '¡salgamos a las calles en una sola voz'],
#  ['Sthefania_820', ''],
#  ['ElgritoAfroo',
#   'el gobierno duque uribe debe caer el abuso policial debe caer el racismo debe caer el machismo debe caer la violencia de genero debe caer la homofóbica debe caer la corrupcion debe caer y para que caigan nosotros nos debemos levantar'],
#  ['FelipeM22851767', ''],
#  ['Juanpineda2802', 'algo así creo que pasará en los noticieros'],
#  ['ColombiaStyle', 'así se estará realizando los test para covid20 en la 🌡'],
#  ['monotovar1989',
#   'se pueden es infectar todos en esas marchas y puede pasar qué ya tenga el 100 de camas uci’s y respiradores copados para qué entonces las marchas del 15 sea pero de cajones'],
#  ['DavidGamezXD', '¿y si mejor cierras em hocico y te unes a la marcha'],
#  ['Cristiancami_lo',
#   'las revueltas sociales de las grandes capitales del mundo deben servir como aliento a este país marginado por una moral conservadora clasista y opresora'],
#  ['josedcuellars',
#   'en florencia caquetá un hombre presuntamente violo a un niño de tan solo 8 años algo más para la'],
#  ['ImHenao', 'yo no marcho por el virus osea guevon'],
#  ['Andreafiresb',
#   'si porque el país esta cansado de tanta corrupción y violencia orquestada por el estado ñeñepolitica fiscal de bolsillo asesinatos de lideres abuso policial cartel del covid y muchas injusticias mas 🚫'],
#  ['Pipec_137',
#   'sin falta y tempranito estaré allí marchando a todo pulmón y de todo corazón'],
#  ['1970Yesid',
#   'por lo general al año se robaban 50 billones pero el par se picaros y carrasquilla rompieron guinnes record en dos meses de curentena ya los desaparecieron'],
#  ['Daniel_stikk',
#   'no al racismo no a la homofobia no a los feminicidios y acosos no a la maternidad obligatoria'],
#  ['monotovar1989',
#   'lo malo es que el tiene una tasa de letalidad baja de un 5 a un 7 maximo si usted tiene un hijo que es mantenido y mamerto y quiere ir a el 4 y 12 y ya sabe claudia ya tiene casi el 70 de uci’s ocupada'],
#  ['arleytrujillo7',
#   'tod@s a las calles no falta esa persona q dirá q es por petro 🤦\u200d♂️ lucha es por nuestros derechos q nos están vulnerando'],
#  ['NatalyMora_',
#   'por eso estaré prénsenle en la porque estoy cansada de la injusticia cansada de sentir impotencia por no poder hacer nada por aquellos que alzan su voz y mueren por eso saldré a las calles a luchar por mi futuro y el futuro de mi país'],
#  ['Laubassmusic', 'por dylan por alejandra por anderson'],
#  ['Sttteven_', 'como putas harán una marcha aca en colombia'],
#  ['snavarro161',
#   'para el gobierno la muerte de un hombre es una tragedia y la muerte de millones es estadística'],
#  ['LeFaltaLaC',
#   'todos los que salgan a mariquear el 15 deberían dejar estipulado que no se les permita ocupar una cama de uci cuando les pegue el virus'],
#  ['atomocartun', 'la pirámide'],
#  ['Don_Juan62', 'jajajajaja la peinada que le pegaron 😂😂'],
#  ['ElDaIaiLama',
#   '¿alguna duda de que el cacas estuvo en cuba definiendo con su círculo regional cuál será agenda de los próximos meses para seguir quemando el país añora que el sistema de salud y la economía colapsen zombies ñeros listos a sus órdenes es lo que sabe que tiene👇🏽'],
#  ['Alexeprz',
#   'bueno creo que influenciamos a petro se supone que el apoye es la oposición 🤷\u200d♂️ igualmente te quiero recordar que inicio en fb con una publicación de un ciudadano x'],
#  ['killingMe_boy', 'este 15 de junio también salimos a marchar por alejandra'],
#  ['Oscar08464952',
#   'ustedes conocen algún colombiano que haya libertado ha nuestro pueblo de la opresión ni bolivar ni benkos biohó fueron paridos por esta tierra de cobardes'],
#  ['fungusxxs', 'esta mierda no se justifica 🌲⚒'],
#  ['Gav_LoM', 'yo a punto de salir rumbo a la por narnia mamá'],
#  ['sszzz__', ''],
#  ['d_padilla_93', ''],
#  ['Anahismr6',
#   'en colombia hay una marcha el 15 de junio en contra del racismo no podré asistir por mi familia recuerden llevar tapabocas cuidarse y gritar sobre todo gritar y emprender ese rumbo al cambio social e igualdad tqm'],
#  ['BCertuche',
#   'mi estimado señor si su compresión lectora es mala mediana o buena podrá entender que me refiero a que sigan posteando con el hastagh porque es el el que vale en este momento el senador se une a postear por la tendencia en qué se convirtió'],
#  ['Oscar08464952',
#   'quién se iba a imaginar que el covid 19 era nuestro simón bolivar'],
#  ['OscarPavi',
#   'los padres de familia que enseñan a sus hijos en casa pueden marchar con fecode 😅😅😅'],
#  ['profet538', ''],
#  ['Fredy_GuerraA', '✊🏾'],
#  ['Davinci_Hugh',
#   'los hijueputas que pedian el fin de la cuarentena ahora quejándose de la no más abusos de la policia ejercito no más líderes sociales asesinados por dilan y anderson ✊✊✊✊✊'],
#  ['oropesatoledo',
#   'no tiene que ver nada en pero le dice que lo postee jejejeje muy coherente'],
#  ['kukoflowpaisa',
#   '🗣️ esperen un momento títeres uno de sus lideres el doctor bobolivar les quiere decir algo o quizás ya no'],
#  ['OscarPavi',
#   'salgan a marchar con proyectos productivos y de generar empresa en las manos no con una piedra y banderas comunistas para que todo se lo regalen'],
#  ['rolistongs',
#   'los héroes en colombia 🇨🇴 si existen y son todos los que usan su voz son todos los estudiantes líderes sociales docentes y cada una de las personas que lucha por un país diferente la misma lucha del 21n pero con pruebas 🔥🔥'],
#  ['andrespaz1',
#   'este país no aguanta más el corrupto y ladrón la asesinando jóvenes y maltratando ancianos y el presidente gobernando por decreto y regalando plata a los bancos hay que levantarse y luchar'],
#  ['ColProgresista',
#   'existen muchas razones para salir a la 1 asesinatos a lideres sociales 2 abuso policial 3 corrupción en colombia y sobrecostos en la pandemia 4 agro ingreso seguro 2 0 5 violación de la soberanía en la llegada de las tropas americanas 6 ñeñe política'],
#  ['GoldenC34634053', 'esto es increíble colombia'],
#  ['sacamargov',
#   'creo que esto no se da en un momento bueno son algo estúpidos en cuanto a la convocatoria en estos momentos aunque las razones son muy válidas'],
#  ['GoldenC34634053', 'esto es increíble'],
#  ['OscarPavi',
#   'con esta marcha fortalecerán al gobierno nacional la gente del común entenderán que solo les importa vandalizar el comercio y generar el caos'],
#  ['lnicorojasl',
#   'otra marcha fracasada para darnos golpes de pecho de que despertamos y la siguiente pa cuando pa l 15 de julio yo veré por el andén bolitas de pintura para el congreso y piedras para el local del ciudadano'],
#  ['watosyss',
#   'que esté bien la protesta pero sino se comportan bien se van del culo para el estanco con el covid ese les protesta por camas en las uci'],
#  ['camilo58466717',
#   'tenemos miles de motivos desde los años 90 la historia de colombia la domina la violancia'],
#  ['LaPocholina',
#   'el es real que mierda les pasa ahora en es serio ey jodanse todes de verdad es lo más estudiado que se puede hacer en estos momentos pero bueno ahora si en plena pandemia coman mucha mierda'],
#  ['littledaughte11',
#   'ya que tanto les gusta desobedecer las indicaciones de no salir debido a la pandemia ¡entonces salgan pero con motivos de sobra no por cacorradas'],
#  ['OscarPavi',
#   'el virus nos demostró que tenemos un sistema de salud muy bueno comparado con otras naciones pero como nos les conviene eso los izquierdosos lo quieren colapasar'],
#  ['Aana31378828',
#   'la es totalmente entendible y necesaria pero hay que tener en cuenta varios factores como 1 va a pasar como 21n donde nada pasó por que la gente no sabía ni por qué marchaba 2 el pico de contagio va a aumentar hablando desde la lógica'],
#  ['And_mellet', ''],
#  ['Elian_Dv15',
#   'yo no sé si es que me estoy volviendo locó o es que está pasando de todo en este hijueputa año 🤦🏻\u200d♂️ que mondaa 🤦🏻\u200d♂️'],
#  ['OscarPavi',
#   'espero no ver a en los noticieros explicando el cerco epidemiológico de las marchas 😅😅😅'],
#  ['GodDragonSlifer',
#   'el silencio del inpec sobre el motín de la modelo después de las 7 horas de angustia en la modelo los familiares de los 24 internos muertos y 83 heridos muchos con heridas tiros de fusil tuvieron que enfrentar un silencio del inpec'],
#  ['OscarPavi',
#   'si deja realizar la marcha se entenderá que nunca le importó la salud de los bogotanos solo su carrera política'],
#  ['CastanoValbuena', 'las razones sobran'],
#  ['JorgeAJ9',
#   'si no eres de colombia no opines porque no sabes la realidad ni la has vivido si por el contrario eres de colombia o vives acá entonces no sabes nada mejor cállate el hocico 🤫🤐 🤭✌️☮️'],
#  ['JeissonDuenas',
#   'el esmad se va a dar gusto estrenando toda la compra que les hizo duque'],
#  ['andrudel',
#   'quiero ver a los mismos que están indignados con lo qué pasa en eeuu apoyando esto'],
#  ['DianaMHurtado',
#   'los colombianos somos tan cagados que no salimos de inmediato sino que hay que esperar la tal'],
#  ['OscarPavi', 'ya entendemos los fines de la reunión en cuba'],
#  ['CindySarmientoZ',
#   'bueno ahora que los que convocan a la repartan las máscaras y los tapabocas'],
#  ['OscarPavi',
# ...
#  ['GuilleSwd', ''],
#  ['KIKERIV56583861', '💪🏾🇨🇴'],
#  ['EnriqueTeacher1',
#   'cuántos asesinatos debe cometer la policía para detener este país'],
#  ['christian_atlh',
#   'ya que es incapaz de controlar marchas y controlar el covid propongo que rocíen con desinféctate a los manifestantes'],
#  ['Horacio57527276', ''],
#  ['FranciscoA_L',
#   '¿es en serio lo de la sus promotores de forma mezquina van a hacer que se contagien y posiblemente mueran miles de ciudadanos que bajeza'],
#  ['PatriciaDurn11',
#   'george floy levantó eeuu en colombia 347 asesinatos desde 2018 duque y 88 2020 q esperamos q nos maté el matarife el virus el hambre juego mi vida d todas maneras la llevo pérdida'],
#  ['andersoncasta16', 'de una'],
#  ['Lvcastillog',
#   'ridículos la gente no entiende por la pandemia que estamos pasando y la cantidad de contagiados muchos quieren activarse en sus empresas en su día a día todos queremos salir de este encierro de una vez por todas por favor dejen de incentivar esta maricada'],
#  ['Ceblue101',
#   'el que convoca a esto o es uribista o es la persona más estúpida de este país'],
#  ['Mediarse',
#   'duque alargará la 40rentena por las protestas que están por estallar en toda colombia lo de contener el virus ya no va a ser lo importante'],
#  ['Anglica14128255',
#   'por nuestros muertos ni un minuto de silencio ¡a las calles'],
#  ['soysantialarcon',
#   'después aumentan los contagios y ahí si lloran esos líderes que se aprovechan de la nobleza de sus seguidores producen rabia'],
#  ['Ritmica_Roja',
#   'porque si no nos mata el virus nos mata la inequidad 🦠୧ ಠ д ಠ ୨'],
#  ['CarolGonzalez5', ''],
#  ['Juanchocar80',
#   'vamos con toda el futuro es de los valientes he inteligentes acuérdense de salir sin tapa bocas y cogidos de la mano siii se puede'],
#  ['_castrosebas', 'yo me apunto ♥️'],
#  ['slayingrocky',
#   'dios mío por favor que mi mamá me deje ir a la marcha del 15 de junio'],
#  ['Cletrado10',
#   'en plena pandemia es completamente ilógico proponer esta claro que hay que seguir protestando pero hay que cuidar la salud de nuestros familiares'],
#  ['JuahnPis', ''],
#  ['Venusislife_',
#   'no más racismo no más homofobia no más feminicidios no más acosos no más violaciones a nuestros derechos basta de ignorancia'],
#  ['WilliamAFGarcia',
#   'pero que no incluya cacerolazo ni besaton y que no termine convirtiéndose en un festival recreativo'],
#  ['Felipe_sa_c',
#   '¿y si mejor iniciamos un levantamiento cívico basados en nuestras propias luchas porque salir a la calle a pintar acab y fuckthepolice no es nuestro culturalmente no despierta nada'],
#  ['MateRodriguezB', ''],
#  ['Joserextirano',
#   'los mamertos son tan brutos que primero exigieron que se decretara la cuarentena por mas de 60 dias con los cual se aumentaron los indices de pobreza ahora quieren contagiarse en forma diciendole a su sequito de idiotas'],
#  ['DraGranadilla',
#   'veo el luego pienso en lo reventados que estamos tratando de contener esta mierda y pues'],
#  ['ManosLimpiasCo',
#   'protesta con distanciamiento interpersonal daría dos mensajes que si podemos con el auto cuidado y que no somos pendejos'],
#  ['marlyntuiran', ''],
#  ['DORIACABRERA', 'con todo a la'],
#  ['posso0654', ''],
#  ['FelipeV2210',
#   'hasta que la dignidad se haga costumbre no más abuso policial no más escuadrón de la muerte no más lideres sociales asesinado'],
#  ['OrtizDirley', 'yo estoy listo marcho por mis hijos y marcho con mis hijos'],
#  ['Diego_Ibarra13',
#   'ojalá todos los que se andan quejando del en estados unidos tengan la valentía de salir este 15 de junio a la'],
#  ['danovislozano', 'en colombia el racismo también es sistemático y letal'],
#  ['Estrada0222',
#   'la verdad si viviera sola no me la pensaría para salir a marchar pero como no ni de chiste no voy a exponer a mi familia al puto virus'],
#  ['alexreyescast', 'cuando y son hipócritas'],
#  ['anibalom', ''],
#  ['ComiteDeParo', ''],
#  ['StefanBravo3',
#   'soy moisés galan gaitán un pueblo ahora marchen por nuestro líder social eeuu increíble tanta estupidez petrista'],
#  ['oscarabeja',
#   'que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['oscarabeja',
#   'que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['tomatetrip',
#   'casi que no el gobierno sosteniendo la cuarentena a punta de mentiras y decretos cual dictadura dejando más que claro que no les importa nuestra salud sino su bolsillo el 15 nos vemos'],
#  ['PasosPazzini',
#   'no nunca se saldra de la eterna cuarentena quieren bajar los contagios cuidense y mantengan el distanciamiento social las cosas se arreglan en las urnas se arreglan con inteligencia no con manifestaciones multi propósito sin objetivo claro'],
#  ['oscarabeja',
#   'que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['Marcosval01',
#   'sera que este es el verdadero proposito sacrificar a los idiotas utiles del socialismo para aumentar el número de contagios'],
#  ['CamiloPinzn17',
#   'alcaldes robando mercados sobrefacturando ingreso solidario para muertos los médic@s y enfermer@s sin sus trajes el desempleo por las nubes la policía abusando de su poder entre otras que estas razones te muevan pero sal con los cuidados necesarios'],
#  ['_Jack_Naipe',
#   'y como acá nos gusta darle largas a todo esperen una carentena general antes de la'],
#  ['robertoortega02', 'el covid_19 esperando la'],
#  ['HijueputaCasa', 'sin miedo'],
#  ['CSarahelenht',
#   'pido a todas las personas que van salir a con justa razón que piensen en todos los daños colaterales que esto dejará cargaremos con un genocidio en nuestras espaldas y haremos quedar a los tiranos como héroes'],
#  ['CamiloMejaR1',
#   'muchos dicen que es ignorante salir a marchar mientras estamos en el pico de la pandemia yo digo que es ignorante dejarnos manejar por la corrupción y el abuso de poder'],
#  ['HHsotelo27', 'no me imagine que el rencuentro seria en una marcha'],
#  ['lispinmaya',
#   'no entiendo a la gente si salen a marchar solo conseguirán que hayan más muertos piensen en que cuando vuelvan a sus casa van a estar sus padres tíos abuelos hermanos los jóvenes no somos inmunes es nuestro deber cuidarnos y a nuestros seres queridos'],
#  ['Piensa__', 'irresponsable es no hacer nada y quejarme en redes sociales'],
#  ['nana56973518',
#   'salgan vagos bandidos flojos ridículos irresponsables y demás estúpidos'],
#  ['Dannapa10653407', 'asi es'],
#  ['FCarri',
#   'los invitó a buscar otras formas de manifestarse hay que hacerlo pero reventando el sistema de salud los contagios y con muertes de manifestantes solo benefician el status quo mejor un cacerolazo o semejantes oigo ideas'],
#  ['JuanLindarteP',
#   'con esto de la se comprueba que más se demoraron en enviar el vuelo humanitario para traer a que este en desplegar las ordenes recibidas por parte del eln para vandalizar nuevamente el país'],
#  ['Sansarita',
#   'se alborotaron los bodegueros vayan pues qué el covid haga una buena limpieza social'],
#  ['memitodiez',
#   'si la la van a hacer con bozal y distanciamiento apague y vamonos me decantaría mejor por la de anden y festivo'],
#  ['Sombreroooooo',
#   'tengo tantas cosas porque marchar que no sé cuántas pancartas llevar que gonorrea que todos los sistemas y sectores estén en la mierda en este país'],
#  ['SoyMonicaMar', ''],
#  ['ElCapucchino', 'razones sobran no dan ayudas pero dan bolillo'],
#  ['Antifa55460356', 'democracia usurpada por el gobierno fascista'],
#  ['jostin_panza',
#   'espero que la no sea violenta eso lo único que provoca es el desprestigio del movimiento y se opaca el mensaje del mismo'],
#  ['CataGaviiriia',
#   'ojalá no mal entiendan mi punto porque yo estoy muy firme apoyando esto pero siempre nos ponemos a esperar y estas cosas son ya'],
#  ['SebastinForer15',
#   'no nos dejemos ver la cara salgamos a las calles a retomar el 21n pero con más resistencia más fuerza y más furia a pelear por nuestros derechos'],
#  ['Laura_Rod10',
#   'creí que era broma pero hay gente que lo apoya de verdad definitivamente la estupidez humana no conoce el límite'],
#  ['Soniaguer',
#   'todos a contagiarnos que con los problemas que tenemos no es suficiente'],
#  ['Baub__', ''],
#  ['iLordPorky',
#   'les da miedo salir a buscar trabajo pero gustavo petro los manda a marchar y la pandemia no existe'],
#  ['DSOTELOZ', ''],
#  ['richar10rock',
#   'los dioses de las marchas son los gringos ellos sí tienen adrenalina lo llevan en la sangre aguante u s a 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🤘'],
#  ['Os56351001', 'policía criminal'],
#  ['BizarroMesa', '✊🏽'],
#  ['JorgeMr_Paez',
#   'esto fue que fue petro a cuba a planear que iba a hacer y miren con la que salió'],
#  ['ili_llanos',
#   'eso de me parece la estupidez más grande como es que en plena pandemia van a convocar miles de personas a aglomerarse esa no es la forma'],
#  ['wilson9503',
#   'esto se debe tener muy en discusión de la forma política que quieren tomar esta consigna mucho cuidado'],
#  ['Cloqlitos',
#   'tú yo una marcha por los derechos de los ciudadanos no sé piénsalo chiquibeibi 😳'],
#  ['gersonpailitas', 'va a volver trizas el sistema de salud'],
#  ['karenel11199500',
#   'me pregunto qué piensa el personal de salud a que convoquen'],
#  ['Ribartolo',
#   'jodian y jodian para que no levantaran la cuerentena porque todos iban a morir y ahora van a jajajaja esa coherencia me encanta'],
#  ['GigiVirviescas',
#   'porque si no nos mata el virus nos mata este gobierno nos mata la indiferencia'],
#  ['nataliabenavidd',
#   'en serio 🤦🏼\u200d♀️ motivos sobran si pero no es el momento'],
#  ['escuelathemrdog', 'gobiernos de mafiosos con la biblia en mano'],
#  ['lord17572',
#   'señora alcaldesa claramente por la pandemia no se podría autorizar una marcha verdad'],
#  ['Piensa__', 'por la defensa de nuestros derechos humanos también marcho'],
#  ['Oscar_GCh',
#   'me acuerdo cuando todos le recordábamos al que tenía 276 investigaciones meses después él h p completa 300 ¿y todavía se atreve demandar con el fin de protejer su buen nombre'],
#  ['CataGaviiriia',
#   'mi duda es ¿por que vamos a esperar hasta el 15 para salir a marchar de aquí a allá se inventan algo para desviar la atención en mi opinion deberíamos dejar de darle tantas largas a las cosas que se note de verdad que estamos emputados'],
#  ['RAFAELF02343473',
#   'es justo y necesario más de 100 leyes aprobadas a puerta cerrada sin control político y hablan de transparencia y luego el gringo llega a violar niñas y duque se limpia el culo con la constitución no más dictadura corrupta narco traficante paracolombianos'],
#  ['Perreoapocaluzz', 'estoy preparado y listo hasta mi mamá va a salir'],
#  ['SantiMoncada_', 'allá los espero 💪'],
#  ['rozo_juan',
#   'toda la izquierda puede salir a la que la selección natural se encarga del resto 😘'],
#  ['carduar1',
#   'una en donde no se sabe si marcharán la gente civilizada o los violentos como siempre dañan todo'],
#  ['Antifa55460356',
#   'es hora de levantar nuestras voces frente a los líderes sociales asesinados el desempleo y el hambre del pueblo oprimido temas pasados desapercibidos por una pandemia'],
#  ['Carlosbedoya_',
#   'por los asesinatos diario de lideres sociales por la corrupción de alcaldes y gobernadores por la ñeñepolítica etc 🇨🇴'],
#  ['Juanding',
#   'en colombia también la policía nos mata pero acá a nadie le importa'],
#  ['LazyProfe', ''],
#  ['lunapower88', 'really'],
#  ['CSarahelenht',
#   'la verdad hay que decirla sería muy hipocrita de nuestra parte criticar al gobierno por reactivar la economía mientras nosotros promovemos una marcha empezando el pico de la pandemia amigos sin impulsividad no apoyo'],
#  ['CnprCol',
#   'a las calles las veces que sea necesario por nuestros muertos ni un minuto de silencio 🔥🔥'],
#  ['Camarada109',
#   'llego la hora de despertar es inaudito que sigamos dejando a los que juegan a ser dios en colombia seguir con este régimen de terror'],
#  ['Juandatorres24',
#   'por las politicas neoliberal de por los 9 mil millones de pesos que se gasto para sus camionetas blindadas por la invasión de los militares gringos en colombia por todo eso yo marcho este'],
#  ['Gaso40321953',
#   'pregunto petro claudia y sus compinches a quien le van a echar la culpa por el aumento exponencial de contagios y muertes de adultos y abuelos producidos por los adolecentes que envian a las calles y que van a llevar el virus a sus casas aduque a uribe'],
#  ['fsalasparra',
#   'un festivo no es fecha para una marcha 🤦\u200d♂️ de igual forma necesitamos un cambio y para eso tenemos que seguirla el martes miércoles y los días necesarios aprendamos de los gringos una semana seguida en las calles aprendamos de ecuador y chile todos los días'],
#  ['matarife82', 'marchamos por esto maldito paramilitar'],
#  ['DianitaMartin',
#   'definitivamente está vez digo desde casa podemos protestar'],
#  ['La26974565', 'gritemos juntos'],
#  ['gracias_uribe', 'mamertos hijos de puta'],
#  ['EliabRangel2', 'muy pronto en colombia'],
#  ['Dannapa10653407', ''],
#  ['barbie_ensus30',
#   'ojalá a la se unan de alguna forma los abogados litigantes llevamos más de dos meses sin juzgados parece que se nos olvidó que la administración de justifica es un servicio público y el acceso a ésta un derecho fundamental'],
#  ['Son15Letras', 'en nuestras redes ¿pa qué es en la calle y por millones'],
#  ['lord17572',
#   'eso salgan a marchar el 15 y así tendremos cuarentena hasta bueno quien sabe hasta cuando y después peleando por qué la economía y muchas cosas están mal'],
#  ['Oscar_GCh',
#   'aquí uno de los pestilente abogados del mal en épocas cuando el razocinio lo acompañaba hoy que pensará al saber que el perfilador de periodistas y patrocinador de paramilitares a quienes entrenó yair klein es el'],
#  ['DotorMataLawyer',
#   'esos mismos fanáticos son los convocantes y posibles marchantes de la que por supuesto'],
#  ['Esteban55603333', ''],
#  ['Vlad_xciv',
#   'han sufrido por el control y la opresión que les han infundido por algo que ha existido millones de años ha sido la excusa perfecta para jugar con tus miedos y confinandolos en casa frente a una caja diciendo supuestos y entreteniendolos todo esto es pura falacia'],
#  ['Son15Letras',
#   'pero todos sin pendejadas y con constancia un solo día no un solo día no sirve de nada'],
#  ['elunicoeldivino', 'estas son las razones a favor de la favor de y hacerlo'],
#  ['Avargasg131',
#   'en colombia tenemos mil vainas por las cuales protestar sin embargo marchar en medio de una pandemia donde la principal arma es el aislamiento y distanciamiento social las convocatorias resultan bastante irresponsables'],
#  ['LcolombiaM', ''],
#  ['JuanDavidC_',
#   'por anderson por dylan por la corrupción con las ayudas humanitarias en esta crisis del covid19 por los líderes sociales que son muchos por el sistema de salud tan pésimo que tenemos y por cientos de cosas más'],
#  ['peznaranjaTweet',
#   'peznaranja lab es el sistema de tus sueños ya sea que tengas un negocio pequeño una megacorporación o tu oficina lab es la mejor opción'],
#  ['brayanprieto95',
#   'definitivamente la inconsciencia moral de la gente en plena cuarentena y piensan marchar claro sigan como borregos a los que quieren que esto estalle y por fin empiecen a haber muertos en las calles al fin y a cabo un pobre menos para ellos'],
#  ['dana13_31', ''],
#  ['SoyMonicaMar', 'el 30 de junio'],
#  ['JUANBABYLAN', 'que falla ponerle fecha a una marcha 🤦🏻\u200d♂️'],
#  ['Estrella_Calva',
#   'comparto tu opinion se unio todo el mundo para apoyar a estados unidos y quien nos apoya porfavor los que tengan influencia ayudar ayuden que nos escuchen'],
#  ['mochilaWayuu',
#   'o se marean si nos vamos a marear que sea por el lacrimógeno mientras protestamos por lo nuestro'],
#  ...]

# %% [markdown]
# - ## Replace the emojis for their names

# %%
# !pip install emoji
import emoji # Emoji codes
# Out:
# Requirement already satisfied: emoji in /home/daniel/.local/lib/python3.8/site-packages (1.7.0)

# %%
#This function replaces emoticons by their names
#Input: List of tweets to be processed
#Output: List of processed tweets

def replace_name_emoji(list_text):
    list_name_emoji = []
    for l in list_text:
        name_emoji = emoji.demojize(l, delimiters=(' ', ' ')) #Delimiters to be put before and after the emoji meaning
        list_name_emoji.append(name_emoji) 
    return(list_name_emoji)

# %%
#Test the function replace_name_emoji
text1 = 'en completo desacuerdo con las politicas de estado 🤮'
text1 = replace_name_emoji([text1[i] for i in range (len(text1))])
print(text1)
# Out:
# ['e', 'n', ' ', 'c', 'o', 'm', 'p', 'l', 'e', 't', 'o', ' ', 'd', 'e', 's', 'a', 'c', 'u', 'e', 'r', 'd', 'o', ' ', 'c', 'o', 'n', ' ', 'l', 'a', 's', ' ', 'p', 'o', 'l', 'i', 't', 'i', 'c', 'a', 's', ' ', 'd', 'e', ' ', 'e', 's', 't', 'a', 'd', 'o', ' ', ' face_vomiting ']

# %%
tweets = replace_name_emoji([text[i][1] for i in range(len(text))])
tweets = [tweets[i].replace("_"," ") for i in range(len(tweets))]
text = [[users[i],tweets[i]] for i in range(len(users))]
text
# Out:
# [['DiegoTorresCast',
#   'marchas programadas para el 15 de junio en plena pandemia definitivamente la insensatez reina en colombia'],
#  ['dariocaicedo0',
#   'vamos a marchar nadie se va enfermar xd todos estaremos con muchos cuidados'],
#  ['dariocaicedo0',
#   'ok vamos a regresar a marchar bien chimba hp contra este gobierno de mierda'],
#  ['rockero1901',
#   'no podemos dsrle espera a las causas sociales es sierto que enfrentamos una pandemia pero y las muertes a causas de las fuerzas armadas q deberian cuidaenos la cuarentena que es un privilegio de clases la corrupción la de forestación el abandono con toda15'],
#  ['Insurrsion',
#   'los uga uga cavernícolas onvres y mugerez que se oponen a la son los que comen como borregos de rcn y paracol'],
#  ['Antonio163016', ''],
#  ['Margari97231178',
#   'la hipocresía de los noticiero colombianos vendidos y corruptos'],
#  ['DePorDiosMayer',
#   'avisenme si esta vez si vamos a tomar en serio la protesta y vamos a armar una verdadera revolución porque si es pa tomar chocolate con los del esmad prefiero quedarme en mi casa gracias'],
#  ['Paozroca1',
#   'no salgo a marchar por nuestra salud pero no significa que no levante mi voz de protesta por todo lo que está mal en este país usaré mis redes sociales como medio para protestar'],
#  ['Carolin15498454',
#   'no seas como que sólo apoya a usa tenemos que hacer algo por el país'],
#  ['CazaSarcasmos',
#   'y en que cambia el país no a la marcha del 15 de junio respeto la vida de los médicos'],
#  ['licethpao123',
#   'el gobierno empezará una semana antes a aplacar la curva del covid19 y después de la marcha aumentará la cifra de contagios  face with rolling eyes  face with rolling eyes nuestra polombia sumergidos en la ignorancia de la ultraderecha'],
#  ['ETV1122',
#   'no que les pasa son retrasados mentales o que¿‽ ya estamos en bajada de casos no hagan eso háganlo después cuándo tenga suficiente neuronas para pensar y que aprenda a tender la cama no se tiren más el país'],
#  ['Astro27350111',
#   'yo voy a demandar a el presidente por vulnerar mis derechos si me muero de hambre el presidente tiene la culpa y si me muero por covid 19 es por que el precidente se robo la plata y no hay respiradores'],
#  ['CazaSarcasmos',
#   'me van odiar por esto pero y si salen los que no tienen empleo los que no tienen recursos porque los que tienen no se van a exponer entonces esos que salen se enferman y toca ver cuantos tienen salud porque si el sistema no es bueno pero para que retarlo'],
#  ['juanfel16448123', 'por una colombia libre de corrupcion'],
#  ['Oscar_GCh',
#   'y 100 líderes asesinados también lo que va corrido del año y para eso si hay esmad fuerzas militares armamento para defensa y asesoría gringa el artífice de esta matanza'],
#  ['GLondoo2', 'protestas en vivo en washington d c'],
#  ['hernanmorenoe',
#   'está cerrando las puertas de la democracia así rechaza la búsqueda de soluciones el país quiere paz con justicia no el estado tomado por la mafia y la corrupción'],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['BobaHijueputaaa', ''],
#  ['Angie_SM98',
#   'yo se necesita hacer justicia soy una persona insignificante pero tengo mis derechos y por eso marcho hay que alzar la voz y hacer que todos esos malditos paguen mi mamá'],
#  ['_kaatooo', 'ya sabes cuándo'],
#  ['GLondoo2',
#   'siguen las protestas en vivo en washington d c live video protest protestas en vivo'],
#  ['Astro27350111',
#   'vamos todas a exojir lo que es de nosotros estudio salud trabajo y 0 maltrato de la policía ah y que renuncien todas esas ratas de políticos'],
#  ['AcademicallAse1', ''],
#  ['dana13_31', ''],
#  ['Calcor70',
#   ' rolling on the floor laughing  sin tapa bocas sin gel anti bacterias y sin distanciamiento social  middle finger hagan lo que les dé la puta gana después no se quejen si les da covid 19 y que los atienda quien los convoca a su marcha  OK hand '],
#  ['ElVueloVacio',
#   'buenos días a todos menos a esos humanos que les da por convocar marchas con distanciamiento social en medio de una pandemia a esos no por demagogos e irresponsables'],
#  ['_kaatooo',
#   'yo salgo a la por la corrupción en medio de la pandemia por la ñeñepolitica por cada líder social asesinado por los indígenas y afros por la naturaleza y su cuidado ¿hay motivos para no salir a marchar prefiero morir de que de indiferencia'],
#  ['PamelaVelezH', 'me fuiii'],
#  ['Oscar_GCh',
#   'aquí uno de los barra brava y defensores del mal en épocas cuando el razocinio aún lo acompañaba hoy qué pensará al saber que el perfilador de periodistas y patrocinador de paramilitares a quienes entrenó yair klein es el'],
#  ['edwarkenw861245', 'los esperan para el baile pero con el ataúd de cartón'],
#  ['CrisFlorez07',
#   'aquí nos tratan de vándalos pero allá sí legitiman la marcha'],
#  ['lopezfco', ''],
#  ['Marcela6C', 'esos deseos me dan más ganas de apoyar la'],
#  ['oskarciber',
#   'contra un gobierno corrupto que se tomó el poder si el pueblo se levanta se les acaba el juego'],
#  ['Generalsandrita',
#   'pretedenden quebrar la economía que se pare la producción ya que es el estado ideal en socialismo pilas después no digan que no le avisaron'],
#  ['Jorgetolds1219',
#   'vamos a marchar no mas vamos con toda no importa la pandemia mire todo europa como esta estados unidos y a nosotros nos matan mas lideres y nadie hace nada'],
#  ['NatieeeG',
#   'acabo de ver que es tendencia también por la indignación que provocan decenas de asesinatos de líderes sociales en colombia'],
#  ['AngleleeB', 'colombia necesita paz'],
#  ['AngleleeB',
#   'salgamos a marchar a protestar y la verdad duele en el alma colombia al saber de que no somos capaces de luchar por nuestros derechos piensen en lo que nos espera a la futura generación'],
#  ['PijAnon',
#   'el que quiere llevar fútbol a la tv más agro ingreso solidario más mano dura etc con tal de distraer la opinión pública del problema real el veneno de colombia'],
#  ['AngleleeB',
#   'no entiendo y no me cabe en mi cabeza como hay gente que todavía preguntan que por cual razón debemos salir a las calles a protestar en colombia queremos que el gobierno le vea la cara al pueblo que luchemos por lo que queremos que se acabe esta desigualdad'],
#  ['javiwar',
#   'es la estupidez más grande de gente con cerebro pequeño como este petardo y que siga la propagación del virus nojoda es que no pueden ser más brutos'],
#  ['AndersonAlzateL',
#   'realmente sino estuviéramos en un proceso obligatorio de salud yo saldría a la hay muchas razones exigir justicia ante los escándalos una ley más fuerte contra los corruptos seguridad en el territorio implementación del gobierno y la plata de la emergencia'],
#  ['EdisonStevenRi1',
#   'los que quieren iniciar la en colombia saldrán a protestar de verdad ¿o a desbaratar las ciudades y generar disturbios con actos vandálicos como en la casa blanca luego dicen que la autoridad abusa cuando el único objetivo de algunos es salir a robar'],
#  ['Javi_ERH',
#   'porque en colombia nos debe doler primero los más de 200 líderes sociales asesinados en los últimos 2 años'],
#  ['lopezfco',
#   'el problema es que el nos van a mandar a encerrar en la casa con alguna excusa así actúan las dictaduras'],
#  ['Lictius',
#   'locombia país en que en plena pandemia fecode organiza una marcha es decir anuncia que va a cometer un delito para propagar el virus que nos tiene confinados a muchos desde hace dos meses van a dar los permisos para marchar los alcaldes'],
#  ['sheriith',
#   'yo me considero una persona ignorante en cuanto a historia y las fechorías de los políticos pero siempre apoyaré el hecho de que los dejen en evidencia y me sumo a'],
#  ['EduardoAbelRom1',
#   'todos a las calles no podemos seguir callados mientras el porcino se roba nuestros recursos'],
#  ['PaolaAn85777033',
#   'en serio nos encerramos 3 meses para salir a marchar bobotes'],
#  ['Alejand32574510', 'nooo'],
#  ['germanecabrerao', ''],
#  ['CarlosReey',
#   'de verdad van a poner a prueba las uci no jueguen con la suerte así que irresponsables'],
#  ['wverodr79',
#   'por favor que marchen todos sin tapabocas y antes de la marcha firmar el desestimiento de la uci gracias buenos para nada'],
#  ['germanecabrerao', ''],
#  ['germanecabrerao', 'no debemos graduarnos de pendejos'],
#  ['KlausGoebel',
#   'tenemos derechos y libertades también tenemos deberes marchas sin violencia es un momento difícil en colombia y en el mundo construir país en paz en sana convivencia y respeto sin odios si se puede hermosa colombia adelante'],
#  ['verdolaga2323',
#   'es irresponsable salir en pleno pico epidémicologico la protesta es un derecho por supuesto pero por qué hacerlo en plena pandemia y ojala recuerden esos colombianos que mueren por pisar minas y combatir el nacotrafico'],
#  ['jusepu', '¿no más goles'],
#  ['JuanGuarin11', ''],
#  ['alexcastellan07',
#   'y si salimos desde ya eso de programar marchar hace que esté más preparada la maquinaria corrupta en complicidad con el smad para vulnerar nuestros derechos y para que se infiltren y generen caos'],
#  ['JohanMa20', ''],
#  ['BENJAMINGARZON7', 'listos'],
#  ['oskar4791', ''],
#  ['Donatell131', 'para la calle los superamos 1 en un millon'],
#  ['PUBLINET8', ''],
#  ['Donatell131', ''],
#  ['ARicardoBenitez',
#   'porque a diario mueren más por el virus de la corrupción'],
#  ['mochilaWayuu',
#   'ya lo teníamos son los líderes y lideresas sociales asesinadas son los niños que mueren de desnutrición por olvido del estado son los niños muertos en el bombardeo son los falsos positivos etc'],
#  ['PaitoCas',
#   'esa gente que pregunta porque salir a protestar en plena pandemia es la misma gente que está cómoda con la realidad del país solo les recuerdo que si no nos mata el virus nos va a matar la desigualdad la injusticia y la corrupción'],
#  ['SergioM0614',
#   'los que querían que claudia lópez quitara la cuarentena ahora si critican qué haya'],
#  ['mafaldagallego',
#   'muy valiente desde la comodidad de su casa llamar a los pendejos a una marcha para que se contagien y uds ni siquiera han ido al congreso a trabajar face with symbols on mouth  irresponsable'],
#  ['Andresg0689', 'contra este puto gobierno corrupto'],
#  ['GREG09751392',
#   'la marcha de los idiotas para intentar tapar la volada del jefe petro a cuba no se salva'],
#  ['pposejo',
#   'ojalá salgan todos sus seguidores y los del y entre todos se abracen y protesten para que el virus haga lo suyo se llama selección natural lo dijo darwin'],
#  ['andercal24', ''],
#  ['javier_zulia', 'un marcapasos para aida'],
#  ['ARicardoBenitez', 'con bandera y tapabocas salgo'],
#  ['sevilla11_karol',
#   'tengo mucha impotencia todo lo que esta pasando en este mundo cuando será que la policía no va abusar de su autoridad y no van a matar a negros por ser racistas creo que me voy a quedar esperando este cambio por que nunca va a pasar'],
#  ['yeison_fox',
#   'no estaban luego ayer poniendo imágenes negras en sus perfiles hipócritas de mierda se les pide aquí actuar y les da miedo'],
#  ['arleytrujillo7', 'tod@s a las calles por q se haga justicia'],
#  ['sevilla11_karol', 'motivo'],
#  ['sevilla11_karol',
#   'todos piensan en la pandemia y todo en parte tienen razón pero parce acá uno tiene valer su vida los policías somo por que son autoridad tiene derechos hacer esas cosas pues no acá todos somos humanos que esa marcha se haga por gente que está arriba sin ningún'],
#  ['yeison_fox',
#   'aplauden protestas en estados unidos pero se convoca en colombia y les asusta la pandemia me asusta ma sola pandemia de hambre y sangre que agobia este platanal'],
#  ['TutaDiego',
#   'todos a las calles por más aglomeraciones más contagios más muertes más coronavirus más aislamiento y cuarentena más crisis hospitalaria más crisis económica más decretos de duque'],
#  ['mafaldagallego',
#   'la economía cerrada negocios en quiebra y preparan marcha face screaming in fear  que irresponsables mejor no se hubiese implementado la cuarentena y todos contagiados pero con empleo'],
#  ['yeison_fox',
#   'contra el fascismo que estos sometidos durante está pandemia'],
#  ['arleytrujillo7', 'para q metan a a la carcel'],
#  ['SteffaniaRo', 'salgo'],
#  ['JohnGO92',
#   'cule marcha organizada con dos semanas de anticipación sin cero espontaneidad de parte de nosotros no valemos es verga'],
#  ['sevilla11_karol',
#   'vamos a marchar por todas esas personas que no pudieron estar y vamos a pelear por todos'],
#  ['Carlosa83209358', ''],
#  ['OracionesPara',
#   'no asistiré porque respeto mi vida y cuido a mi familia pero me gusta que muchos  pig face  vayan a la esa depuración le sirve a colombia  beaming face with smiling eyes '],
#  ['Elquenadasabeo1',
#   'señor y colombia humana están dispuestos a lo que sea por llegar al poder incluso a por sobre la sangre se la gente como pasó a principio de año cuando decían que eran toda colombia cuando en realidad solo era el petrismo'],
#  ['FilosofoImpuro', 'esto no se logra con marchas ya está demostrado'],
#  ['Elquenadasabeo1',
#   'los mismos que criticaban al gov por no cerrar el aeropuerto por el asilamiento inteligente por abrir reactivar el mercado son los mismos que están promoviendo la yo les digo no mas manipulación de la disque oposición'],
#  ['David08642453', ''],
#  ['jomach35',
#   'muero de ganas de ver estrenar los nuevos juguetes del esmad  clapping hands  clapping hands  clapping hands  clapping hands  clapping hands  clapping hands #marcha15dejunio'],
#  ['Ivager69',
#   'ciudades en el mundo marchan contra el odio y racismo policial que también se ve en btá es hora de despertar de verdad dónde están estudiantes maestros desempleados sindicatos es hora de reclamar y decirles no más a los corruptos y a los violadores de ddhh'],
#  ['Gaso40321953',
#   'todos los contagios y muertes de adultos y abuelos después del 15 de junio son culpa de petro bolívar cepeda claudia etc y de los adolecentes que van a llevar el virus a sus casas no hay escusas serán asesinos de sus padres y abuelos'],
#  ['David08642453', ''],
#  ['TutaDiego',
#   'en pleno aislamiento en plena cuarentena en plena pandemia es enserio los que promueven esto de verdad que son inconscientes e irresponsables si lo que quieren es destruir las ciudades y el país ya tendrán tiempo después cuando no tengo ni puta idea'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['MiguelP51520329',
#   'lo bueno de la es que saldrán muchos mamertos de izquierda y el coronavirus estará presente para aniquilarlos para siempre todo puede pasar se aniquilan sólitos señores sólitos'],
#  ['joseale30251145',
#   'mamados de tantos decretos presidenciales tan mediocres'],
#  ['alejorcasta',
#   'a las calles por todos nuestros muertos lideres sociales indigenas estudiantes profesores'],
#  ['hernangarcia98',
#   '“tenemos que despertar y no quedarnos callados” spike lee'],
#  ['cesfit7',
#   'otra de las razones por la cual marcharemos que verguenza de congreso ahora no solo tenemos que lidiar con su manera de robarnos si no que hay que sumarle la desfachatez para realizar su labor'],
#  ['Elquenadasabeo1',
#   'a los que promueven la absurda ustedes no son oposición no representan nada sabemos que son el vano intento de un político de cuyo nombre no quiero ni recordar por ser elegido en las próximas elecciones presidenciales'],
#  ['redcajapandora', ''],
#  ['maleja_28_', 'será como el'],
#  ['Ang_Altamirano',
#   'el desempleo por encima del 20 la reforma tributaria que se nos viene para tapar el hueco gigante de lo poco que han repartido más lo mucho que se han robado la corrupción cada día más descarada y la justicia creada para librar al que tiene motivos existen'],
#  ['Elquenadasabeo1',
#   'la disque oposición lista para mandar todo al garete en la es por eso q esta gente no puede ser considerada oposición ni nada mas que un grupo criminal acaso no entienden que ha una pandemia no ven q sus disque protestas pacificas han hecho mas daño q bien'],
#  ['LaGwens',
#   'pa’ mi es una irresponsabilidad sí hay infinitas razones para salir a protestar pero no es el momento yo por allá no voy'],
#  ['Vladmizar6',
#   'buen dia hombre mucha para vos y toda la genté hoy cierto que quedo decente agradeco si ayudas a difundir la buena compa y prepararse con toda para  Colombia  monkey face  flexed biceps '],
#  ['o_agudelo75',
#   'en una economía golpeada a los genios de siempre se les ocurre ¿por qué no practican un deporte que pereza la gente inconsciente'],
#  ['LuIsOvEjO', ''],
#  ['latriplehp5678', ''],
#  ['delmontonsoy',
#   'para que los hps salgan a contagiarse masivamente de covid19 y lleguen a sus casas a joder a sus familias asesinos'],
#  ['JaimeAlonsoPar6',
#   'a la calle para exigir al narcogobierno o a la narcodictadura que cese su hostilidad contra el pueblo'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['josevecinop',
#   'el efecto dominó del derecho a la justa protesta y la responsabilidad de cuidar a la familia'],
#  ['mariafe37834240', 'nos vemos en las calles'],
#  ['mrwatch808',
#   '¿en serio y porque esta única vez los afrodescendientes si importan es una hipocresia cuando en choco y otras tantas partes de colombia hay muchos anderson sin oportunidades e inmersos en una guerra causada por el famoso acuerdo pero esos no merecen marcha'],
#  ['nano1960',
#   'la apoyo pero 1 día suficiente para desahogarnos pero no servirá para cambiar mejorar el pais sera otro saludo a la bandera un mes paro'],
#  ['Alfredoboita1',
#   'se acabó la valeriana en colombia el matarife se la tomo toda'],
#  ['tostadadeatun1',
#   'el mundo necesita la verdad ironia una organización con máscara contando más que toda la iglesia nada más que cuentos de disney'],
#  ['sin_praxis',
#   'las protestas y reclamos que se quiere hacer al gobierno son legítimos pero no olviden que en colombia el solo es una campaña publicitaria no esperen condescendencia de nuestros medios de comunicación a las causas colombianas'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['jairoroa171',
#   'aquí el mundo nos está mostrando que ni los gobiernos ni autoridades van a seguir abusando y en colombia una de las razones de éstos abusos es la permisividad de la justicia con el y sus secuaces por éso como pueblo vamos a derrotar ésas injusticias'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['rpegazo',
#   'el símbolo de la gente imbecil y demasiada enferma de este país álvaro uribe vélez argiro corte suprema en repudio por el asesinato de anderson a manos de criminales policías yair klein juanpis gonzález corte suprema'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['luchocontrerasp',
#   'cómo puede decir que reberlde con causa si has estado en todas las mermeladas presidenciales ahora el pueblo es quiénes deberíamos ser los rebeeldes con justa causa'],
#  ['So_lecito',
#   'en colombia matan diariamente a líderes sociales e indígenas y yo no los veo poniendo una imagen negra en redes es que los muertos extranjeros valen más'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['EliasLavoz1',
#   '¿y ahora cuál es el motivo de la famosa marcha estamos en una situación de la cual debemos estar unidos como país para salir adelante no para “revolucionar” el corazón de otros'],
#  ['robertpenuela',
#   'que no se quejen déspues es un delito contra la salud pública y violación de medida sanitaria pero el que llego de cuba no le importa enviar incautos a la calle a contagiar y contagiarse con tal de incendiar el país por su sed de poder'],
#  ['oskarciber',
#   'a marchar y protestar contra el narco estado la ñeñe política y el silencio cómplice del gobierno de uriduque por narco embajador sanclemente'],
#  ['Andres_Lopez13',
#   '¿y nuestra indignación pa cuándo pal 15 de junio todos a las calles'],
#  ['Vcv173',
#   'se suponía que ud iva a expropiar las tierras si ganaba las elecciones ahora que dirán los uribestias pobres tirados a capitalistas que tienen fincas pequeñas heredadas de su familiar indígena que detestatan y no producen por qué son de derecha'],
#  ['PATRICI20413620',
#   'a estas alturas de la vida para mi marcha es sinónimo de destrucción y también de contagio'],
#  ['Alfredoboita1', 'el líder de la banca criminal más grande de colombia'],
#  ['occiauditores',
#   'no a marchas no aglomeraciones ni clases en aulas no saben ni imagina qué es no poder respirar deberían los medios hacer más publicidad con testimonios de los que se están ahogando con el virus por dentro incredulidad hasta cuando se ahoguen'],
#  ['oskarciber',
#   'contra el saqueo solidario robar plata en plena pandemia es un acto criminal'],
#  ['cesp2010', 'con toda'],
#  ['Sebastian_xdxd1', '¿listos para quemar tombos este día'],
#  ['PaoSalazT',
#   'es real o va a pasar como con el paro que llegó diciembre y el paro también se fue a vacaciones porque ahí el referente fue chile qué se haga por convicción no solo porque el mundo alrededor está ardiendo y pues cómo nos quedamos atrás en tendencia'],
#  ['OGalvisC',
#   'son muchos los llamados que se le han hecho al gobierno pidiendo protección a los líderes sociales núnca han querido atender los llamados por eso'],
#  ['AlexMartinez258', ''],
#  ['oskarciber',
#   'por la soberanía no a las bases militares gringas en colombia no somos el patio trasero de trump'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['sanntiago_er', ''],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amaestrados sus idiotas útiles pandemia'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['Alfredoboita1',
#   'investigado por homicidio por masacres por narcotrafico por chuzadas por corrupción por paramilitar no hay delito donde no esté involucrado el matarife de uribe ya es hora que pague carcel'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['weinsh3z',
#   'un escudero de las convivir él concibe la paz únicamente como resultado de una victoria militar sobre los alzados en armas iván duque al parecer el duque del pasado les da sopa y seco a los periodistas del presente  person facepalming  backhand index pointing down '],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', ''],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['juanpariasl',
#   'es el reflejo de lo que quieren y representan para este país muchos tratando de ver como sacan adelante a y otros como poner palos en la rueda'],
#  ['oskarciber', ''],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', 'éstas son las razones para'],
#  ['juanpariasl',
#   'es en serio cuando estamos ante la peor tragedia de la historia y pensando en esto'],
#  ['cabrales_ospino', ''],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['Alfredoboita1',
#   'estos son los policías que asesinaron a dylan cruz y anderson arboleda demosle retwees para que no se olvide'],
#  ['milostickersas', 'acabo de ver que se está convocando a'],
#  ['oskarciber',
#   'no más esmad y abuso policial derecho a la protesta social legítima'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['OGalvisC', ''],
#  ['cabrales_ospino',
#   'maldito comunismo maldito socialismo salgan ustedes manada de borregos'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['oskarciber',
#   'por las víctimas del paramilitarismo en colombia no más narco paraco uribismo'],
#  ['trampastejo',
#   'petroincendios y asociados quieren llegar al poder generando caos violencia por vía de la democracia no tienen respaldo tienen amestrados sus idiotas útiles'],
#  ['alejo2000_2000',
#   'las marchas para el 15 de junio nos permitirá ver que tan letal es el virus sin confinamiento de las personas si el virus es muy contagioso y letal reducirá el número de manifestantes en el futuro cercano'],
#  ['OGalvisC', 'no más asesinatos justicia ya'],
#  ['oskarciber',
#   'no más narco paraco uribismo asesino en colombia  Colombia  no más genocidios y asesinatos'],
#  ['OGalvisC', 'justicia ya'],
#  ['Liliana09695487',
#   'yo no estoy de acuerdo con esta marcha no ven que estamos pasando por una terrible epidemia que ganan con eso propagar más este virus si no se hizo nada antes de esta pandemia mucho menos ahora alcontrario van a empeorar esto  pouting face '],
#  ['OGalvisC', 'por los miles de líderes sociales asesinados justicia ya'],
#  ['Oscar08464952',
#   'si comparan el socialismo con desigualdad porque no equiparan el capitalismo con riquezas para todas'],
#  ['Angela9637', 'el verdadero y más peligro virus ves el estado'],
#  ['OGalvisC', 'justicia ya'],
#  ['chocante25',
#   'por racismo y no se acuerdan que un señor metió varias personas en una iglesia y las quemó lo más hijueputa es que esta con una curul en el senado chimba de país'],
#  ['oskarciber',
#   'en colombia cada día asesinan cobardemente lideres sociales defensores de derechos humanos ambientalistas ex guerrilleros que dejaron sus armas reclamantes de tierras y no pasa nada no más indiferencia cómplice vamos a las calles'],
#  ['jorgelopez59', ''],
#  ['jorgelopez59', ''],
#  ['jorgelopez59', 'hipocresía'],
#  ['OGalvisC', ''],
#  ['Angela9637',
#   'despertar ya este gobierno farandulero y banquero es un derecho vque tenemos'],
#  ['Edna_moliina',
#   'ustedes lo que quieren es contagiarse de covid 19 para culpar al gobierno y pedir mas ayudas'],
#  ['iSamuelES', 'vamos'],
#  ['oskarciber',
#   'los del esmad saldrán a estrenar sus uniformes para reprimir la protesta social legítima mientras personal médico no tiene dotación para enfrentar pandemia'],
#  ['SebazZz_14',
#   'que impotencia no poder hacer ni mierda para evitar la hijueputa'],
#  ['Antonio163016',
#   'vamos colombia entusiasmo con dignidad y amor sin cobardía'],
#  ['ReyLenidas3',
#   'desde que la lo llama a indagatoria es porque tiene pruebas a la mano contra y ahora sí se le acabó el derroche porque se le vienen las otras con extinción de dominio'],
#  ['croactibo',
#   'vamos apoyar a en esta marcha que sea multitudinaria que sea la marcha más grande nunca vista en colombia con abrazaton besaton cojida de teta al aire de las feministas y tal y que repartan hasta para llevarles a la casa de sus padres  rolling on the floor laughing '],
#  ['oskarciber', ''],
#  ['algrano_ibarra',
#   'las ganas de generar violencia son infinitas acab justicia para todo el mundo no al abuso de autoridad todos a las calles'],
#  ['oskarciber',
#   'en memoria adilan cruz y george floy asesinados por un policía'],
#  ['Matto04981427', 'cuenten conmi apoyo'],
#  ['JuanDiego_CG', ''],
#  ['JuanDiego_CG', ''],
#  ['Antonio163016', 'contra estos sinvergüenzas también es la'],
#  ['elkin197628', ''],
#  ['Lachavitadel8', 'recomendaciones para la primero la salud'],
#  ['JuanRicardoAgu8',
#   'de verdad piensan salir a una marcha por las calles en 12 días verdad hay alguien que lo va a hacer pero lo más tenaz creen que sirve de algo de verdad'],
#  ['_sancheezp', 'cómo sería entonces para la'],
#  ['Antonio163016', ''],
#  ['Antonio163016',
#   'la puta de babilonia quiere acallar los gritos de hambre de inconformismo quiere acallar las marchas'],
#  ['group_pepe', ''],
#  ['group_pepe', 'trece días es demaciado tiempo pero hay estaremos'],
#  ['Antonio163016', 'colombia'],
#  ['elkin197628', ''],
#  ['Leonorgs_24',
#   'por él por nuestros afros por la brutalidad policial por la educación por la ñeñe política'],
#  ['Antonio163016', ''],
#  ['Antonio163016', ''],
#  ['Antonio163016', 'necesitamos de su energía al igual que el 8 12 2019'],
#  ['SebazZz_14',
#   'me parecen las razones lo que no me parece es el momento para hacerlo ignoran por completo el tema'],
#  ['Arquiman2', 'ñeros peligrosos'],
#  ['Arquiman2', 'saqueos'],
#  ['Arquiman2', 'robos'],
#  ['RobertoMTico', 'todos a las calles me sigues te sigo'],
#  ['septimoartecol',
#   'especial  woman artist  parte 4 edmonia lewis 1844 1907 escultora de origen haitiana y ojibwe la liendra'],
#  ['Merseysound23',
#   'por anderson por dylan por nuestr@s muert@s nos volveremos a encontrar'],
#  ['iam_jhoanp', ''],
#  ['bolivarjk',
#   'ya es hora de sacar a la mafia del poder si queremos un futuro'],
#  ['ingdeas',
#   'una mentalidad destructiva y poco sensata quieren el caos perse y tienen como forma de hacer política la primitiva búsqueda del odio'],
#  ['RobertChilito',
#   'enrique oramas agricultor orgánico y productor de alimentos saludables asesinado en su casa ya son 100'],
#  ['RobertoMTico',
#   'me uno a esta iniciativa un estado en sus tres ramas del poder público completamente arrodillado a la cultura d la muerte al a la corrupción al narcotráfico a la compra d votos a la injusticia al sistema financiero etc solo merece desprecio'],
#  ['iam_jhoanp', ''],
#  ['andrudel',
#   'concuerdo con y en qué la situación no es la adecuada para la pero la situación del país indigna a la mayoría de los colombianos y las personas ya no aguantan más'],
#  ['Mar_Cherbonneau',
#   'y a esto hay que sumar incumplimientos del acuerdo de paz políticas favoreciendo tenedores de mala fe chuzadas ilegales del ejército cuyo destinatario es el señor uribe tropas extranjeras sin consultar al congreso ingreso solidario para artistas millonarios'],
#  ['Mar_Cherbonneau',
#   '¿por qué nunca leo ni veo ni escucho por pelmazos hipócritas y descriteriados como este tipo'],
#  ['Sroldang', 'que de poder'],
#  ['GoDiegoGo017',
#   'por la brutalidad policiaca por anderson arboleda por los líderes asesinados por la corrupción de derecha e izquierda porque solo marchando se sentiran acorraladas las ratas esas'],
#  ['iam_jhoanp', ''],
#  ['KillerDoge',
#   'para todos los que ven y apoyan las marchas en estados unidos a causa de la brutalidad policial en nuestros paises pasa todos los días'],
#  ['iam_jhoanp', ''],
#  ['iam_jhoanp', 'unamos esfuerzos para combatir lo que nos pasa en el país'],
#  ['Ferjoher1',
#   'yo marcharé porque ya me canse de que el matarife haga lo que se le dé la gana jarto del gobierno títere y de las porquerias que hace esa es mi razón'],
#  ['Numa08053160',
#   'esa me lo mamá y estoy dispuesto a peliar con argumentos  worried face '],
#  ['gonzzo91',
#   'les recuerdo que las marchas son para que se haga justicia por el racismo y el abuso policial no para tomar cosas personales en contra de un lado político'],
#  ['Oscar08464952',
#   'no tenemos miedo no tenemos miedo matarife prensa arrodillada si no se ponen a favor del pueblo también para la mierda hptas'],
#  ['KevinMarinOC',
#   'ahora nos toca ha nosotros  raised fist medium-light skin tone  black heart '],
#  ['natsinpena',
#   'marica yo no sé si sea buena idea esta marcha estoy entre sí y no tal vez no debamos no es el momento dado estamos en mitad de pandemia suerte a los que vayan cuídense mucho psdt será que pega tanto como el 21 de noviembre k nervios'],
#  ['Gar4780',
#   'me preocupa que el sistema de salud está a punto de colapsar por esta pandemia y ante todo debemos evitar aglomeraciones las protestas son un derecho pero bajo estas circunstancias es irresponsable por eso no apoyo la'],
#  ['LaTropaChibcha',
#   'entre otras por que uribe debe pagar algún día por ser el jefe de corrupción y paramilitarismo mas grande que haya visto colombia'],
#  ['didiersanchez26',
#   '5 tips no más en colombia no mas racismo no tropas estadounidense abuso de los policías colombiana la corrupción en plena cuarentena no mas violencia a nivel país colombiano'],
#  ['jhonnisjk',
#   'porque nos programamos para aser el ridiculo donde tenemos que salir a pedir justicia estamos hartos de el abuso de poder tanto como politicos como la policia que en ves de proteger lo que asen es lucrarse de la nesesidad ajena'],
#  ['ReyesSalmha',
#   'por qué al igual que aquel periodista y líder para muchos jaime garzón yo creo que esto tiene salvación y somos nosotros la juventud quienes tenemos la dirección correcta hacia un mejor país'],
#  ['paissinyugos', 'reaccionaaaaa'],
#  ['Oscar08464952', 'que pena y jesús también era comunista'],
#  ['momofronaldo',
#   'si muy bueno lo de pero si lo van a hacer bien porque si es para alborotar por 5 días y después cada uno para su casa como todas las perras marchas de este país que no logran nada mejor se quedan y no arriesgan a un contagio'],
#  ['daniellozada99',
#   'a manifestar las inconformidades contra este inneficiente sistema político y económico creemos en la paz y los cambios radicales no se justifica ningún tipo de violencia'],
#  ['alexcrios1999',
#   'tenemos miedo pero también queremos un mejor país un mejor futuro una mejor educación un plato donde comer una casa donde vivir una mejor salud tenemos miedo pero este gobierno nos tiene que escuchar'],
#  ['wmejialo', ''],
#  ['RumikoStephanie',
#   'lo sé y estoy de acuerdo pero considero que n este momento son importantes nuestros padres abuelos e hijos ellos serían los perjudicados no el gob y obvio que a las calles debemos volver para que seamos escuchados pero no poniendo en riesgo a los nuestros'],
#  ['Marcha15deJunio',
#   'un botellazo en la cabeza de un patrullero de la gloriosa acabó su vida'],
#  ['ssssssebas',
#   'si de veras supieras por qué criticamos al gobierno los que promovemos la borrarías este tweet'],
#  ['Anascupar',
#   'le dije a mi mamá gorda si hay que salir a marchar acá tú sabes que yo tendré que salir verdad ajá pero llevas tapabocas y no te toques mucho la cara si mami me compro la careta de la gorra'],
#  ['Marcha15deJunio', 'en colombia el racismo también es sistemático y letal'],
#  ['Marcha15deJunio', ''],
#  ['Marcha15deJunio', ''],
#  ['RumikoStephanie',
#   'critican al gobierno porque no consigue que la gente respete la cuarentena pero van a salír el 15 de junio en fin la hipertensión xd'],
#  ['Marcha15deJunio', 'caerá el que dio la orden'],
#  ['Marcha15deJunio', 'colombia se cansó'],
#  ['CAROLINAD10A', 'recuerden no hay tanqueta pa tanta gente'],
#  ['AngieVal2226',
#   'hay que luchar juntos por el amor la paz la igualdad el respeto el país y nuestro pueblo maldito sea el soldado que apunte su arma contra el pueblo simón bolívar'],
#  ['Likar105',
#   'vamos salgamos a las calles exigimos nuestros derechos justicia social la brutalidad de la fuerza pública los falsos positivos que se activaron otra ves'],
#  ['stevenoosd',
#   'no estoy de acuerdo con que salgan a marchar en estos momentos si no lo hicieron antes de la pandemia ahora si piensen en sus familias marchar ahora solo hará aglomerar más personas e incrementar más casos y más muertas por el virus quédense en casa'],
#  ['TenoriKoi',
#   'quería hacer una lista de razones para marchar pero ¿en serio hay que nombrarlas ¿hay algo bien en este país ¿en serio no vamos a cambiar muy lindo que apoyen protestas en otros países pero a ver si hacemos algo con el nuestro y apoyamos al mismo pueblo'],
#  ['juanshootss',
#   'los héroes en colombia si existen y son esos mismos que por empatía con el cuerpo médico no saldrán a la a contagiarse u colapsar el sistema de salud crack'],
#  ['ldsjota16', 'todos son todos'],
#  ['Harol72860060',
#   'cómo todo en este país ¿ que hacemos nosotros para mejorarlo criticando e insultando no hacemos nada'],
#  ['Harol72860060',
#   'protesto por las miles de familias que hoy en día están esperando a sus familiares desaparecido protesto por la muerte de muchos líderes sociales por estás y muchas razones más'],
#  ['CamilaL75539792',
#   'yo marchó por la colombia olvidada donde los crímenes no salen a la luz pública donde el estado solo llega en forma de guerra y represión donde los grupos secretos del estado águilas negras desplazan asesinan violan e imponen su feudalismo moderno'],
#  ['YesicaMylano',
#   'en serio bueno con tanto desocupado un 20 de desempleo se entiende pero la verdad espero que una marcha traiga alguna solución de los enormes problema que tenemos ahora una marcha pacifica y no violenta'],
#  ['peznaranjaTweet', 'ya te lavaste las manos'],
#  ['Leonard20514252', ''],
#  ['gloqui20',
#   'a esos brutos de la les recuerdo que la marcha feminista en madrid fue la que ayudo a regar el virus y los llevo al pico tienen toda una vida para protestar no cuando vamos para el pico de una pandemia no se les pudo ocurrir en peor epoca idiotas'],
#  ['Leonard20514252', ''],
#  ['AhhDiga',
#   'marcha marcha marchaaaaaa  folded hands  pero que se infecte todos los marchantes por favor  folded hands  folded hands  folded hands  folded hands  folded hands #marcha15dejunio'],
#  ['alterahuevos', 'yo marcho por ellos porque merecen justicia'],
#  ['AhhDiga',
#   'eso marchen pero eso si infectence todos oooosssss  folded hands #marcha15dejunio'],
#  ['fulrecos7',
#   'no se sabe que es peor en  Colombia  si morir de covid o morir de hambre'],
#  ['alterahuevos',
#   'yo marcho porque estoy cansada del abuso de estos que dicen proteger al pueblo y lo único que hacen es reprimirlo y matarlo'],
#  ['otratremenda',
#   'y así como tanto le indignó la muerte de george floyd que me duela también su país anderson arango asesinado de un bolillazo por un policía en el cauca que no se derrame más sangre inocente queremos justicia'],
#  ['Migux_0',
#   'prefiero que un virus acabe conmigo y mi libertad a que un estado injusto y corrupto lo haga justicia es lo que necesita colombia y el mundo entero por sobre cualquier virus el humano sin libertad no es humano'],
#  ['MiguelCab1989',
#   'me gustaría saber qué opina sobre este ridículo ht dejen de buscar lo que no se nos ha perdido esto del coronavirus apenas está empezando'],
#  ['UnBufonMas',
#   'si si y si de una u otra manera nos tenemos que hacer escuchar y que sepan que ya estamos cansados de lo mismo y de los mismos'],
#  ['Certero331',
#   'piden las hordas petrofarcistas castrochavistas farc historia plagada de crímenes atroces al secretariado farc le perdonarán 16 siglos de cárcel'],
#  ['Cristhi96660434', '¡salgamos a las calles en una sola voz'],
#  ['Sthefania_820', ''],
#  ['ElgritoAfroo',
#   'el gobierno duque uribe debe caer el abuso policial debe caer el racismo debe caer el machismo debe caer la violencia de genero debe caer la homofóbica debe caer la corrupcion debe caer y para que caigan nosotros nos debemos levantar'],
#  ['FelipeM22851767', ''],
#  ['Juanpineda2802', 'algo así creo que pasará en los noticieros'],
#  ['ColombiaStyle',
#   'así se estará realizando los test para covid20 en la  thermometer '],
#  ['monotovar1989',
#   'se pueden es infectar todos en esas marchas y puede pasar qué ya tenga el 100 de camas uci’s y respiradores copados para qué entonces las marchas del 15 sea pero de cajones'],
#  ['DavidGamezXD', '¿y si mejor cierras em hocico y te unes a la marcha'],
#  ['Cristiancami_lo',
#   'las revueltas sociales de las grandes capitales del mundo deben servir como aliento a este país marginado por una moral conservadora clasista y opresora'],
#  ['josedcuellars',
#   'en florencia caquetá un hombre presuntamente violo a un niño de tan solo 8 años algo más para la'],
#  ['ImHenao', 'yo no marcho por el virus osea guevon'],
#  ['Andreafiresb',
#   'si porque el país esta cansado de tanta corrupción y violencia orquestada por el estado ñeñepolitica fiscal de bolsillo asesinatos de lideres abuso policial cartel del covid y muchas injusticias mas  prohibited '],
#  ['Pipec_137',
#   'sin falta y tempranito estaré allí marchando a todo pulmón y de todo corazón'],
#  ['1970Yesid',
#   'por lo general al año se robaban 50 billones pero el par se picaros y carrasquilla rompieron guinnes record en dos meses de curentena ya los desaparecieron'],
#  ['Daniel_stikk',
#   'no al racismo no a la homofobia no a los feminicidios y acosos no a la maternidad obligatoria'],
#  ['monotovar1989',
#   'lo malo es que el tiene una tasa de letalidad baja de un 5 a un 7 maximo si usted tiene un hijo que es mantenido y mamerto y quiere ir a el 4 y 12 y ya sabe claudia ya tiene casi el 70 de uci’s ocupada'],
#  ['arleytrujillo7',
#   'tod@s a las calles no falta esa persona q dirá q es por petro  man facepalming  lucha es por nuestros derechos q nos están vulnerando'],
#  ['NatalyMora_',
#   'por eso estaré prénsenle en la porque estoy cansada de la injusticia cansada de sentir impotencia por no poder hacer nada por aquellos que alzan su voz y mueren por eso saldré a las calles a luchar por mi futuro y el futuro de mi país'],
#  ['Laubassmusic', 'por dylan por alejandra por anderson'],
#  ['Sttteven_', 'como putas harán una marcha aca en colombia'],
#  ['snavarro161',
#   'para el gobierno la muerte de un hombre es una tragedia y la muerte de millones es estadística'],
#  ['LeFaltaLaC',
#   'todos los que salgan a mariquear el 15 deberían dejar estipulado que no se les permita ocupar una cama de uci cuando les pegue el virus'],
#  ['atomocartun', 'la pirámide'],
#  ['Don_Juan62',
#   'jajajajaja la peinada que le pegaron  face with tears of joy  face with tears of joy '],
#  ['ElDaIaiLama',
#   '¿alguna duda de que el cacas estuvo en cuba definiendo con su círculo regional cuál será agenda de los próximos meses para seguir quemando el país añora que el sistema de salud y la economía colapsen zombies ñeros listos a sus órdenes es lo que sabe que tiene backhand index pointing down medium skin tone '],
#  ['Alexeprz',
#   'bueno creo que influenciamos a petro se supone que el apoye es la oposición  man shrugging  igualmente te quiero recordar que inicio en fb con una publicación de un ciudadano x'],
#  ['killingMe_boy', 'este 15 de junio también salimos a marchar por alejandra'],
#  ['Oscar08464952',
#   'ustedes conocen algún colombiano que haya libertado ha nuestro pueblo de la opresión ni bolivar ni benkos biohó fueron paridos por esta tierra de cobardes'],
#  ['fungusxxs',
#   'esta mierda no se justifica  evergreen tree  hammer and pick '],
#  ['Gav_LoM', 'yo a punto de salir rumbo a la por narnia mamá'],
#  ['sszzz__', ''],
#  ['d_padilla_93', ''],
#  ['Anahismr6',
#   'en colombia hay una marcha el 15 de junio en contra del racismo no podré asistir por mi familia recuerden llevar tapabocas cuidarse y gritar sobre todo gritar y emprender ese rumbo al cambio social e igualdad tqm'],
#  ['BCertuche',
#   'mi estimado señor si su compresión lectora es mala mediana o buena podrá entender que me refiero a que sigan posteando con el hastagh porque es el el que vale en este momento el senador se une a postear por la tendencia en qué se convirtió'],
#  ['Oscar08464952',
#   'quién se iba a imaginar que el covid 19 era nuestro simón bolivar'],
#  ['OscarPavi',
#   'los padres de familia que enseñan a sus hijos en casa pueden marchar con fecode  grinning face with sweat  grinning face with sweat  grinning face with sweat '],
#  ['profet538', ''],
#  ['Fredy_GuerraA', ' raised fist medium-dark skin tone '],
#  ['Davinci_Hugh',
#   'los hijueputas que pedian el fin de la cuarentena ahora quejándose de la no más abusos de la policia ejercito no más líderes sociales asesinados por dilan y anderson  raised fist  raised fist  raised fist  raised fist  raised fist '],
#  ['oropesatoledo',
#   'no tiene que ver nada en pero le dice que lo postee jejejeje muy coherente'],
#  ['kukoflowpaisa',
#   ' speaking head  esperen un momento títeres uno de sus lideres el doctor bobolivar les quiere decir algo o quizás ya no'],
#  ['OscarPavi',
#   'salgan a marchar con proyectos productivos y de generar empresa en las manos no con una piedra y banderas comunistas para que todo se lo regalen'],
#  ['rolistongs',
#   'los héroes en colombia  Colombia  si existen y son todos los que usan su voz son todos los estudiantes líderes sociales docentes y cada una de las personas que lucha por un país diferente la misma lucha del 21n pero con pruebas  fire  fire '],
#  ['andrespaz1',
#   'este país no aguanta más el corrupto y ladrón la asesinando jóvenes y maltratando ancianos y el presidente gobernando por decreto y regalando plata a los bancos hay que levantarse y luchar'],
#  ['ColProgresista',
#   'existen muchas razones para salir a la 1 asesinatos a lideres sociales 2 abuso policial 3 corrupción en colombia y sobrecostos en la pandemia 4 agro ingreso seguro 2 0 5 violación de la soberanía en la llegada de las tropas americanas 6 ñeñe política'],
#  ['GoldenC34634053', 'esto es increíble colombia'],
#  ['sacamargov',
#   'creo que esto no se da en un momento bueno son algo estúpidos en cuanto a la convocatoria en estos momentos aunque las razones son muy válidas'],
#  ['GoldenC34634053', 'esto es increíble'],
#  ['OscarPavi',
#   'con esta marcha fortalecerán al gobierno nacional la gente del común entenderán que solo les importa vandalizar el comercio y generar el caos'],
#  ['lnicorojasl',
#   'otra marcha fracasada para darnos golpes de pecho de que despertamos y la siguiente pa cuando pa l 15 de julio yo veré por el andén bolitas de pintura para el congreso y piedras para el local del ciudadano'],
#  ['watosyss',
#   'que esté bien la protesta pero sino se comportan bien se van del culo para el estanco con el covid ese les protesta por camas en las uci'],
#  ['camilo58466717',
#   'tenemos miles de motivos desde los años 90 la historia de colombia la domina la violancia'],
#  ['LaPocholina',
#   'el es real que mierda les pasa ahora en es serio ey jodanse todes de verdad es lo más estudiado que se puede hacer en estos momentos pero bueno ahora si en plena pandemia coman mucha mierda'],
#  ['littledaughte11',
#   'ya que tanto les gusta desobedecer las indicaciones de no salir debido a la pandemia ¡entonces salgan pero con motivos de sobra no por cacorradas'],
#  ['OscarPavi',
#   'el virus nos demostró que tenemos un sistema de salud muy bueno comparado con otras naciones pero como nos les conviene eso los izquierdosos lo quieren colapasar'],
#  ['Aana31378828',
#   'la es totalmente entendible y necesaria pero hay que tener en cuenta varios factores como 1 va a pasar como 21n donde nada pasó por que la gente no sabía ni por qué marchaba 2 el pico de contagio va a aumentar hablando desde la lógica'],
#  ['And_mellet', ''],
#  ['Elian_Dv15',
#   'yo no sé si es que me estoy volviendo locó o es que está pasando de todo en este hijueputa año  man facepalming light skin tone  que mondaa  man facepalming light skin tone '],
#  ['OscarPavi',
#   'espero no ver a en los noticieros explicando el cerco epidemiológico de las marchas  grinning face with sweat  grinning face with sweat  grinning face with sweat '],
#  ['GodDragonSlifer',
# ...
#  ['EnriqueTeacher1',
#   'cuántos asesinatos debe cometer la policía para detener este país'],
#  ['christian_atlh',
#   'ya que es incapaz de controlar marchas y controlar el covid propongo que rocíen con desinféctate a los manifestantes'],
#  ['Horacio57527276', ''],
#  ['FranciscoA_L',
#   '¿es en serio lo de la sus promotores de forma mezquina van a hacer que se contagien y posiblemente mueran miles de ciudadanos que bajeza'],
#  ['PatriciaDurn11',
#   'george floy levantó eeuu en colombia 347 asesinatos desde 2018 duque y 88 2020 q esperamos q nos maté el matarife el virus el hambre juego mi vida d todas maneras la llevo pérdida'],
#  ['andersoncasta16', 'de una'],
#  ['Lvcastillog',
#   'ridículos la gente no entiende por la pandemia que estamos pasando y la cantidad de contagiados muchos quieren activarse en sus empresas en su día a día todos queremos salir de este encierro de una vez por todas por favor dejen de incentivar esta maricada'],
#  ['Ceblue101',
#   'el que convoca a esto o es uribista o es la persona más estúpida de este país'],
#  ['Mediarse',
#   'duque alargará la 40rentena por las protestas que están por estallar en toda colombia lo de contener el virus ya no va a ser lo importante'],
#  ['Anglica14128255',
#   'por nuestros muertos ni un minuto de silencio ¡a las calles'],
#  ['soysantialarcon',
#   'después aumentan los contagios y ahí si lloran esos líderes que se aprovechan de la nobleza de sus seguidores producen rabia'],
#  ['Ritmica_Roja',
#   'porque si no nos mata el virus nos mata la inequidad  microbe ୧ ಠ д ಠ ୨'],
#  ['CarolGonzalez5', ''],
#  ['Juanchocar80',
#   'vamos con toda el futuro es de los valientes he inteligentes acuérdense de salir sin tapa bocas y cogidos de la mano siii se puede'],
#  ['_castrosebas', 'yo me apunto  heart suit '],
#  ['slayingrocky',
#   'dios mío por favor que mi mamá me deje ir a la marcha del 15 de junio'],
#  ['Cletrado10',
#   'en plena pandemia es completamente ilógico proponer esta claro que hay que seguir protestando pero hay que cuidar la salud de nuestros familiares'],
#  ['JuahnPis', ''],
#  ['Venusislife_',
#   'no más racismo no más homofobia no más feminicidios no más acosos no más violaciones a nuestros derechos basta de ignorancia'],
#  ['WilliamAFGarcia',
#   'pero que no incluya cacerolazo ni besaton y que no termine convirtiéndose en un festival recreativo'],
#  ['Felipe_sa_c',
#   '¿y si mejor iniciamos un levantamiento cívico basados en nuestras propias luchas porque salir a la calle a pintar acab y fuckthepolice no es nuestro culturalmente no despierta nada'],
#  ['MateRodriguezB', ''],
#  ['Joserextirano',
#   'los mamertos son tan brutos que primero exigieron que se decretara la cuarentena por mas de 60 dias con los cual se aumentaron los indices de pobreza ahora quieren contagiarse en forma diciendole a su sequito de idiotas'],
#  ['DraGranadilla',
#   'veo el luego pienso en lo reventados que estamos tratando de contener esta mierda y pues'],
#  ['ManosLimpiasCo',
#   'protesta con distanciamiento interpersonal daría dos mensajes que si podemos con el auto cuidado y que no somos pendejos'],
#  ['marlyntuiran', ''],
#  ['DORIACABRERA', 'con todo a la'],
#  ['posso0654', ''],
#  ['FelipeV2210',
#   'hasta que la dignidad se haga costumbre no más abuso policial no más escuadrón de la muerte no más lideres sociales asesinado'],
#  ['OrtizDirley', 'yo estoy listo marcho por mis hijos y marcho con mis hijos'],
#  ['Diego_Ibarra13',
#   'ojalá todos los que se andan quejando del en estados unidos tengan la valentía de salir este 15 de junio a la'],
#  ['danovislozano', 'en colombia el racismo también es sistemático y letal'],
#  ['Estrada0222',
#   'la verdad si viviera sola no me la pensaría para salir a marchar pero como no ni de chiste no voy a exponer a mi familia al puto virus'],
#  ['alexreyescast', 'cuando y son hipócritas'],
#  ['anibalom', ''],
#  ['ComiteDeParo', ''],
#  ['StefanBravo3',
#   'soy moisés galan gaitán un pueblo ahora marchen por nuestro líder social eeuu increíble tanta estupidez petrista'],
#  ['oscarabeja',
#   'que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['oscarabeja',
#   'que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['tomatetrip',
#   'casi que no el gobierno sosteniendo la cuarentena a punta de mentiras y decretos cual dictadura dejando más que claro que no les importa nuestra salud sino su bolsillo el 15 nos vemos'],
#  ['PasosPazzini',
#   'no nunca se saldra de la eterna cuarentena quieren bajar los contagios cuidense y mantengan el distanciamiento social las cosas se arreglan en las urnas se arreglan con inteligencia no con manifestaciones multi propósito sin objetivo claro'],
#  ['oscarabeja',
#   'que irresponsabilidad tan grande en plena pandemia no les da miedo nada la peor parte las llevarán sus familias cuando les lleven el virus después con llorar ya para que'],
#  ['Marcosval01',
#   'sera que este es el verdadero proposito sacrificar a los idiotas utiles del socialismo para aumentar el número de contagios'],
#  ['CamiloPinzn17',
#   'alcaldes robando mercados sobrefacturando ingreso solidario para muertos los médic@s y enfermer@s sin sus trajes el desempleo por las nubes la policía abusando de su poder entre otras que estas razones te muevan pero sal con los cuidados necesarios'],
#  ['_Jack_Naipe',
#   'y como acá nos gusta darle largas a todo esperen una carentena general antes de la'],
#  ['robertoortega02', 'el covid 19 esperando la'],
#  ['HijueputaCasa', 'sin miedo'],
#  ['CSarahelenht',
#   'pido a todas las personas que van salir a con justa razón que piensen en todos los daños colaterales que esto dejará cargaremos con un genocidio en nuestras espaldas y haremos quedar a los tiranos como héroes'],
#  ['CamiloMejaR1',
#   'muchos dicen que es ignorante salir a marchar mientras estamos en el pico de la pandemia yo digo que es ignorante dejarnos manejar por la corrupción y el abuso de poder'],
#  ['HHsotelo27', 'no me imagine que el rencuentro seria en una marcha'],
#  ['lispinmaya',
#   'no entiendo a la gente si salen a marchar solo conseguirán que hayan más muertos piensen en que cuando vuelvan a sus casa van a estar sus padres tíos abuelos hermanos los jóvenes no somos inmunes es nuestro deber cuidarnos y a nuestros seres queridos'],
#  ['Piensa__', 'irresponsable es no hacer nada y quejarme en redes sociales'],
#  ['nana56973518',
#   'salgan vagos bandidos flojos ridículos irresponsables y demás estúpidos'],
#  ['Dannapa10653407', 'asi es'],
#  ['FCarri',
#   'los invitó a buscar otras formas de manifestarse hay que hacerlo pero reventando el sistema de salud los contagios y con muertes de manifestantes solo benefician el status quo mejor un cacerolazo o semejantes oigo ideas'],
#  ['JuanLindarteP',
#   'con esto de la se comprueba que más se demoraron en enviar el vuelo humanitario para traer a que este en desplegar las ordenes recibidas por parte del eln para vandalizar nuevamente el país'],
#  ['Sansarita',
#   'se alborotaron los bodegueros vayan pues qué el covid haga una buena limpieza social'],
#  ['memitodiez',
#   'si la la van a hacer con bozal y distanciamiento apague y vamonos me decantaría mejor por la de anden y festivo'],
#  ['Sombreroooooo',
#   'tengo tantas cosas porque marchar que no sé cuántas pancartas llevar que gonorrea que todos los sistemas y sectores estén en la mierda en este país'],
#  ['SoyMonicaMar', ''],
#  ['ElCapucchino', 'razones sobran no dan ayudas pero dan bolillo'],
#  ['Antifa55460356', 'democracia usurpada por el gobierno fascista'],
#  ['jostin_panza',
#   'espero que la no sea violenta eso lo único que provoca es el desprestigio del movimiento y se opaca el mensaje del mismo'],
#  ['CataGaviiriia',
#   'ojalá no mal entiendan mi punto porque yo estoy muy firme apoyando esto pero siempre nos ponemos a esperar y estas cosas son ya'],
#  ['SebastinForer15',
#   'no nos dejemos ver la cara salgamos a las calles a retomar el 21n pero con más resistencia más fuerza y más furia a pelear por nuestros derechos'],
#  ['Laura_Rod10',
#   'creí que era broma pero hay gente que lo apoya de verdad definitivamente la estupidez humana no conoce el límite'],
#  ['Soniaguer',
#   'todos a contagiarnos que con los problemas que tenemos no es suficiente'],
#  ['Baub__', ''],
#  ['iLordPorky',
#   'les da miedo salir a buscar trabajo pero gustavo petro los manda a marchar y la pandemia no existe'],
#  ['DSOTELOZ', ''],
#  ['richar10rock',
#   'los dioses de las marchas son los gringos ellos sí tienen adrenalina lo llevan en la sangre aguante u s a  United States  United States  United States  United States  United States  sign of the horns '],
#  ['Os56351001', 'policía criminal'],
#  ['BizarroMesa', ' raised fist medium skin tone '],
#  ['JorgeMr_Paez',
#   'esto fue que fue petro a cuba a planear que iba a hacer y miren con la que salió'],
#  ['ili_llanos',
#   'eso de me parece la estupidez más grande como es que en plena pandemia van a convocar miles de personas a aglomerarse esa no es la forma'],
#  ['wilson9503',
#   'esto se debe tener muy en discusión de la forma política que quieren tomar esta consigna mucho cuidado'],
#  ['Cloqlitos',
#   'tú yo una marcha por los derechos de los ciudadanos no sé piénsalo chiquibeibi  flushed face '],
#  ['gersonpailitas', 'va a volver trizas el sistema de salud'],
#  ['karenel11199500',
#   'me pregunto qué piensa el personal de salud a que convoquen'],
#  ['Ribartolo',
#   'jodian y jodian para que no levantaran la cuerentena porque todos iban a morir y ahora van a jajajaja esa coherencia me encanta'],
#  ['GigiVirviescas',
#   'porque si no nos mata el virus nos mata este gobierno nos mata la indiferencia'],
#  ['nataliabenavidd',
#   'en serio  woman facepalming medium-light skin tone  motivos sobran si pero no es el momento'],
#  ['escuelathemrdog', 'gobiernos de mafiosos con la biblia en mano'],
#  ['lord17572',
#   'señora alcaldesa claramente por la pandemia no se podría autorizar una marcha verdad'],
#  ['Piensa__', 'por la defensa de nuestros derechos humanos también marcho'],
#  ['Oscar_GCh',
#   'me acuerdo cuando todos le recordábamos al que tenía 276 investigaciones meses después él h p completa 300 ¿y todavía se atreve demandar con el fin de protejer su buen nombre'],
#  ['CataGaviiriia',
#   'mi duda es ¿por que vamos a esperar hasta el 15 para salir a marchar de aquí a allá se inventan algo para desviar la atención en mi opinion deberíamos dejar de darle tantas largas a las cosas que se note de verdad que estamos emputados'],
#  ['RAFAELF02343473',
#   'es justo y necesario más de 100 leyes aprobadas a puerta cerrada sin control político y hablan de transparencia y luego el gringo llega a violar niñas y duque se limpia el culo con la constitución no más dictadura corrupta narco traficante paracolombianos'],
#  ['Perreoapocaluzz', 'estoy preparado y listo hasta mi mamá va a salir'],
#  ['SantiMoncada_', 'allá los espero  flexed biceps '],
#  ['rozo_juan',
#   'toda la izquierda puede salir a la que la selección natural se encarga del resto  face blowing a kiss '],
#  ['carduar1',
#   'una en donde no se sabe si marcharán la gente civilizada o los violentos como siempre dañan todo'],
#  ['Antifa55460356',
#   'es hora de levantar nuestras voces frente a los líderes sociales asesinados el desempleo y el hambre del pueblo oprimido temas pasados desapercibidos por una pandemia'],
#  ['Carlosbedoya_',
#   'por los asesinatos diario de lideres sociales por la corrupción de alcaldes y gobernadores por la ñeñepolítica etc  Colombia '],
#  ['Juanding',
#   'en colombia también la policía nos mata pero acá a nadie le importa'],
#  ['LazyProfe', ''],
#  ['lunapower88', 'really'],
#  ['CSarahelenht',
#   'la verdad hay que decirla sería muy hipocrita de nuestra parte criticar al gobierno por reactivar la economía mientras nosotros promovemos una marcha empezando el pico de la pandemia amigos sin impulsividad no apoyo'],
#  ['CnprCol',
#   'a las calles las veces que sea necesario por nuestros muertos ni un minuto de silencio  fire  fire '],
#  ['Camarada109',
#   'llego la hora de despertar es inaudito que sigamos dejando a los que juegan a ser dios en colombia seguir con este régimen de terror'],
#  ['Juandatorres24',
#   'por las politicas neoliberal de por los 9 mil millones de pesos que se gasto para sus camionetas blindadas por la invasión de los militares gringos en colombia por todo eso yo marcho este'],
#  ['Gaso40321953',
#   'pregunto petro claudia y sus compinches a quien le van a echar la culpa por el aumento exponencial de contagios y muertes de adultos y abuelos producidos por los adolecentes que envian a las calles y que van a llevar el virus a sus casas aduque a uribe'],
#  ['fsalasparra',
#   'un festivo no es fecha para una marcha  man facepalming  de igual forma necesitamos un cambio y para eso tenemos que seguirla el martes miércoles y los días necesarios aprendamos de los gringos una semana seguida en las calles aprendamos de ecuador y chile todos los días'],
#  ['matarife82', 'marchamos por esto maldito paramilitar'],
#  ['DianitaMartin',
#   'definitivamente está vez digo desde casa podemos protestar'],
#  ['La26974565', 'gritemos juntos'],
#  ['gracias_uribe', 'mamertos hijos de puta'],
#  ['EliabRangel2', 'muy pronto en colombia'],
#  ['Dannapa10653407', ''],
#  ['barbie_ensus30',
#   'ojalá a la se unan de alguna forma los abogados litigantes llevamos más de dos meses sin juzgados parece que se nos olvidó que la administración de justifica es un servicio público y el acceso a ésta un derecho fundamental'],
#  ['Son15Letras', 'en nuestras redes ¿pa qué es en la calle y por millones'],
#  ['lord17572',
#   'eso salgan a marchar el 15 y así tendremos cuarentena hasta bueno quien sabe hasta cuando y después peleando por qué la economía y muchas cosas están mal'],
#  ['Oscar_GCh',
#   'aquí uno de los pestilente abogados del mal en épocas cuando el razocinio lo acompañaba hoy que pensará al saber que el perfilador de periodistas y patrocinador de paramilitares a quienes entrenó yair klein es el'],
#  ['DotorMataLawyer',
#   'esos mismos fanáticos son los convocantes y posibles marchantes de la que por supuesto'],
#  ['Esteban55603333', ''],
#  ['Vlad_xciv',
#   'han sufrido por el control y la opresión que les han infundido por algo que ha existido millones de años ha sido la excusa perfecta para jugar con tus miedos y confinandolos en casa frente a una caja diciendo supuestos y entreteniendolos todo esto es pura falacia'],
#  ['Son15Letras',
#   'pero todos sin pendejadas y con constancia un solo día no un solo día no sirve de nada'],
#  ['elunicoeldivino', 'estas son las razones a favor de la favor de y hacerlo'],
#  ['Avargasg131',
#   'en colombia tenemos mil vainas por las cuales protestar sin embargo marchar en medio de una pandemia donde la principal arma es el aislamiento y distanciamiento social las convocatorias resultan bastante irresponsables'],
#  ['LcolombiaM', ''],
#  ['JuanDavidC_',
#   'por anderson por dylan por la corrupción con las ayudas humanitarias en esta crisis del covid19 por los líderes sociales que son muchos por el sistema de salud tan pésimo que tenemos y por cientos de cosas más'],
#  ['peznaranjaTweet',
#   'peznaranja lab es el sistema de tus sueños ya sea que tengas un negocio pequeño una megacorporación o tu oficina lab es la mejor opción'],
#  ['brayanprieto95',
#   'definitivamente la inconsciencia moral de la gente en plena cuarentena y piensan marchar claro sigan como borregos a los que quieren que esto estalle y por fin empiecen a haber muertos en las calles al fin y a cabo un pobre menos para ellos'],
#  ['dana13_31', ''],
#  ['SoyMonicaMar', 'el 30 de junio'],
#  ['JUANBABYLAN',
#   'que falla ponerle fecha a una marcha  man facepalming light skin tone '],
#  ['Estrella_Calva',
#   'comparto tu opinion se unio todo el mundo para apoyar a estados unidos y quien nos apoya porfavor los que tengan influencia ayudar ayuden que nos escuchen'],
#  ['mochilaWayuu',
#   'o se marean si nos vamos a marear que sea por el lacrimógeno mientras protestamos por lo nuestro'],
#  ...]

# %% [markdown]
# ## Translation

# %%
# Option 1: Usar un modelo de traducción basado en Transformers: Helsinki-NLP/opus-mt-es-en
# !pip install transformers[sentencepiece]
# !pip install torch
# Out:
# Requirement already satisfied: transformers[sentencepiece] in /home/daniel/.local/lib/python3.8/site-packages (4.20.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (0.12.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers[sentencepiece]) (2.22.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers[sentencepiece]) (5.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (0.8.1)
# Requirement already satisfied: filelock in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (3.7.1)
# Requirement already satisfied: packaging>=20.0 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (1.23.1)
# Requirement already satisfied: protobuf<=3.20.1; extra == "sentencepiece" in /usr/lib/python3/dist-packages (from transformers[sentencepiece]) (3.6.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91; extra == "sentencepiece" in /home/daniel/.local/lib/python3.8/site-packages (from transformers[sentencepiece]) (0.1.96)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/daniel/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers[sentencepiece]) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/daniel/.local/lib/python3.8/site-packages (from packaging>=20.0->transformers[sentencepiece]) (3.0.6)
# Collecting torch
#   Downloading torch-1.12.0-cp38-cp38-manylinux1_x86_64.whl (776.3 MB)
#      |████████████████████████████████| 776.3 MB 39 kB/s  eta 0:00:012    |████▋                           | 111.1 MB 4.8 MB/s eta 0:02:20  | 415.1 MB 6.7 MB/s eta 0:00:54[K     |██████████████████▋             | 451.2 MB 1.1 MB/s eta 0:04:58��████████████████████▉          | 529.8 MB 827 kB/s eta 0:04:58MB 9.0 MB/s eta 0:00:25█████▎        | 563.7 MB 6.8 MB/s eta 0:00:32�██████████▌        | 570.9 MB 10.1 MB/s eta 0:00:21�███████████▍       | 590.4 MB 35 kB/s eta 1:26:18 | 639.9 MB 688 kB/s eta 0:03:19 | 644.1 MB 4.3 MB/s eta 0:00:31��████████▋    | 668.9 MB 1.5 MB/s eta 0:01:14��███████████████████▎   | 686.2 MB 5.6 MB/s eta 0:00:17��███████████████████▌   | 692.1 MB 5.5 MB/s eta 0:00:16��███████████████████▋   | 695.2 MB 5.5 MB/s eta 0:00:15��███████████████████▊   | 697.9 MB 1.5 MB/s eta 0:00:53��████████████████████   | 701.6 MB 1.5 MB/s eta 0:00:50    |█████████████████████████████▌  | 714.5 MB 8.8 MB/s eta 0:00:08    |██████████████████████████████  | 730.3 MB 1.8 MB/s eta 0:00:253 MB 1.8 MB/s eta 0:00:231 MB 1.8 MB/s eta 0:00:239 MB 2.2 MB/s eta 0:00:154 MB 2.2 MB/s eta 0:00:142 MB 2.2 MB/s eta 0:00:13�██ | 750.3 MB 13.2 MB/s eta 0:00:02�██ | 751.8 MB 13.2 MB/s eta 0:00:02███████▎| 760.0 MB 6.2 MB/s eta 0:00:03███████▌| 763.3 MB 1.6 MB/s eta 0:00:09███████▌| 765.4 MB 1.6 MB/s eta 0:00:07███████▋| 766.9 MB 1.6 MB/s eta 0:00:06███████▋| 767.5 MB 1.6 MB/s eta 0:00:06███████▊| 769.6 MB 1.5 MB/s eta 0:00:05
# Requirement already satisfied: typing-extensions in /home/daniel/.local/lib/python3.8/site-packages (from torch) (4.3.0)
# Installing collected packages: torch
# Successfully installed torch-1.12.0

# %%
# Option 1:
import torch
device = "cuda:0" if torch.cuda.is_available() else "cpu"
device

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-es-en")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-es-en").to(device)

sample_text = "esto es una prueba de un modelo de traducción español a inglés"

batch = tokenizer([sample_text], return_tensors="pt").to(device)

generated_ids = model.generate(**batch)
tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
# Out:
# 'This is a proof of a Spanish to English translation model.'

# %%
# Option 1:
tweets = [text[i][1] for i in range(len(text))]
tweets
test_tweets = []

character_count = 0
translated_tweets = 0

for f in tweets:
    batch = tokenizer([f], return_tensors="pt").to(device)
    generated_ids = model.generate(**batch)
    tweet_translated = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

    test_tweets.append(tweet_translated)
    
    translated_tweets += 1
    character_count += len(f)
    pp = (translated_tweets/len(tweets))*100
    if translated_tweets%100 == 0:
        print(round(pp,2), '%')
# Out:
# 7.77 %
# 15.54 %

# %%
# Option 1:
print("Total characters translated: {0}".format(character_count))
print("Translated Tweets: {0}".format(translated_tweets))
# Out:
# Total characters translated: 130287
# Translated Tweets: 1287

# %%
# Option 1:
text = [[users[i],test_tweets[i]] for i in range(len(users))]
text

# %%
# Option 2: Another way to translate tweets is using Google translator, but we need a credit card to register
# provides authentication credentials to application code:

os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="C:/Path/Proyecto/My Project 51416-7941bb73685e"

# %%
# Option 2: This function translate tweets from English to Spanish
#Input: List of tweets to be processed
#Output: List of processed tweets

from google.cloud import translate_v2 as translate

def translate_text(text, target='en'):
    translate_client = translate.Client()
    result = translate_client.translate(text, target_language=target, format_= "text")
    
    return(result['translatedText'])

# %%
# Option 2:
tweets = [text[i][1] for i in range(len(text))]
tweets

# %%
# Option 2:
test_tweets = []

character_count = 0
translated_tweets = 0

for f in tweets:
    tweets_translated = translate_text(f, target = "en")
    test_tweets.append(tweets_translated)
    
    translated_tweets += 1
    character_count += len(f)

# %%
# Option 2:
text = [[users[i],test_tweets[i]] for i in range(len(users))]
text

# %%
# Option 2:
len(text)

# %%
# Option 2:
print("Total characters translated: {0}".format(character_count))
print("Translated Tweets: {0}".format(translated_tweets))

# %%
text[0][1] # first translated tweet
# Out:
# 'marches scheduled for June 15 in the middle of the pandemic definitely the foolishness reigns in Colombia'

# %%
# exporting translated tweets

# %%
base = pd.DataFrame(text, columns=["users","tweets"])

# %%
base.to_excel('test.xlsx')

# %% [markdown]
# ## Additional Text Cleaning

# %% [markdown]
# - ## Delete blank rows

# %%
df = pd.read_excel("test.xlsx")

df.to_string(index=False)
nan_value = float("nan")

df.replace("", nan_value, inplace=True)

df.dropna(subset = ["tweets"], inplace=True)
df.reset_index(drop=True, inplace=True) 

df.head()
# Out:
#    Unnamed: 0            users  \
# 0           0  DiegoTorresCast
# 1           1    dariocaicedo0
# 2           2    dariocaicedo0
# 3           3      rockero1901
# 4           4       Insurrsion
#
#                                               tweets
# 0  marches scheduled for June 15 in the middle of...
# 1  Let's go. No one's gonna get sick. We'll all b...
# 2  Okay, we're gonna go back and march well. Chim...
# 3  We cannot wait for the social causes it is cle...
# 4  the uga uga cavemen onvres and mugerez who opp...

# %%
df['tweets']
# Out:
# 0       marches scheduled for June 15 in the middle of...
# 1       Let's go. No one's gonna get sick. We'll all b...
# 2       Okay, we're gonna go back and march well. Chim...
# 3       We cannot wait for the social causes it is cle...
# 4       the uga uga cavemen onvres and mugerez who opp...
#                               ...
# 1282                            Partido de irresponsibles
# 1283    by our leaders killed by the Farc el-Eln and t...
# 1284                                           I'm sorry.
# 1285    I find it very imprudent to make a march in th...
# 1286    We're marching in peace. We're marching in ord...
# Name: tweets, Length: 1287, dtype: object

# %%
len(df)
# Out:
# 1287

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# users         0
# tweets        0
# dtype: int64

# %%
len(df)
# Out:
# 1287

# %%
# !pip install xlsxwriter
def write_excel(tab,name):
    writer = pd.ExcelWriter(name+'.xlsx', engine='xlsxwriter')
    # Convert the dataframe to an XlsxWriter Excel object.
    tab.to_excel(writer, sheet_name='Sheet1',index=False)
    # Close the Pandas Excel writer and output the Excel file.
    writer.save()


write_excel(df,"test2")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 7.3 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.3

# %%
cols = ['users', 'tweets']
text = df[cols].values.tolist()
text
len(text)
# Out:
# 1287

# %%
tweets = [text[i][1] for i in range(len(text))]
len(tweets)
# Out:
# 1287

# %%
users = [text[i][0] for i in range(len(text))]
len(users)
# Out:
# 1287

# %%
test_tweets = df['tweets'].tolist()

# %%
#test_tweets

# %%
#write_excel(tweets,"test3")

# %% [markdown]
# ### Grading

# %%
pip install grader

# %%
from grader import Grader

# %%
grader = Grader()

# %% [markdown]
# ## Word Embedding

# %%
import gensim

#wv_embedding is the embedding loaded
wv_embeddings = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True, limit=500000) ######### YOUR CODE HERE #############
type(wv_embeddings )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-205-1f4dce641fe2> in <module>()
#       2
#       3 #wv_embedding is the embedding loaded
# ----> 4 wv_embeddings = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True, limit=500000) ######### YOUR CODE HERE #############
#       5 type(wv_embeddings )
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1436         return _load_word2vec_format(
#    1437             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
# -> 1438             limit=limit, datatype=datatype)
#    1439
#    1440     def get_keras_embedding(self, train_embeddings=False):
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#     169
#     170     logger.info("loading projection weights from %s", fname)
# --> 171     with utils.smart_open(fname) as fin:
#     172         header = utils.to_unicode(fin.readline(), encoding=encoding)
#     173         vocab_size, vector_size = (int(x) for x in header.split())  # throws for invalid file format
#
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py in smart_open(***failed resolving arguments***)
#     496     ignore_ext = ignore_extension
#     497     del kwargs, url, message, ignore_extension
# --> 498     return open(**locals())
#     499
#     500
#
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, compression, transport_params)
#     193         encoding=encoding,
#     194         errors=errors,
# --> 195         newline=newline,
#     196     )
#     197     if fobj is not None:
#
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, compression, buffering, encoding, errors, newline)
#     359         open_kwargs['errors'] = errors
#     360
# --> 361     return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#     362
#     363
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GoogleNews-vectors-negative300.bin'

# %% [markdown]
# ## From word to text embedding

# %%
#This function converts a tweet in a vector
import numpy as np
def tweets_to_vec(tweet, embeddings, dim=300):

    result = np.zeros(dim) #300 dimensional vector for phrase vector
    cnt = 0
    words = tweet.split()
    for word in words: #All word vectors composing the phrase are summed
        if word in embeddings:
            result += np.array(embeddings[word])
            cnt += 1
    if cnt != 0: #This would happen if no word was found in the embedding
        result /= cnt
    return result

# %%
import nltk
nltk.download('stopwords')

# %%
import util

# %%
tweet2vec_result = []
for tweet in test_tweets:
    tweet = tweet.strip()
    answer = tweets_to_vec(tweet, wv_embeddings)
    tweet2vec_result = np.append(tweet2vec_result, answer)
    print("hola", tweet2vec_result)
    print(tweet2vec_result)

# %% [markdown]
# ## Evaluation of text similarity

# %% [markdown]
# ### HitsCount and DCGScore

# %%
'''
Metric 1 to validate the precision of a model
'''
def hits_count(dup_ranks, k):
    
    return np.average(np.array(dup_ranks) <= np.array([k]))

# %%
'''
Metric 2 to validate the precision of a model
'''

def dcg_score(dup_ranks, k):

    return np.average((np.array(dup_ranks) <= np.array([k]))*1./(np.log2(1. + np.array(dup_ranks))))

# %% [markdown]
# ## Cosine similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
tweet_vec= []
for tweet in test_tweets:
    # Strip removes the first space in the string
    tweet = tweet.strip()
    
    answer = tweets_to_vec(tweet, wv_embeddings)
    # Print each question with its vectorization
    tweet_vec.append(answer)

# %%
len(tweet_vec)

# %%
tweet_vec

# %%
a=cosine_similarity([tweet_vec[0]],[tweet_vec[1]])

# %%
def cosine_measure(list_text):
    list_total =[]
    sum = 1
    for i in list_text:
        sum = sum+1
        list_cosine =[]
        for j in list_text:
            if (i-j).all():
                a=cosine_similarity([i],[j])
                list_cosine.append(a)
            else:
                list_cosine.append(1)
        list_total.append(list_cosine)
        print(sum)
    return(list_total)

# %%
cosines = cosine_measure(tweet_vec)

# %%
cosines

# %%
len(cosines[0])

# %%
np.argmin(cosines[0])
np.argmax(cosines[0])

cosines[0][1][0][0]

# %%
def column_organization_to_validation(list_text):
    final_list=[]
    for i in range(0,len(list_text)):
        temp=[]
        for j in range(0,len(list_text[i])):
            try:
                temp.append(list_text[i][j][0][0])
            except:
                temp.append(1)
        temp = np.array(temp)
        final_list.append(temp)
    return(final_list)

#def column_organization_to_validation(list_text):
 #   final_list=[]
  #  for i in range(0,len(list_text)):
   #     temp=[]
    #    for j in range(0,len(list_text[i])):
     #       temp.append(list_text[i][j][0][0])
      #  final_list.append(temp)
   # return(final_list)

# %%
final_cosines = column_organization_to_validation(cosines)

# %%
sorted(final_cosines[2])

# %%
a=sorted(final_cosines[0])
#a[0]
#a.index(a[0])
a.index(0.0)

# %%
import random
def data_validation_classification(cosines,tweets):
    total=[]
    for i in range(0,len(cosines)):
        #print(i)
        temp=[]
        organized=sorted(cosines[i])
        min1=random.choice(organized[0:30])
        min2=random.choice(organized[0:30])
        #while min1==min2:
        #    min2=random.choice(organized[0:30])
        max1=random.choice(organized[len(organized)-32:len(organized)-2])
        print("distancias minimas",[min1,min2])
        print("distancia maxima", max1)
        pos_min_1=organized.index(min1)
        pos_min_2=organized.index(min2)
        pos_max_1=organized.index(max1)
        print("posiciones minimos",[pos_min_1,pos_min_2])
        print("posicion maximo",[pos_max_1])
        temp.append(tweets[i])
        if pos_max_1>=i:
            temp.append(tweets[(pos_max_1+1)])
        else:
            temp.append(tweets[pos_max_1])
        if pos_min_1>=i:
            temp.append(tweets[(pos_min_1+1)])
        else:
            temp.append(tweets[pos_min_1])
        if pos_min_2>=i:
            temp.append(tweets[(pos_min_2+1)])
        else:
            temp.append(tweets[pos_min_2])
        total.append(temp)
    return(total)

# %%
len(test_tweets)

# %%
u=data_validation_classification(final_cosines, test_tweets)

# %%
import xlsxwriter as ws

# %%
workbook = ws.Workbook('validation.xlsx') 
worksheet = workbook.add_worksheet()

# %%
row=0
worksheet.write(row, 0, "tweet")
worksheet.write(row, 1, "positive") 
worksheet.write(row, 2, "negative1") 
worksheet.write(row, 3, "negative2")
row=1
for i in range(0,len(u)):
    worksheet.write(row, 0, u[i][0])
    worksheet.write(row, 1, u[i][1]) 
    worksheet.write(row, 2, u[i][2]) 
    worksheet.write(row, 3, u[i][3])
    row+=1
workbook.close()

# %% [markdown]
# ### First solution: pre-trained embeddings
# We will work with predefined train and validation:
#
# - train corpus contains similar sentences at the same row.
# - validation corpus contains the following columns: tweet, similar tweet, negative example 1, negative example 2.

# %%
def read_corpus(filename):
    data = []
    for line in open(filename,encoding='cp1252'):
        data.append(line.strip().split(','))
    return data

# %%
val = pd.read_excel("validation.xlsx")

# %%
len(val)

# %%
val

# %%
print(validation)

# %%
def rank_candidates(tweet, candidates, embeddings, dim=300):


    t_vecs = np.array([tweets_to_vec(tweet, embeddings, dim) for i in range(len(candidates))])
    cand_vecs = np.array([tweets_to_vec(candidate, embeddings, dim) for candidate in candidates])
    cosines = np.array(cosine_similarity(t_vecs, cand_vecs)[0])
    merged_list = list(zip(cosines, range(len(candidates)), candidates))
    #print(merged_list)
    sorted_list  = sorted(merged_list, key=lambda x: x[0], reverse=True)
    result = [(b,c) for a,b,c in sorted_list]
    
    return result

# %%
wv_ranking = []
for line in range(0,len(val)):
    t=val.tweet[line]
    ex=[val.positive[line],val.negative1[line],val.negative2[line]]
    ranks = rank_candidates(t, ex, wv_embeddings)
    wv_ranking.append([r[0] for r in ranks].index(0) + 1)

# %%
for k in [1, 5, 10, 100, 500, 1000]:
    print("DCG@%4d: %.3f | Hits@%4d: %.3f" % (k, dcg_score(wv_ranking, k), k, hits_count(wv_ranking, k)))

# %%
from util import text_prepare

# %%
prepared_validation = []
for line in range(0,len(val)):
    l=[val.tweet[line],val.positive[line],val.negative1[line],val.negative2[line]]
    prepared_validation.append([text_prepare(sentence) for sentence in l])

# %%
wv_prepared_ranking = []
for line in prepared_validation:
    q, *ex = line
    ranks = rank_candidates(q, ex, wv_embeddings)
    wv_prepared_ranking.append([r[0] for r in ranks].index(0) + 1)

# %%
for k in [1, 5, 10, 100, 500, 1000]:
    print("DCG@%4d: %.3f | Hits@%4d: %.3f" % (k, dcg_score(wv_prepared_ranking, k), 
                                              k, hits_count(wv_prepared_ranking, k)))
