# %%
import pandas as pd

# %%
datos=pd.read_excel("pruebas_bases/prueba_covid.xlsx",sheet_name="Archive")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d0026ec1e759> in <module>
# ----> 1 datos=pd.read_excel("datos/prueba_covid.xlsx",sheet_name="Archive")
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# --> 821         self._reader = self._engines[engine](self._io)
#     822
#     823     def __fspath__(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~\anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datos/prueba_covid.xlsx'

# %%
datos.head()
# Out:
#                 id_str       from_user  \
# 0  1255693419361468416    aethcolombia
# 1  1255693048387862530  FranciscoPayro
# 2  1255693035352002561        rafmor80
# 3  1255692968696086529        harmol16
# 4  1255692907174154240  herre_argemiro
#
#                                                 text  \
# 0  Colombia, firma el Tratado para la Prohibición...
# 1  El gran Burundún-Burundá ha muerto fue escrito...
# 2  @lafm Ojalá lo escuchará el anciano @AlvaroUri...
# 3  @rcnradio Este hijo de puta todavía dividiendo...
# 4  @rcnradio La Paz si es mejor que la guerra per...
#
#                        created_at                time geo_coordinates  \
# 0  Thu Apr 30 03:00:15 +0000 2020 2020-04-30 04:00:15             NaN
# 1  Thu Apr 30 02:58:47 +0000 2020 2020-04-30 03:58:47             NaN
# 2  Thu Apr 30 02:58:43 +0000 2020 2020-04-30 03:58:43             NaN
# 3  Thu Apr 30 02:58:28 +0000 2020 2020-04-30 03:58:28             NaN
# 4  Thu Apr 30 02:58:13 +0000 2020 2020-04-30 03:58:13             NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN              126204564.0                    lafm
# 3        NaN               40533752.0                rcnradio
# 4        NaN               40533752.0                rcnradio
#
#      from_user_id_str  in_reply_to_status_id_str  \
# 0           246623440                        NaN
# 1           131620470                        NaN
# 2           521667706               1.255691e+18
# 3          1372405256               1.255689e+18
# 4  919418505459617797               1.255689e+18
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1233338391...                3297.0
# 1  http://pbs.twimg.com/profile_images/1016721942...                 173.0
# 2  http://pbs.twimg.com/profile_images/1252062695...                 412.0
# 3  http://pbs.twimg.com/profile_images/1242671901...                3087.0
# 4  http://pbs.twimg.com/profile_images/1142982283...                   6.0
#
#    user_friends_count    user_location  \
# 0              4566.0      Bogotá D.C.
# 1               139.0  Tabasco, México
# 2               664.0          Bogotá
# 3              4993.0         Colombia
# 4                37.0   Tona, Colombia
#
#                                           status_url  \
# 0  http://twitter.com/aethcolombia/statuses/12556...
# 1  http://twitter.com/FranciscoPayro/statuses/125...
# 2  http://twitter.com/rafmor80/statuses/125569303...
# 3  http://twitter.com/harmol16/statuses/125569296...
# 4  http://twitter.com/herre_argemiro/statuses/125...
#
#                                         entities_str
# 0  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 1  {"hashtags":[{"text":"lecturasdelconfinamiento...
# 2  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 3  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 4  {"hashtags":[],"symbols":[],"user_mentions":[{...

# %% [markdown]
# ## Paso 1: Quitar arrobas

# %%
def quitar_arr(lista):
    lista_final=[]
    for i in lista:
        texto=''
        temp=0
        palabra=i.strip()
        for j in range(0,len(i)):
            if temp>j:
                b=""
            else:
                if palabra[j] =="@":
                    a=j+1      
                    while i[a]!=" ":
                        if a<(len(i)-1):
                            a=a+1
                        else:
                            break
                    temp=a
                else:
                    a=j
                    while palabra[a]!=" ":
                        if a<(len(i)-1):
                            a=a+1
                        else:
                            break
                    pal=palabra[j:a+1]
                    texto=texto+""+pal
                    temp=a
        texto=texto.strip()
        lista_final.append(texto)
    return(lista_final)

# %% [markdown]
# Seleccionar la columna del texto

# %%
text=datos['text'].tolist()

# %%
type(text)
# Out:
# list

# %%
lista_prueba=[text[0]]

# %%
lista_prueba
# Out:
# ['@Fernand60915270 @farmerguanabana @jflafaurie @HenaoBernardo @Fedegan @GaulaMilitares @GaulaPolicia @NobelPrize @JuanManSantos @JEP_Colombia @PartidoFARC @IvanDuque @CongresoCol Por La Empresa e Inversión es que Ud y Su Flia Pueden Comer y Disfrutar  de Medios para que uds PARASITOS VIVAN porque Trabaja Mas facil una Pala Empeñada que un Solo MAMERTOS de Uds Se Mueva y Algo por este País Viven de Gorra del Secuestro la Extorsión y Se Camuflan de Lideres']

# %%
sin_arr=quitar_arr(lista_prueba)
print(sin_arr)
# Out:
# ['Por  La  Empresa  e  Inversión  es  que  Ud  y  Su  Flia  Pueden  Comer  y  Disfrutar   de  Medios  para  que  uds  PARASITOS  VIVAN  porque  Trabaja  Mas  facil  una  Pala  Empeñada  que  un  Solo  MAMERTOS  de  Uds  Se  Mueva  y  Algo  por  este  País  Viven  de  Gorra  del  Secuestro  la  Extorsión  y  Se  Camuflan  de  Lideress']

# %% [markdown]
# Ahora con toda la lista

# %%
lista_v1=quitar_arr(text)
lista_v1[1]
# Out:
# 'El  gran  Burundún-Burundá  ha  muerto  fue  escrito  y  publicado  hacia  1952  por  Jorge  Zalamea,  en  Buenos  Aires,  después  de  que  éste  abandonara  Colombia  tras  la  guerra  civil  conocida  como  "El  bogotazo".  Es  considerada  una  obra  maestra.  #lecturasdelconfinamiento   https://t.co/gKUuICAPTff'

# %% [markdown]
# ## Paso 2: Todo minuscula

# %%
a='JULIAN Ramirez'
a.lower()
# Out:
# 'julian ramirez'

# %%
def minuscula(lista):
    lista_def=[]
    for i in lista:
        palabra=i.strip()
        nueva=palabra.lower()
        lista_def.append(nueva)
    return(lista_def)

# %%
lista_v2=minuscula(lista_v1)

# %%
lista_v2[0]
# Out:
# 'colombia,  firma  el  tratado  para  la  prohibición  de  las  armas  nucleares  (tpan)  -  ¡firma  la  petición!  https://t.co/f0jyhhorik  vía  o'

# %% [markdown]
# ## Paso 3: Eliminar Emojis

# %%
def deEmojify(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')
def eliminar_emojis(lista):
    lista_def=[]
    for i in lista:
        palabra=i.strip()
        palabra_nuev=deEmojify(palabra)
        lista_def.append(palabra_nuev)
    return(lista_def)

# %%
lista_v3=eliminar_emojis(lista_v2)

# %% [markdown]
# ## Paso 4: Mas limpieza

# %%
def caracteres_raros(lista):
    caracteres_especiales=['@','+','-','&','!','$']
    lista_def=[]
    for i in lista:
        palabra=i.strip()
        for j in range(0,len(i)):
            a=j+1
            b=d
            j+2
            if a<len
            if j

# %% [markdown]
# ## Paso 5: Traducir palabras

# %%
from googletrans import Translator

# %%
a.src
# Out:
# 'es'

# %%
a.text
# Out:
# 'by the company and investment is that you'

# %%
def traducir_ingles(lista):
    lista_def=[]
    for i in range(0,len(lista)):
        palabra=lista[i].strip()
        try:
            pal_ingles=traductor.translate(palabra,src='es',dest='en')
            print("se hizo",i)
            lista_def.append(pal_ingles)
        except:
            print("problemas en la palabra",i)
            lista_def.append('NA')
    return(lista_def)

# %%
lista_v4=traducir_ingles(lista_v3)
# Out:
# se hizo 0
# se hizo 1
# se hizo 2
# se hizo 3
# se hizo 4
# se hizo 5
# se hizo 6
# se hizo 7
# se hizo 8
# se hizo 9
# se hizo 10
# se hizo 11
# se hizo 12
# se hizo 13
# se hizo 14
# se hizo 15
# se hizo 16
# se hizo 17
# se hizo 18
# se hizo 19
# se hizo 20
# se hizo 21
# se hizo 22
# se hizo 23
# se hizo 24
# se hizo 25
# se hizo 26
# se hizo 27
# se hizo 28
# se hizo 29
# se hizo 30
# se hizo 31
# se hizo 32
# se hizo 33
# se hizo 34
# se hizo 35
# se hizo 36
# se hizo 37
# se hizo 38
# se hizo 39
# se hizo 40
# se hizo 41
# se hizo 42
# se hizo 43
# se hizo 44
# se hizo 45
# se hizo 46
# se hizo 47
# se hizo 48
# se hizo 49
# se hizo 50
# se hizo 51
# se hizo 52
# se hizo 53
# se hizo 54
# se hizo 55
# se hizo 56
# se hizo 57
# se hizo 58
# se hizo 59
# se hizo 60
# se hizo 61
# se hizo 62
# se hizo 63
# se hizo 64
# se hizo 65
# se hizo 66
# se hizo 67
# se hizo 68
# se hizo 69
# se hizo 70
# se hizo 71
# se hizo 72
# se hizo 73
# se hizo 74
# se hizo 75
# se hizo 76
# se hizo 77
# se hizo 78
# se hizo 79
# se hizo 80
# se hizo 81
# se hizo 82
# se hizo 83
# se hizo 84
# se hizo 85
# se hizo 86
# se hizo 87
# se hizo 88
# se hizo 89
# se hizo 90
# se hizo 91
# se hizo 92
# se hizo 93
# se hizo 94
# se hizo 95
# se hizo 96
# se hizo 97
# se hizo 98
# se hizo 99
# se hizo 100
# se hizo 101
# se hizo 102
# se hizo 103
# se hizo 104
# se hizo 105
# se hizo 106
# se hizo 107
# se hizo 108
# se hizo 109
# se hizo 110
# se hizo 111
# se hizo 112
# se hizo 113
# se hizo 114
# se hizo 115
# se hizo 116
# se hizo 117
# se hizo 118
# se hizo 119
# se hizo 120
# se hizo 121
# se hizo 122
# se hizo 123
# se hizo 124
# se hizo 125
# se hizo 126
# se hizo 127
# se hizo 128
# se hizo 129
# se hizo 130
# se hizo 131
# se hizo 132
# se hizo 133
# se hizo 134
# se hizo 135
# se hizo 136
# se hizo 137
# se hizo 138
# se hizo 139
# se hizo 140
# se hizo 141
# se hizo 142
# se hizo 143
# se hizo 144
# se hizo 145
# se hizo 146
# se hizo 147
# se hizo 148
# se hizo 149
# se hizo 150
# se hizo 151
# se hizo 152
# se hizo 153
# se hizo 154
# se hizo 155
# se hizo 156
# se hizo 157
# se hizo 158
# se hizo 159
# se hizo 160
# se hizo 161
# se hizo 162
# se hizo 163
# se hizo 164
# se hizo 165
# se hizo 166
# se hizo 167
# se hizo 168
# se hizo 169
# se hizo 170
# se hizo 171
# se hizo 172
# se hizo 173
# se hizo 174
# se hizo 175
# se hizo 176
# se hizo 177
# se hizo 178
# se hizo 179
# se hizo 180
# se hizo 181
# se hizo 182
# se hizo 183
# se hizo 184
# se hizo 185
# se hizo 186
# se hizo 187
# se hizo 188
# se hizo 189
# se hizo 190
# se hizo 191
# se hizo 192
# se hizo 193
# se hizo 194
# se hizo 195
# se hizo 196
# se hizo 197
# se hizo 198
# se hizo 199
# se hizo 200
# se hizo 201
# se hizo 202
# se hizo 203
# se hizo 204
# se hizo 205
# se hizo 206
# se hizo 207
# se hizo 208
# se hizo 209
# se hizo 210
# se hizo 211
# se hizo 212
# se hizo 213
# se hizo 214
# se hizo 215
# se hizo 216
# se hizo 217
# se hizo 218
# se hizo 219
# se hizo 220
# se hizo 221
# se hizo 222
# se hizo 223
# se hizo 224
# se hizo 225
# se hizo 226
# se hizo 227
# se hizo 228
# se hizo 229
# se hizo 230
# se hizo 231
# se hizo 232
# se hizo 233
# se hizo 234
# se hizo 235
# se hizo 236
# se hizo 237
# se hizo 238
# se hizo 239
# se hizo 240
# se hizo 241
# se hizo 242
# se hizo 243
# se hizo 244
# se hizo 245
# se hizo 246
# se hizo 247
# se hizo 248
# se hizo 249
# se hizo 250
# se hizo 251
# se hizo 252
# se hizo 253
# se hizo 254
# se hizo 255
# se hizo 256
# se hizo 257
# se hizo 258
# se hizo 259
# se hizo 260
# se hizo 261
# se hizo 262
# se hizo 263
# se hizo 264
# se hizo 265
# se hizo 266
# se hizo 267
# se hizo 268
# se hizo 269
# se hizo 270
# se hizo 271
# se hizo 272
# se hizo 273
# se hizo 274
# se hizo 275
# se hizo 276
# se hizo 277
# problemas en la palabra 278
# se hizo 279
# se hizo 280
# se hizo 281
# se hizo 282
# problemas en la palabra 283
# se hizo 284
# problemas en la palabra 285
# se hizo 286
# se hizo 287
# se hizo 288
# se hizo 289
# problemas en la palabra 290
# se hizo 291
# se hizo 292
# se hizo 293
# se hizo 294
# se hizo 295
# problemas en la palabra 296
# se hizo 297
# se hizo 298
# se hizo 299
# se hizo 300
# se hizo 301
# se hizo 302
# se hizo 303
# se hizo 304
# problemas en la palabra 305
# se hizo 306
# se hizo 307
# se hizo 308
# se hizo 309
# se hizo 310
# problemas en la palabra 311
# problemas en la palabra 312
# se hizo 313
# se hizo 314
# se hizo 315
# se hizo 316
# se hizo 317
# se hizo 318
# se hizo 319
# se hizo 320
# se hizo 321
# problemas en la palabra 322
# se hizo 323
# se hizo 324
# se hizo 325
# se hizo 326
# se hizo 327
# problemas en la palabra 328
# problemas en la palabra 329
# se hizo 330
# se hizo 331
# se hizo 332
# se hizo 333
# se hizo 334
# se hizo 335
# se hizo 336
# se hizo 337
# problemas en la palabra 338
# problemas en la palabra 339
# se hizo 340
# problemas en la palabra 341
# se hizo 342
# se hizo 343
# se hizo 344
# se hizo 345
# se hizo 346
# se hizo 347
# se hizo 348
# se hizo 349
# se hizo 350
# se hizo 351
# se hizo 352
# se hizo 353
# se hizo 354
# se hizo 355
# se hizo 356
# se hizo 357
# se hizo 358
# se hizo 359
# se hizo 360
# se hizo 361
# se hizo 362
# problemas en la palabra 363
# problemas en la palabra 364
# se hizo 365
# se hizo 366
# problemas en la palabra 367
# se hizo 368
# problemas en la palabra 369
# se hizo 370
# se hizo 371
# problemas en la palabra 372
# se hizo 373
# se hizo 374
# se hizo 375
# se hizo 376
# se hizo 377
# problemas en la palabra 378
# se hizo 379
# problemas en la palabra 380
# se hizo 381
# se hizo 382
# se hizo 383
# problemas en la palabra 384
# se hizo 385
# se hizo 386
# se hizo 387
# se hizo 388
# se hizo 389
# se hizo 390
# se hizo 391
# se hizo 392
# se hizo 393
# se hizo 394
# se hizo 395
# se hizo 396
# problemas en la palabra 397
# se hizo 398
# se hizo 399
# se hizo 400
# se hizo 401
# problemas en la palabra 402
# se hizo 403
# se hizo 404
# se hizo 405
# se hizo 406
# se hizo 407
# problemas en la palabra 408
# se hizo 409
# se hizo 410
# se hizo 411
# se hizo 412
# se hizo 413
# se hizo 414
# problemas en la palabra 415
# se hizo 416
# se hizo 417
# se hizo 418
# se hizo 419
# se hizo 420
# se hizo 421
# se hizo 422
# se hizo 423
# se hizo 424
# se hizo 425
# problemas en la palabra 426
# se hizo 427
# se hizo 428
# se hizo 429
# se hizo 430
# se hizo 431
# se hizo 432
# problemas en la palabra 433
# se hizo 434
# se hizo 435
# se hizo 436
# se hizo 437
# se hizo 438
# problemas en la palabra 439
# se hizo 440
# se hizo 441
# se hizo 442
# se hizo 443
# problemas en la palabra 444
# se hizo 445
# se hizo 446
# se hizo 447
# se hizo 448
# se hizo 449
# se hizo 450
# se hizo 451
# se hizo 452
# problemas en la palabra 453
# problemas en la palabra 454
# se hizo 455
# se hizo 456
# se hizo 457
# se hizo 458
# se hizo 459
# se hizo 460
# se hizo 461
# se hizo 462
# se hizo 463
# se hizo 464
# se hizo 465
# se hizo 466
# se hizo 467
# se hizo 468
# problemas en la palabra 469
# se hizo 470
# se hizo 471
# se hizo 472
# se hizo 473
# problemas en la palabra 474
# se hizo 475
# se hizo 476
# se hizo 477
# se hizo 478
# se hizo 479
# se hizo 480
# se hizo 481
# se hizo 482
# se hizo 483
# se hizo 484
# se hizo 485
# se hizo 486
# se hizo 487
# problemas en la palabra 488
# se hizo 489
# se hizo 490
# se hizo 491
# se hizo 492
# se hizo 493
# se hizo 494
# se hizo 495
# se hizo 496
# se hizo 497
# se hizo 498
# se hizo 499
# se hizo 500
# se hizo 501
# se hizo 502
# se hizo 503
# se hizo 504
# se hizo 505
# se hizo 506
# se hizo 507
# se hizo 508
# problemas en la palabra 509
# se hizo 510
# se hizo 511
# se hizo 512
# se hizo 513
# se hizo 514
# se hizo 515
# se hizo 516
# se hizo 517
# se hizo 518
# se hizo 519
# se hizo 520
# se hizo 521
# se hizo 522
# se hizo 523
# se hizo 524
# se hizo 525
# se hizo 526
# se hizo 527
# se hizo 528
# se hizo 529
# se hizo 530
# se hizo 531
# se hizo 532
# se hizo 533
# se hizo 534
# se hizo 535
# se hizo 536
# se hizo 537
# se hizo 538
# se hizo 539
# se hizo 540
# se hizo 541
# se hizo 542
# se hizo 543
# se hizo 544
# problemas en la palabra 545
# se hizo 546
# se hizo 547
# se hizo 548
# se hizo 549
# se hizo 550
# se hizo 551
# se hizo 552
# se hizo 553
# problemas en la palabra 961
# problemas en la palabra 962
# problemas en la palabra 963
# problemas en la palabra 964
# problemas en la palabra 965
# problemas en la palabra 966
# problemas en la palabra 967
# problemas en la palabra 968
# problemas en la palabra 969
# problemas en la palabra 970
# problemas en la palabra 971
# problemas en la palabra 972
# problemas en la palabra 973
# problemas en la palabra 974
# problemas en la palabra 975
# problemas en la palabra 976
# problemas en la palabra 977
# problemas en la palabra 978
# problemas en la palabra 979
# problemas en la palabra 980
# problemas en la palabra 981
# problemas en la palabra 982
# problemas en la palabra 983
# problemas en la palabra 984
# problemas en la palabra 985
# problemas en la palabra 986
# problemas en la palabra 987
# problemas en la palabra 988
# problemas en la palabra 989

# %%
lista_v3[970]
# Out:
# 'Colombia signs the treaty for the prohibition of nuclear weapons (TPAN) - sign the petition! https://t.co/f0jyhhorik will or'

# %% [markdown]
# ## Un tema importante es que al parecer la API bloque la IP si es muy usada.

# %%
def lista_ingles(lista):
    lista_def=[]
    for i in lista:
        try:
            pal=i.text
            lista_def.append(pal)
        except:
            lista_def.append('NA')
    return(lista_def)

# %%
lista_v5=lista_ingles(lista_v4)

# %% [markdown]
# # Sig paso: Eliminacion de HTTPS

# %%
def sin_https(lista):
    lista_def=lista
    for i in range(0,len(lista)):
        try:
            pal=lista[i].strip()
            word='https:'
            if word in pal:
                s=pal.find(word)
                e=s+len(word)
                while pal[e]!=" ":
                    if e<(len(pal)-1):
                        e=e+1
                    else:
                        break
                if s!=0 and e!=len(pal):
                    pal_final=pal[0:(s-1)]+pal[e:len(pal)]
                elif s!=0 and e==len(pal):
                    pal_final=pal[0:(s-1)]
                else:
                    pal_final=pal[e:len(pal)]
                lista_def[i]=pal_final
        except:
            print("revisar",i)
    return(lista_def)

# %%
lista_v6=sin_https(lista_v5)

# %% [markdown]
# ## Embedding de cada frase de Twitter

# %%
import gensim

# %%
import numpy as np

# %%
wv_embeddings = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True, limit=500000)

# %%
def tweet_to_vec(question, embeddings, dim=300):
    """
        question: string
        embeddings: llave=palabra, valor=vectorizacion
        dim: size de la representacion

        resultado= pregunta vectorizada en dicha dimension 
    """
    result = np.zeros(dim)
    cnt = 0
    # pregunta se convierte en lista
    words = question.split()
    for word in words:
        # Buscamos cada palabra de la lista en el diccionario
        if word in embeddings:
            result += np.array(embeddings[word])
            cnt += 1
    if cnt != 0:
        result /= cnt
    return result

# %%
tweet_vec= []
for tweet in lista_v6:
    # Strip elimina el primer espacio en el string
    question = tweet.strip()
    # Cada pregunta la pasamos al testeo
    answer = tweet_to_vec(question, wv_embeddings)
    # Imprimimos cada pregunta con su vectorizacion 
    tweet_vec.append(answer)
    #print(question2vec_result)

# %%
len(tweet_vec)
# Out:
# 990

# %% [markdown]
# ### Cosine

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
a=cosine_similarity([tweet_vec[0]],[tweet_vec[1]])

# %% [markdown]
# Medida coseno de cada arreglo con los demas

# %%
def medida_coseno(lista):
    lista_total=[]
    for i in lista:
        lista_coseno=[]
        for j in lista:
            if (i-j).all():
                a=cosine_similarity([i],[j])
                lista_coseno.append(a)
        lista_total.append(lista_coseno)
    return(lista_total)

# %%
cosenos=medida_coseno(tweet_vec)
# Toma unos segundos

# %%
len(cosenos[0])
# Out:
# 989
